# %% [markdown]
# # Get review data and teams keywords

# %%
REVIEW_PATH = '../Resources/1_clean_review_data'

KEYWORDS_PATH = '../Resources/2_keywords_for_teams_data'

DATA_PATH = '../Resources'

REVIEW_COL = 'Review'
TITLE_COL = 'Title'

# %%
data = pd.read_csv(os.path.join(REVIEW_PATH,'cleanAppStore.csv'))

# %%
with open(os.path.join(KEYWORDS_PATH,'team_keywords.json'),'r') as f:
    team_names_keywords = json.load(f)

with open(os.path.join(KEYWORDS_PATH,'grouped_team_keywords.json'),'r') as f:
    groups_keywords = json.load(f)
    
with open(os.path.join(KEYWORDS_PATH,'grouped_team_mapping.json'),'r') as f:
    mapping = json.load(f)

# %% [markdown]
# # Extract keywords in 2 ways

# %% [markdown]
# ## Term_extractor (POS-tagging based algorithm)

# %%
from rutermextract import TermExtractor
term_extractor = TermExtractor()

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
reviews_keywords = {}
empty_index = []
for i in tqdm(data.index):
    reviews_keywords[i] = []
    for term in term_extractor(data.iloc[i][REVIEW_COL]):
        reviews_keywords[i].append(term.normalized)
    for term in term_extractor(data.iloc[i][TITLE_COL]):
        reviews_keywords[i].append(term.normalized)
    reviews_keywords[i] = list(set(reviews_keywords[i]))
    if len(reviews_keywords[i])==0:
        del reviews_keywords[i]
        empty_index.append(i)
# Out:
# 100%|██████████| 11584/11584 [00:53<00:00, 218.31it/s]

# %%
reviews_keywords
# Out:
# {0: ['сбербанк', 'приложение'],
#  1: ['обновление', 'неделя', 'мои друзья', 'приложение'],
#  2: ['функция',
#   'работа',
#   'последнее обновление',
#   'обновлённая версия',
#   'приложение',
#   'сканирование лица',
#   'добрый день'],
#  3: ['подключение wi-fi'],
#  4: ['минус', 'applepay', 'баланс', 'mastercard'],
#  5: ['перевод',
#   'нея',
#   'номер телефона',
#   'деньга',
#   'поддержка',
#   'банка',
#   'аккаунт',
#   'карта',
#   '2 карты',
#   'проблема',
#   'такая низкая оценка',
#   'такой крупный банка',
#   'приложение',
#   'ошибка',
#   'тупой бот',
#   'нонсенс'],
#  6: ['история', 'возможность'],
#  7: ['2020 год',
#   'вид',
#   'ваши жёлтые конкуренты',
#   'банка',
#   'сии поры',
#   'доставка',
#   'отдетение',
#   'ваше банка',
#   'огромная база зарплатников',
#   'все счёт',
#   'банк',
#   'сбер',
#   'одно город',
#   'другие банка',
#   'ребята',
#   'офис',
#   'пенсионеры',
#   'переводы',
#   'карта',
#   'закрой',
#   'другое отделение'],
#  8: ['перевод денег', 'банка'],
#  9: ['дипломированные мошенники'],
#  10: ['половина операций',
#   'приложение',
#   'история',
#   'др проблемы',
#   'последнее время',
#   'баллы'],
#  11: ['уведомления',
#   'история операций',
#   'приложение',
#   'штуки',
#   'приложение супер,вот'],
#  12: ['хорошее приложение', 'баги', 'лаги'],
#  13: ['вайфай', 'скачивание'],
#  14: ['работа', 'mvm3105', 'самое моё любимое приложение'],
#  15: ['время пользователя', 'новый интерфейс', 'ненужные анимации'],
#  16: ['5 дней', 'обновление', 'сбербанк'],
#  17: ['остаток',
#   'остатки',
#   'вкладка',
#   'увеличение',
#   'неделя',
#   'день',
#   'бюджет',
#   'p.s',
#   'самое дело'],
#  18: ['батарея', 'iphone', 'последнее обновление'],
#  19: ['раздел', 'сбербанк', 'проблема', 'вклад'],
#  20: ['удобное приложение'],
#  21: ['каждое обновление', 'один недостаток', 'push уведомления', 'сбербанк'],
#  22: ['комиссия',
#   'сумма',
#   'месяц',
#   'подписка',
#   'деньга',
#   'сбербанк',
#   '50 тыс рублей',
#   'люди',
#   'клиенты',
#   'бесчеловечный подход',
#   'другие карта сбербанка'],
#  23: ['тема искусства',
#   'одна маленькая деталь',
#   'искусство',
#   'приложение',
#   'приветствие',
#   'целое',
#   'телефон'],
#  24: ['недоработанный приложение',
#   'идентификаторы',
#   'неудобное банковское приложение',
#   'кривое приложение',
#   'интернет',
#   'платёж',
#   'шаблон',
#   'кривые',
#   'ежемесячная оплата',
#   'время'],
#  25: ['банк', 'оформление', 'логика', 'окно', 'заявка', 'кредитная карта'],
#  26: ['тихий ужас',
#   'новая версия приложения',
#   'лишние переходы',
#   'история операций',
#   'обновление приложения'],
#  27: ['негатив', 'реклама'],
#  28: ['предыдущая версия',
#   'константинович',
#   'сергей',
#   'версия',
#   'вклады',
#   'провайдер',
#   'планшет ipad',
#   'андроид',
#   'тарифы',
#   'меню смартфона',
#   'планшет',
#   'сбербанк',
#   'меню',
#   'мой взгляд',
#   'уважение',
#   'клиенты',
#   'смартфон',
#   'одна ориентация',
#   'весь планшет',
#   'начисление',
#   'товар',
#   'кома',
#   'пенсионеры',
#   'ошибочное решение',
#   'втб россии',
#   'ipad',
#   'отзыв',
#   'новая версия'],
#  29: ['2 дня', 'итог', 'обновление', 'интернет', 'память'],
#  30: ['apple watch', 'деньга', 'приложение apple watch', 'приложение'],
#  31: ['картина',
#   'настройки',
#   'добрый день',
#   'замечательная идея',
#   'репродукция картин художников',
#   'обычные видовые фотография'],
#  32: ['списание', 'последнее обновление', 'подключённые копилка', 'копилка'],
#  33: ['ошибка программы',
#   'вход',
#   'флажок сообщений',
#   'значок',
#   'горящий окно сообщений',
#   'мобильное приложение',
#   'сбербанк',
#   'проблема',
#   'диалоги',
#   'красный цифра',
#   'время',
#   'моё обращение',
#   'ошибку!!’ь',
#   'непрочитанные сообщения',
#   'окно',
#   'два обновления',
#   'повод',
#   'уважаемые разработчики программы',
#   'красный значок',
#   'каждый раз',
#   'приложение',
#   'непрочитанный сообщение'],
#  34: ['обновление'],
#  35: ['хороший пример',
#   'самое удобное приложение',
#   'другие банки',
#   'наихорошие банковское приложение'],
#  36: ['офигели', 'карта сбербанка', 'перевод', 'комиссия'],
#  37: ['т', 'каждый раз', 'заёбали'],
#  38: ['раздел',
#   'два параллельными полосами',
#   'световая волна',
#   'карта',
#   'очередной глюк',
#   'какие-то 2 прямоугольника',
#   'никакая информация'],
#  39: ['функция',
#   'менеджер',
#   'банк',
#   'оператор',
#   '15 минут',
#   'ожидание',
#   'звонок',
#   'помощь интернета',
#   'чат',
#   'куда',
#   'связь',
#   'отзыв',
#   'бот',
#   'кнопка'],
#  40: ['обновление', 'перезапуск', 'приложение', 'карта'],
#  41: ['ужас',
#   'очередь',
#   '2 часа',
#   'карта',
#   'услуги',
#   'какой год',
#   'смс',
#   'ваше банка'],
#  42: ['пошлина', 'приложение'],
#  43: ['два дня', 'начало', 'приложение', 'результат', 'обновление'],
#  44: ['сбербанк', 'стильное приложение'],
#  45: ['банк',
#   '2020 год',
#   'приложение',
#   'остальные приличные банковские приложения',
#   'правильное направление',
#   'перспектива'],
#  46: ['виджет', 'уведомление', 'заход'],
#  47: ['главное',
#   'реклама',
#   'данная ситуация',
#   'возможность',
#   'мобильное приложение',
#   'умышленно-навязанная реклама',
#   'каждый обновление',
#   'экран'],
#  48: ['пользователь',
#   'корп',
#   'новостные лента',
#   'понимание',
#   'бесящая проблема',
#   'такое ощущение',
#   'люба',
#   'вход',
#   'лайты',
#   'версия',
#   'отделение',
#   'зачисление',
#   'минуты',
#   'ваши истории',
#   'wi-fi',
#   'истории',
#   'перевод',
#   'сворачивание',
#   'остальной ненужная ерунда',
#   'анимации',
#   'окно входа',
#   'банковские операции',
#   'диалоги',
#   'люди',
#   'политика',
#   'главная страница',
#   'телефон',
#   'медиакомбайн',
#   'проблемы',
#   'разработчики',
#   'сворачивание историй',
#   'мессенджеры',
#   'банк-клиент',
#   'кома',
#   'загружаемые картинки',
#   'кнопка',
#   'блэк-джек',
#   'сообщение',
#   'сеть',
#   'ваши диалоги',
#   'раз',
#   'банкоматы',
#   'ваше приложение',
#   'общение',
#   'кнопочки',
#   'новые сообщения',
#   'мессенджер'],
#  49: ['какое-либо перевод',
#   'галочка',
#   'значок загрузки',
#   'режим',
#   'тёмная тема',
#   'надпись',
#   'страница',
#   'зелёный экран',
#   'светофор',
#   'экран'],
#  50: ['лаж', 'оценка', 'удобное приложение'],
#  51: ['другие банки', 'приложение', 'карта'],
#  52: ['подписка', 'сосуны', 'деньга', 'люди'],
#  53: ['уведомление', 'виджет'],
#  54: ['сутки',
#   'переводы',
#   '8 тысяч',
#   '15 тысяч',
#   'ваш лимит',
#   'вопрос',
#   'карта',
#   'лимит',
#   'личный кабинет'],
#  55: ['50 тыс',
#   'переводы',
#   'клиенты',
#   'просьба',
#   'один банка',
#   'приложение',
#   'издевательство',
#   'процент',
#   '100 тыс',
#   'лимит',
#   'месячные переводы',
#   'народ'],
#  56: ['комиссия',
#   'перевод',
#   'банк',
#   'прилодение',
#   'подписка',
#   'банка',
#   'приложение',
#   'молодцы',
#   'уведомление',
#   'абонентка',
#   'разработчики',
#   'полное дно'],
#  57: ['целый день', 'программа', 'все нормы', 'интернет'],
#  58: ['загрузка',
#   'приложение',
#   '200 мб',
#   'файл',
#   'wifi',
#   'подключение',
#   'меньший размер'],
#  59: ['хорошее приложение', 'реклама', 'доставка', 'еда', 'весь экран'],
#  60: ['комиссия', 'банк', 'условия пандемии', 'фашисты'],
#  61: ['банер',
#   'жёлтый банк',
#   'отличное приложение',
#   'возможность',
#   'сбербанк',
#   'узкий круг людей',
#   'сторисы',
#   'мобильный банка'],
#  62: ['отображение времени',
#   'система',
#   '12-часовой формат',
#   'телефон',
#   'формат времени'],
#  63: ['высочайший уровень', 'шик'],
#  64: ['прога', 'ребята', 'интерфейс'],
#  65: ['wallet', 'айфон', 'touch id'],
#  66: ['новое',
#   'мобильный интернет',
#   'новые обновление',
#   'приложение',
#   'обновление',
#   'лимит'],
#  67: ['приложение', 'списание'],
#  68: ['сумма',
#   'денежные средства',
#   'iphone',
#   'виджет показа',
#   'карта',
#   'оплата',
#   'виджет',
#   'люба услуги'],
#  69: ['обновление', 'перевод денег', 'все выжные функция', 'месенджер'],
#  70: ['телефон', 'владимировна', 'бесконтактная карта', 'мир'],
#  71: ['само приложение', 'приложение', 'двойка', 'обновление', 'версия'],
#  72: ['ненужный хлам'],
#  73: ['обвешанное хлам',
#   'касса',
#   'минута',
#   'минимум',
#   'ответ',
#   'интернетом-уведомление',
#   'доброе смс',
#   '3 секунд',
#   'главная страница',
#   'тяжёлое приложение',
#   'очередь',
#   'клики',
#   'смс',
#   'баланс',
#   'приложение',
#   'логотипы-то',
#   'рабочий стола телефона',
#   'неотключаемые виджеты',
#   'старое',
#   'заход'],
#  74: ['проблема', 'обновление'],
#  75: ['отличное приложение', 'отзыв'],
#  76: ['прога',
#   'загрузка',
#   'сожаление',
#   'айфон',
#   'se',
#   'app',
#   'мобильная связь',
#   'такое большое приложение',
#   'лимит 200мб',
#   'app store',
#   'itunes store',
#   'программа',
#   'вай-фай',
#   'разработчик',
#   '280мбы',
#   'настройки телефона',
#   'раздел',
#   'сотовая связь',
#   'город',
#   'лесу/з',
#   'данные разделы',
#   'ограничение',
#   'скачивание фалов',
#   'возможность снятия ограничений',
#   'новая версия'],
#  77: ['сбербанк', 'телефон iphone', 'приложение', 'wi-fi'],
#  78: ['ужас',
#   'ограниченный набор знаков',
#   'важный перевод',
#   'приложение',
#   'назначение платежа'],
#  79: ['добрый день', 'обновление', 'сбербанк', 'айфон'],
#  80: ['обновлённый интерфейс',
#   'последние месяцы',
#   'каждый раз',
#   'каждый ваши обновление',
#   'приложение',
#   'отзывы',
#   'программеры',
#   'переустановка',
#   'время'],
#  81: ['уважаемые разработчики',
#   'история операций',
#   'приложение',
#   'карта',
#   'сбербанк'],
#  82: ['сумма',
#   'персональный менеджер',
#   'иные зачисление',
#   'платежка',
#   'квитанция',
#   'перечисление',
#   'деньга',
#   'возможность',
#   'добрый день',
#   'существенный недостаток',
#   'какие назначение',
#   'заявка',
#   'замечательное приложение',
#   'поступление',
#   'история зачислений'],
#  83: ['магазин',
#   'касса',
#   'счёты',
#   'ужасное обновление',
#   'приложение',
#   'никакое перевод',
#   'поход',
#   'карта',
#   'сбербанк',
#   'пол часа',
#   'старая версия'],
#  84: ['реальный отзыв',
#   'оператор',
#   'оценка',
#   'галочка',
#   'внутренние уведомление',
#   'номер',
#   'вопрос',
#   'живой',
#   'титанические усилие',
#   'боты',
#   'стабильность'],
#  85: ['жёлтый прямоугольник',
#   'раздел',
#   'физическая карта',
#   'соответствующие картинки',
#   'текстура карт',
#   'карта',
#   'текстура',
#   'visa-gold'],
#  86: ['перевод', 'баланс', 'враг', 'сбербанк', 'такая банк'],
#  87: ['приходные операции', 'карты', 'информация', 'последнее обновление'],
#  88: ['обновление', 'ошибка', 'инфо', 'карта'],
#  89: ['деньга', 'лжецы', 'обновление приложения', 'мои деньга'],
#  90: ['устройство iphone7 ios',
#   'возможность',
#   'версия приложения',
#   'непрочитанные сообщения',
#   'версии',
#   'пункт',
#   'баг',
#   'открытие',
#   'действия/история/финансы',
#   'самое дело',
#   'верхняя панель'],
#  91: ['дофига', 'мобильный сеть', 'возможность', 'обновление', 'фай', 'объём'],
#  92: ['отличие',
#   'очередное дно',
#   'слово',
#   'задержка подключения',
#   'комиссия',
#   'примитивная цель',
#   'другие банки',
#   'ручка',
#   'пора',
#   'алчность',
#   'головы',
#   'бедняжечки',
#   'внутрибанковские переводы',
#   'умолчание',
#   'имбецильная мысль',
#   'принуждение',
#   'неосведомлённые граждане',
#   'отказ',
#   'руководство',
#   'компенсация',
#   'межбанковские переводы(от',
#   'ваш низменный способ'],
#  93: ['отличное приложение', 'хорошая работа'],
#  94: ['поддержка карт', 'apple pay', 'мир', 'карта'],
#  95: ['4 раза',
#   'разные люди',
#   'страховка',
#   'такая сервис',
#   'банк',
#   'очередь',
#   '10 раз',
#   'час',
#   'раз',
#   'приложение',
#   'одна звезда',
#   'чат',
#   'кредит',
#   'паспорт',
#   'уведомление',
#   'живой',
#   '15 платных услуг'],
#  96: ['точка зрения эргономики', 'фонтан', 'банк', 'новая версия'],
#  97: ['возможность', 'мешающие карточка', 'история', 'карточка', 'экран'],
#  98: ['3 года',
#   'винд',
#   'интерфейс',
#   'шикарное приложение',
#   'никштяк',
#   'квадраты',
#   'конкуренты',
#   'каждый обновление',
#   'крупные компании',
#   'специальный отдел',
#   'ваши идея',
#   'клиенты',
#   'огонь'],
#  99: ['класс', 'крутое приложение'],
#  100: ['хорошее приложение',
#   'общий баланс',
#   'работа',
#   'приложение',
#   'средства',
#   'постоянный место',
#   'глаза'],
#  101: ['ipad mini',
#   'огрызки',
#   'приложение',
#   'сбер',
#   'экран ipad mini',
#   'тинькова'],
#  102: ['виджет уведомления',
#   'приложение se',
#   'информация',
#   'средства',
#   'вход'],
#  103: ['раздел',
#   'система',
#   'дели',
#   'куда',
#   'обновление',
#   'платежи/переводы',
#   'быстрые платежи'],
#  104: ['обновление', 'счёт'],
#  105: ['чёрные',
#   'зелёные кнопка',
#   'новый дизайнер',
#   'общий дизайн приложения',
#   'сбербанк',
#   'новая метла',
#   'дизайн входа',
#   'общая стилистика'],
#  106: ['реклама',
#   '1 место',
#   'фото',
#   'новая установка',
#   'занимаемый объём',
#   'каждый обновление',
#   'картинки',
#   'место',
#   'удаление'],
#  107: ['функция', 'алименты'],
#  108: ['земля',
#   'успешные конкуренты',
#   'очередное дно',
#   'нетерпение',
#   'недоразумение',
#   'сортировка операций',
#   'одно место',
#   'слово',
#   'люба',
#   'протяжение',
#   'день',
#   'неюзабильное приложение',
#   'запуск',
#   'косяки',
#   'вынужденные имя',
#   'банка',
#   'комиссия',
#   'торговый центр',
#   'два картами сбербанка',
#   'неловкие ситуация',
#   'следующий пункт',
#   'upd',
#   '2019 году',
#   'заправка',
#   'название',
#   'сбербанк',
#   'другие банки',
#   'целое',
#   'один раз',
#   'люди',
#   'ваше банка',
#   'мои купюра',
#   'несколько часов',
#   'моё мнение',
#   'корпоративное зло',
#   'приложения',
#   'новейшая прошивка ios',
#   'адекватный человек',
#   'подобные ситуации',
#   'все вышеописанные проблема',
#   'многие года',
#   'последний обновление приложения',
#   'моя жизнь',
#   'ваши банкоматы',
#   'неработающие банкоматы',
#   '10 тысяч',
#   'первое',
#   'один такая неудачник',
#   'город',
#   'сравнение',
#   'состояние',
#   'снятие',
#   'конец',
#   'пух',
#   'откровенные изъяны',
#   'пенсионеры',
#   'друг друга',
#   'переводы',
#   'раз',
#   'банкоматы',
#   'недобанка',
#   'приложение',
#   'пункты',
#   'клиент',
#   'мой терпение',
#   'этаж',
#   'минусы',
#   'миллионник',
#   'время'],
#  109: ['банальные современные фичи',
#   'шикарное приложение',
#   'усмотрение',
#   'такое отношение',
#   '2020 год',
#   'выглядящий пластик',
#   'деньга',
#   'принтом',
#   'apple wallet',
#   'вопрос',
#   'доработки',
#   'приваты',
#   'apple pay',
#   'вид иконок карт',
#   'названия карт',
#   'классная фишка',
#   'дизайн карт',
#   'передовые история',
#   'продукты',
#   'аляпистые рисунки',
#   'учёт',
#   'банка',
#   'сии поры',
#   'все активные пользователи приложения',
#   'год',
#   'наихорошие образ',
#   'отличное приложение',
#   'дизайнеры',
#   'сбербанк',
#   'двор',
#   'такое приложение',
#   'ваша клиентоориентированность',
#   'люди',
#   'разработчики',
#   'индивидуализация',
#   'банк',
#   'дизайн карты',
#   'сама карта',
#   'самый дизайн карты',
#   'ваша стандартная карта',
#   'возможность',
#   'монохромный чёрный цвет',
#   'дизайнеры приложения сбербанка',
#   'такая реализация',
#   'прекрасная реализация',
#   'кард',
#   'стандартная карта',
#   'настроенное продукт',
#   'тинькова',
#   'дизайн',
#   'кастомизация',
#   'мастер',
#   'окно карты',
#   'гросс периода',
#   'показатель',
#   'такие мелкие недоработка',
#   'ужасные картинка',
#   'предложенные шаблоны',
#   'надпись',
#   'ваши принтом',
#   'просьба',
#   'приложение',
#   'карта',
#   'качество',
#   'ваше приложение',
#   'мой отзыв',
#   'название',
#   'индивидуальный дизайн',
#   'другие пользователи',
#   'юзер',
#   'шаблоны',
#   'ваш имидж'],
#  110: ['звук ввода пароля', 'мультяшная заставка', 'приветствие'],
#  111: ['такие вес приложения', '280 мб'],
#  112: ['iphone'],
#  113: ['комиссия',
#   'месяц',
#   'перевод',
#   'деньга',
#   'астрахань',
#   'карта',
#   'сбербанк',
#   'астраханец'],
#  114: ['работа',
#   'наихорошие банки',
#   'мозг',
#   'тупые статья',
#   '10 минут',
#   'приложение',
#   'карта',
#   'полная сеть',
#   'мой счёт',
#   'ваше даунское приложение',
#   'отличный интернет'],
#  115: ['показуха смысла', 'дно'],
#  116: ['качели', 'позор', 'позорище', 'клоунада', 'такие масштабы', 'банка'],
#  117: ['секунды',
#   'подписка',
#   'ненавязчивая реклама',
#   'вид',
#   'крестик',
#   'приход',
#   'банка',
#   'реклама',
#   'ответ',
#   'upd',
#   'фильмы',
#   'специальное приложение',
#   'заставка',
#   'разработчик',
#   'кинотеатр',
#   'назначение',
#   'кнопка отключения предложений',
#   'обилие рекламы',
#   'банк',
#   'ее(реклама',
#   'запуск приложения',
#   'рекламная помойка',
#   'бакны',
#   'приложение',
#   'кино',
#   'конкуренты',
#   'банковское приложение',
#   'банковские услуги'],
#  118: ['крутое приложение'],
#  119: ['паша',
#   'фото',
#   'отличное приложение',
#   'мобильное приложение',
#   'сбербанк',
#   'привет'],
#  120: ['согласия',
#   'двойка',
#   'меню',
#   'лимиты',
#   'клиент',
#   'игра',
#   'противодействие'],
#  121: ['виджете',
#   'баланс',
#   'приложение',
#   'полученные рекомендации',
#   'уведомление',
#   'iphone xr',
#   'виджет'],
#  122: ['ужасное обновление', 'старая версия'],
#  123: ['загрузка', 'секунды', 'приложение', 'последнее обновление'],
#  124: ['предыдущий обновление',
#   'тиньковы',
#   'медленнооооо',
#   'красота',
#   'приложение',
#   'русский стандарт',
#   'все новшество',
#   'проблема',
#   '7 палубами',
#   'семь потами',
#   '288 мегабайт',
#   'боинг',
#   'тир',
#   'бассейн',
#   'разработчики'],
#  125: ['каждый раз', 'айфон 6s', 'предыдущая сумма', 'виджет'],
#  126: ['татьяна', 'обновление', 'приложение'],
#  127: ['самый высокий процент',
#   'самый плохая банк',
#   'нормальное приложение',
#   'история россии',
#   'имя',
#   'греф',
#   'самый худший банк',
#   'фон',
#   'другие банки'],
#  128: ['стикеры',
#   'хлам',
#   'поддержка',
#   'приложение',
#   'чат',
#   'история',
#   'заставка',
#   'диалоги',
#   'работа приложения',
#   'детальная информация'],
#  129: ['сбербанк', 'второй день'],
#  130: ['push-уведомление',
#   'актуальная информация',
#   'информация',
#   'haptic-touch',
#   'иконка приложения',
#   'приложение',
#   'просмотр списка уведомлений',
#   'виджет',
#   'заход'],
#  131: ['отзыв', 'стабильность', 'клик', 'ваша параша'],
#  132: ['само приложение',
#   'дело',
#   'любые друг',
#   'срочное дело',
#   'е приложения',
#   'сбербанк',
#   'косяк',
#   'все настроение'],
#  133: ['приложение', 'одноразовый код'],
#  134: ['комиссия', 'перевод', 'лимит', 'сбер'],
#  135: ['программа'],
#  136: ['мобильный интернет',
#   'уважаемые разработчики',
#   'деньга',
#   'приложение',
#   '200 мб',
#   'фай'],
#  137: ['комиссия',
#   'банк',
#   'позор',
#   'дружественные банка',
#   'круг',
#   'внутренние переводы',
#   'дебетовая карта'],
#  138: ['мусор',
#   'карта',
#   'ваше приложение',
#   'объём информации',
#   'все ваши нововведение',
#   'счёт',
#   'aliexpress',
#   'память телефона',
#   'валерьянка',
#   'кнопка'],
#  139: ['ужасное обновление', '200мбы', 'приложение'],
#  140: ['черта',
#   'перевод',
#   'экране,',
#   'обратно,раньша',
#   'банк',
#   'фамилия',
#   'пересесть',
#   'сбербанк онлайн..вот',
#   'имя',
#   'онлайн.вы',
#   'нужное человек',
#   'сбербанк',
#   'пишет,перевод',
#   'уведомление',
#   'самая программа'],
#  141: ['приложение', 'айфон xr'],
#  142: ['13.6 iphone',
#   'ios',
#   'изменение',
#   'тёмная тема',
#   'приложение',
#   'обновление',
#   '7 push-уведомления',
#   'виджет'],
#  143: ['номер',
#   'отвратительное приложение',
#   'страна',
#   'лоб',
#   'семь пядей',
#   'история',
#   'диалоги',
#   'нормальная история операций',
#   'расходы',
#   'истинные доходы',
#   'банк',
#   '5 звёзд',
#   'поддержка',
#   'кома',
#   'два разделах',
#   'такое банка',
#   'приложение',
#   'рейтинг',
#   'нервы',
#   'время'],
#  144: ['пуш-уведомление',
#   'платный смс',
#   'все нормальные банки пуш-уведомления',
#   'поступление средств',
#   'очередной обновление',
#   'альтернатива',
#   'уведомление',
#   'ваш приложение',
#   'банка',
#   'ответ',
#   'галочка',
#   'люди',
#   'платная услуга',
#   'разработчики',
#   'самый ущербный банк',
#   'бесплатные пуш-уведомление',
#   'смс',
#   'раз',
#   'приложение',
#   'карта',
#   'практика'],
#  145: ['информирование', 'обновляется!!!смс', 'виджет', 'карта'],
#  146: ['контрольное слово',
#   'жесть',
#   'бред',
#   'номер телефона',
#   'итог',
#   'время',
#   'вопрос',
#   'карта',
#   'сбербанк',
#   'ребята',
#   'банка'],
#  147: ['магазин', 'кой бог', 'смс-банк', 'уведомление', 'списание'],
#  148: ['рукожопый дизайн', 'логотип', 'весь экран', 'открытка', 'ребята'],
#  149: ['проблема'],
#  150: ['тема', 'оформление', 'картины', 'перебои', 'моё сердце', 'эрмитаж'],
#  151: ['18 лет', 'деньга', 'открытие вклада', 'неплохое приложение', 'банка'],
#  152: ['неделя', 'баланс', 'виджет', 'виджете'],
#  153: ['прога', 'телефон'],
#  154: ['раздел',
#   'карты',
#   'действие',
#   'финансы',
#   'карта',
#   'окно',
#   'история',
#   'три точки',
#   'экран',
#   'кнопка'],
#  155: ['проблема', 'сбербанк', 'заход'],
#  156: ['операция списания',
#   'живой оператора',
#   'деньга',
#   'баланс',
#   'карта',
#   'история',
#   'помощник',
#   'некомпетентный помощник',
#   'списание'],
#  157: ['реклама', 'граф', 'специальные предложение', 'минимализм', 'дух'],
#  158: ['совместительство спекулянта',
#   'мерзость',
#   'мошенник сороса',
#   'ваши история',
#   'известный финансист',
#   'советы',
#   'трафик'],
#  159: ['дни',
#   'проверка',
#   'сберегательный счёт',
#   'деньга',
#   'приложение',
#   'проблема',
#   'вклады'],
#  160: ['ошибка входа', 'приложение'],
#  161: ['проверка',
#   'проверка штрафов',
#   'факт',
#   'номер квитанции',
#   'штрафы',
#   'свидетельство',
#   'оплата',
#   'авто'],
#  162: ['функция',
#   'последнее обновление',
#   'push уведомления',
#   'сожаление',
#   'приложение',
#   'такая проблема',
#   'сбербанк',
#   '2 обновления',
#   'место',
#   'виджет'],
#  163: ['комиссия',
#   'согласование условий договора',
#   'самое дно',
#   'переводы',
#   'банк',
#   'банковский сектор',
#   'альфа',
#   'пздцы',
#   'банка'],
#  164: ['ваш конец', 'джордж', 'сорос', 'твёрдый колы'],
#  165: ['ужасное приложение', 'пароль'],
#  166: ['накладки', 'отличное приложение', 'сбои', 'сбербанк'],
#  167: ['кликкнопка',
#   'подстраница',
#   'меню',
#   'страница',
#   'бонусы',
#   'баг',
#   'инфо'],
#  168: ['выгодный банк', 'система', 'нерезиденты', 'быстрые платежи'],
#  169: ['уведомления', 'жалоба', 'приход', 'расход'],
#  170: ['пенсионеры',
#   'спасибоооо',
#   'одно ваше филиал',
#   'очередь',
#   'тихая филиал',
#   'наше район',
#   'услуга',
#   'добровольский',
#   'отзыв',
#   'мой отзыв',
#   'старики',
#   'каждое житель',
#   'г.владивосток'],
#  171: ['приложение'],
#  172: ['норма',
#   'жизнь держателя карты',
#   'самый убогий банк',
#   'наличие',
#   'приложение',
#   'услуги',
#   'постоянное навязывание'],
#  173: ['главное',
#   'вкладка',
#   'финансы',
#   'история',
#   'действие',
#   'экран',
#   'умолчание'],
#  174: ['ненужная информация',
#   'пиратский сайт',
#   '2000хи годов',
#   'банеры',
#   'настройки',
#   'уважаемые разработчики',
#   'возможность',
#   'приложение',
#   'добрый день',
#   'обновление',
#   'главная страница',
#   'ужасные банеры',
#   'банка'],
#  175: ['перевод',
#   'настройка',
#   'баланс',
#   'приложение',
#   'имя',
#   'присутствие',
#   'баланс карты'],
#  176: ['англ', 'english', 'язык'],
#  177: ['уведомления',
#   'сумма',
#   'ответ',
#   'банк',
#   'push',
#   'приложение',
#   'р',
#   'долгий нажатие',
#   'оплата',
#   'смс'],
#  178: ['шанс', 'история', 'срок', 'платежи карт'],
#  179: ['обновлений,темы', 'тормоза'],
#  180: ['ответ',
#   'дело',
#   'сообщение',
#   'дурак',
#   'поддержка',
#   'полный отстой',
#   'чат',
#   'вероятность',
#   'приложение норм',
#   'нафиг',
#   'такая функционал',
#   'нуль'],
#  181: ['соединение', 'смена телефона', 'сбербанк', 'связь', 'интернет'],
#  182: ['другие приложение',
#   'почта',
#   'истории',
#   'отдельное приложение',
#   'соцсеть',
#   'ваши история',
#   'приложение',
#   'агрегатор спама',
#   'тинейджеры',
#   'банка'],
#  183: ['реклама', 'пол экрана', 'приложение', 'история', 'инстаграмм'],
#  184: ['баги',
#   'интерфейс приложения',
#   'глаза',
#   'фильтр',
#   'негатив',
#   'скролл',
#   'история',
#   'диалоги',
#   'все операция',
#   'все разделы',
#   'история операций',
#   'верх',
#   'основной контент',
#   'скольжение',
#   'выбранная карта',
#   'кредитка',
#   'карта',
#   'весь новый функционал',
#   'дубль',
#   'новая версия'],
#  185: ['сбербанк', 'деньга', 'банда,н', 'фссп'],
#  186: ['группировка',
#   'пункты',
#   'основное',
#   'карта',
#   'куда',
#   'анализ финансов',
#   'пункт',
#   'экран',
#   'все время'],
#  187: ['оператор',
#   'всё бот',
#   'анимация',
#   'итог',
#   'полчаса',
#   'приложение',
#   'картинка',
#   'чат',
#   'вход',
#   'футболка',
#   'чаты',
#   'полезные советы',
#   'эрмитаж',
#   'банка'],
#  188: ['какие дни',
#   '1 крупное обновление',
#   '2 месяца',
#   'продавцы',
#   'анализ',
#   'настройка бюджета',
#   'категориям,',
#   'каждое продавец',
#   'детализация',
#   'расходы',
#   'раздел',
#   'сто шагов',
#   'итог',
#   'финансы',
#   'какая версия',
#   'исправления',
#   'операции',
#   'какая сумма',
#   'продавцам...раньша',
#   '2 минорных обновления',
#   'группировка',
#   'продавцам!'],
#  189: ['пользование',
#   'ужас',
#   'такие уведомления',
#   'разработчики',
#   'сообщение',
#   'реклама услуг',
#   'банка',
#   'приложение',
#   'реклама сбера',
#   'отключение',
#   'кнопка',
#   'разные услуги',
#   'вклады',
#   'одно дело',
#   'удаление'],
#  190: ['старые',
#   'заказ справки',
#   'все счёт',
#   'госслужащие',
#   'приложение',
#   'открытые счета',
#   'моё имя'],
#  191: ['природа', 'все приветствие', 'анимация', 'приветствие'],
#  192: ['реклама'],
#  193: ['выгрузка', 'причина', 'разработчики'],
#  194: ['приложение', 'последнее обновление'],
#  195: ['ваше обновление push уведомления', 'push уведомления'],
#  196: ['комиссия', 'сбербанк', 'жлобский банк'],
#  197: ['тёмная тема', 'настройка', 'доработка', 'время суток', 'зависимость'],
#  198: ['сбербанк', 'мир', 'карта'],
#  199: ['деньги',
#   'мобильный интернет',
#   'последнее обновление',
#   'деньга',
#   'приложение',
#   'вайфай',
#   'проблема',
#   'вход',
#   'счёт'],
#  200: ['ios', 'бред', 'приложение', 'переводы'],
#  201: ['тишина', 'sos'],
#  202: ['лишние непонятные окна',
#   'приложение',
#   'вход',
#   'мерзкое обновление',
#   'непонятный интерсервис',
#   'старое'],
#  203: ['карты', 'переводы', 'приложение', 'карта', 'раздел карты', 'ребята'],
#  204: ['пол экрана',
#   'два пустых прямоугольника',
#   'тёмная тема',
#   'прямоугольник',
#   'возможность',
#   'карта',
#   'мерцающие чёрные',
#   'пункт',
#   'действие',
#   'крайняя мера'],
#  205: ['ужас',
#   'наличка',
#   'раз',
#   'балалайка',
#   'приложение',
#   'айфон',
#   'обновление',
#   'жуть'],
#  206: ['название', 'говнопедобанк'],
#  207: ['комиссия',
#   'ужас',
#   'система',
#   'банка',
#   'бот',
#   'техподдержка',
#   'быстрые платежи'],
#  208: ['осень',
#   '18 веке',
#   'сбер',
#   'сравнение',
#   'другие банка',
#   'самое наихорошее приложение',
#   'удобное приложение'],
#  209: ['комиссия',
#   '200мбы',
#   'переводы',
#   'другая банк',
#   'загрузка',
#   'все карта',
#   'программа',
#   'терпение',
#   'обновление',
#   'wi-fi'],
#  210: ['отображение',
#   'нижняя строка',
#   'минута',
#   'айфон',
#   'быстрый доступ',
#   'вай-фай',
#   'кучка',
#   'подключение',
#   'ужас',
#   'зимняя версия',
#   'тупые истории',
#   'бонусы',
#   'петшоп',
#   'приложуха',
#   'новое',
#   'мои интересы',
#   'приложение',
#   'никчёмные говноeды',
#   'интернет',
#   'помойка'],
#  211: ['два приложения',
#   'ваши супер дизайнеры',
#   'встроенный контрстрайк',
#   'переводы',
#   'киданули',
#   'приложение',
#   'нетфликс',
#   'бонусы',
#   'следующий обновление',
#   'всякие рюшечек',
#   'тинейджеры',
#   'подобие',
#   'дизайн',
#   'инстаграмм'],
#  212: ['все блоки',
#   'ужас',
#   'жесть',
#   'интерфейсы',
#   'какие-то всплывашка',
#   'рекомендация',
#   'куда',
#   'день',
#   'товарищи',
#   'весь экран',
#   'ваши дизайнеры'],
#  213: ['жесть',
#   'оператор',
#   'звонки',
#   'каждый раз',
#   'приложение',
#   'крым',
#   'проблема',
#   'идиотизм'],
#  214: ['новое интерфейс', 'раздел историй', 'возможность', 'здоровая критика'],
#  215: ['ответить,бот',
#   'поддержка',
#   'поиск',
#   'обновление',
#   'теги',
#   'открытые вклады'],
#  216: ['уведомления',
#   'банк',
#   'push-уведомление',
#   'виджете',
#   'номер телефона',
#   'баланс',
#   'приложение',
#   'карта',
#   'проблема',
#   'мобильное оператор',
#   'связь',
#   'виджет',
#   'заход'],
#  217: ['сбербанк', 'ваше обновление'],
#  218: ['комиссия'],
#  219: ['цифра суммы платежа',
#   'провал',
#   'одна реклама',
#   'лента',
#   'весь экран',
#   'кабельное тв'],
#  220: ['удовольствие',
#   'новый интерфейс',
#   'последнее обновление',
#   'центр',
#   'загрузка',
#   'приложение',
#   'несчастные точка',
#   'карта',
#   'отвратительное обновление',
#   'старый сбербанк',
#   'три точки',
#   'тип',
#   'операция',
#   'белый экран',
#   'время'],
#  221: ['мир', 'карта'],
#  222: ['конец', 'платные платежи'],
#  223: ['приложение', 'ошибка', 'молодцы', 'какая банк', 'обновление'],
#  224: ['раздел',
#   'перевод',
#   'наклейка',
#   'сообщение',
#   'каждый раз',
#   'какая-то баг/лаг/глюк',
#   'приложение',
#   'вход',
#   'диалоги',
#   'самое дело'],
#  225: ['сплошное неудобство', 'карты', 'обновление'],
#  226: ['опция',
#   'прочие предложение',
#   'минимализм',
#   'карта',
#   'счёт',
#   'данный вид',
#   'сторис'],
#  227: ['выдача карты',
#   'уроды',
#   'ум',
#   'приложение',
#   'карта',
#   'посещение оф-лайнофиса'],
#  228: ['обслуживание карты',
#   'остаток',
#   'месяц',
#   'смс-уведомление',
#   'каждый раз',
#   'деньга',
#   'приложение',
#   'номер',
#   'карта',
#   'разрабочики',
#   'плач',
#   'смс'],
#  229: ['11 программа', 'ios', 'деньга', 'обновление', 'версия'],
#  230: ['все операция',
#   'история операций',
#   'история',
#   'автоплатёж жкх',
#   'списание'],
#  231: ['знак',
#   'магазин',
#   'группировка',
#   'прошлое',
#   'красавчики',
#   'наихорошее банковское приложение',
#   'название',
#   'продавцам(спустя 6обнов',
#   'разрабы',
#   'расходы',
#   'благодарность',
#   'названия',
#   'такая вопрос'],
#  232: ['молодцы', 'история', 'отдельный окошко', 'последнее обновление'],
#  233: ['i can’t use the app cause my daughter does not speak russian',
#   'where are the english version',
#   'why does it take a while just to translate a gui interface',
#   'question'],
#  234: ['интернетом-магазина,такси',
#   'карта',
#   'остальное нарекания',
#   'история',
#   'возврат денег',
#   'возврат',
#   'сумма карт'],
#  235: ['сумма',
#   'отправка',
#   'перезагрузка приложения',
#   'баланс',
#   'карта',
#   'операции',
#   'достаток',
#   'самая большая проблема',
#   'кома',
#   'обновление суммы'],
#  236: ['управляющая директор',
#   'наш счёт',
#   'ребёнок',
#   'операционист',
#   'указание',
#   'уши',
#   'qr-code',
#   'реквизиты отправителя',
#   'комиссия сбербанка',
#   'банка',
#   'урод',
#   'папик',
#   'поганая метла',
#   'перевод',
#   'дата',
#   'гарем',
#   'реквизиты',
#   'голуба',
#   'каждый обновление',
#   'люди',
#   'упырь-то',
#   'оплата',
#   'прокладки',
#   'народ',
#   'клоуны',
#   'девизиона',
#   'посылочки',
#   'настоящее',
#   'целые',
#   'корреляция',
#   'настоящая банковская выписка',
#   'писулька',
#   'подписывающие справка',
#   'дистанционный обворовывание россиян',
#   'твои новые технологии',
#   'поиск',
#   'идиoт',
#   'время коронавируса',
#   'чаты',
#   'подобные существо',
#   'открыточки',
#   'возраст',
#   'личный визит',
#   'расследование',
#   'рубли',
#   'изменение',
#   'деньга',
#   'операций?почий списания',
#   'карта сбера',
#   'греф',
#   'продажа презервативов',
#   'левин',
#   'пример',
#   'платёжное поручение',
#   'рожа',
#   'комиссия',
#   'сии поры',
#   'меню',
#   'высокий рейтинг',
#   'сбербанк',
#   'твой хоботок',
#   'история',
#   'кривой what’s up',
#   'реквизиты карты',
#   'подключение переводов',
#   'история операций',
#   'отстой',
#   'одно раздел',
#   'одна организация',
#   'бабки',
#   'приложение',
#   'зарплата',
#   'подтверждающий документ',
#   'глаз',
#   'люба суммы',
#   'качество',
#   'коммунальные платежи',
#   'воришка',
#   'россияне',
#   'растрата денег россиян',
#   'брокерский счёт',
#   'сумма списания',
#   'новые технологии',
#   'такая абрамов',
#   'имя',
#   'деградант',
#   'твой убогий приложение',
#   'да!накрученные отзывы',
#   'ноги',
#   'такая голуба',
#   'жалкое клоунское подобие',
#   'заполнение реквизитов',
#   'дивизионы',
#   'голубчик',
#   'лапа',
#   '500 руб',
#   'самолётик',
#   'позорище',
#   'диалоги',
#   'половина',
#   'огромные бонусы',
#   'обычные сотрудники',
#   'карты',
#   '50 тыс',
#   'хереющий хоботок грефа',
#   'функционал',
#   'справки реквизитов операции',
#   'подпись абрамовой',
#   'понос',
#   'семья',
#   'польза',
#   'целое',
#   'институт',
#   'обезьяна',
#   'коронавирус',
#   'назначение платежа',
#   'настоящий цирк',
#   'востребование',
#   'текст',
#   'наши украденные деньга',
#   'бесплатные быстрые переводы',
#   'отчётность',
#   'позорище сбера',
#   'клиенты',
#   'чудо-технология',
#   'очередь',
#   'инновационные убогие технология',
#   'итог',
#   'повторяющаяся операция',
#   '2 года',
#   'сбер',
#   'операции',
#   'счёт',
#   'ворюга',
#   'дикая комиссия',
#   'голубок',
#   'счёт россиян',
#   'друг',
#   'каско',
#   'забота',
#   'пункты',
#   'оплата квартплаты',
#   'куда',
#   'пропитой алкаш',
#   'чудо-технология грефа',
#   'банковское приложение',
#   '10 лет существования'],
#  237: ['сбербанк', 'работа', 'интерфейс', 'возможность'],
#  238: ['3 часа', 'удвоение'],
#  239: ['комисси',
#   'подписка',
#   'жена деньги',
#   'вход',
#   'один регион',
#   'банка',
#   'комиссия',
#   'ваше нововведение',
#   'каждое обновление',
#   'данный параметр',
#   'платежи',
#   'оповещение',
#   'компьютер',
#   'возможность',
#   'дол.... push уведомления',
#   'смс',
#   'аду',
#   'друг',
#   'мобильная версия'],
#  240: ['ваши партнёры',
#   'поддержка',
#   'спам',
#   'уведомление',
#   'уважаемый сбербанк',
#   'всякий спам'],
#  241: ['банковский приложение', '270 мб'],
#  242: ['старенькие люди',
#   'молодые-то',
#   'обновление',
#   'нововведения',
#   'большое обновление'],
#  243: ['пчшшчшшф', 'языковч'],
#  244: ['отображение',
#   'настройки',
#   'гл.экран',
#   'вид',
#   'вид утери',
#   'утеря карты',
#   'номер карты',
#   'заблокированные карта',
#   'пополнение',
#   'перевод',
#   'заблокированные карты',
#   'добрый день',
#   'разработчик',
#   'отключённая функция',
#   'банк',
#   'перечисления',
#   'перечисление',
#   'все карта',
#   'сбер',
#   'старые номера карт',
#   'сохранение',
#   'замена',
#   'связь',
#   'оф.запрос',
#   'переводы',
#   'настройки приложения',
#   'приложение',
#   'карта',
#   'вся история',
#   'спокойствие',
#   'блокировка'],
#  245: ['уведомления',
#   'приложение',
#   'отчёт',
#   'карта',
#   'каждая новая версия',
#   'история',
#   'уровень развития',
#   'телекарды',
#   'пополнение счёта'],
#  246: ['10 минут', 'печаль', 'интернет'],
#  247: ['300мбы',
#   'реклама',
#   'ересь',
#   'голова',
#   'приложение',
#   'сбер',
#   'ш',
#   'чаты',
#   'блэкджек',
#   'народ'],
#  248: ['ограниченные возможности',
#   'вкладка',
#   'вкладки',
#   'приложение',
#   'человек',
#   'бак',
#   'платежи',
#   'ксения лазарева'],
#  249: ['сбербанк', 'все класс'],
#  250: ['приложение', 'айфон', 'карта', 'обновление', 'интернет', 'продукты'],
#  251: ['увеличение баланса', '5000р', 'обновление', 'счёт', 'моя карта'],
#  252: ['сбербанк', 'предыдущая версия'],
#  253: ['раздел',
#   'бред',
#   'год',
#   'сообщение',
#   'приложение',
#   'диалоги',
#   'цифра',
#   'стабильность',
#   'следующий раз'],
#  254: ['обслуживание', 'клиент', 'отзыв', 'банка'],
#  255: ['ipad', 'обновление', 'ipados'],
#  256: ['ответ',
#   'оператор',
#   'приложение',
#   'чат',
#   'тупые вопросы',
#   'бот',
#   'план общения'],
#  257: ['супер обновление', 'отличное обновление приложения'],
#  258: ['кнопка включения', 'зелёный цветы', 'другие цветки', 'цветовая гамма'],
#  259: ['раздел',
#   'новое',
#   'дело',
#   'лишнее время',
#   'каждый раз',
#   'возможность',
#   'приложение',
#   'карта',
#   'меню',
#   'обновление',
#   'быстрый доступ',
#   'разработчики'],
#  260: ['прекрасное приветствие',
#   'он-лайны',
#   'восхитительные шедевры',
#   'сбербанк',
#   'вид картин',
#   'тема полотна эрмитажа'],
#  261: ['расходы'],
#  262: ['такие образ',
#   'функция',
#   'банк',
#   'андройда',
#   'расход',
#   'анализ финансов',
#   'затрата'],
#  263: ['старая версия', 'версия'],
#  264: ['низкосортное рекламное агенство',
#   'приложение',
#   'лента',
#   'жиры',
#   'сбербанк',
#   'плохая отзыв',
#   'мои мнение',
#   'банка'],
#  265: ['деньги',
#   'баланс счёта',
#   'хорошее приложение',
#   'итог',
#   'обновление баланса',
#   'сума',
#   'старый баланс',
#   'ребята'],
#  266: ['english', 'добрый день', 'англоязычный интерфейс'],
#  267: ['сами имя', 'тёмная тема', 'приложение', 'сбербанк', 'приветствие'],
#  268: ['какой большенство',
#   'деньга',
#   'последний рубль',
#   '70 процентов страны',
#   'комиссия',
#   'регион',
#   'тарифы',
#   'перевод',
#   'человек',
#   'лимит',
#   'народ',
#   'тариф',
#   'времена коронавируса',
#   'какая комиссия',
#   'деньги',
#   'ахахахахахахахах',
#   'невозможность',
#   'кредитка',
#   'всемирная безработица',
#   'пятая точка',
#   'шок',
#   'большенство пользователей',
#   'какие лимиты'],
#  269: ['пользователь',
#   'отличное приложение',
#   'простой',
#   'дух',
#   'заморочки',
#   'банковское приложение'],
#  270: ['раз', 'диалоги', 'непрочитанное сообщение', 'перевод средств'],
#  271: ['одно досадное упущение',
#   'прогресс',
#   'суть сложностей',
#   'долгие мытарства',
#   'служба поддержки',
#   'недоработки',
#   'лицо',
#   'банка',
#   'работа',
#   'драгоценное время',
#   'период',
#   'другие банки',
#   'дебетовая карта',
#   'единственный возможное способ получения выписки',
#   'одни сутки',
#   'устранение ошибок',
#   'выписка',
#   'файл',
#   'офис',
#   'данный недостаток',
#   'карты',
#   'сообщение',
#   'сожаление возможности',
#   'обращение',
#   'приложение',
#   'карта',
#   'результат',
#   'большой количество операций',
#   'общение',
#   'электронная выписка',
#   'целое',
#   'электронная почта',
#   'попытка'],
#  272: ['раздел',
#   'главное',
#   'истории',
#   'моё счёт',
#   'открытки',
#   'истерии',
#   'возможность',
#   'втб',
#   'витрина',
#   'действия',
#   'экран',
#   'состояние'],
#  273: ['дни',
#   'какое-то время',
#   'день оплаты',
#   'просьба',
#   'квартплата',
#   'день',
#   'бюджет',
#   'платёжка',
#   'автоплатежи',
#   'кнопка'],
#  274: ['все вопросы',
#   'большая список',
#   'сообщение',
#   'возможность',
#   'ненужный мусор',
#   'история',
#   'очистка',
#   'техподдержка'],
#  275: ['раздел',
#   'интересы',
#   'настройки',
#   'все интересы',
#   'еда',
#   'кино',
#   'карточка',
#   'темы'],
#  276: ['российский сегмент',
#   'идея',
#   'информативность',
#   'мобильные банковские приложения',
#   'внимание',
#   'отличный свайпинги',
#   'молодцы',
#   'удобство',
#   'сбербанк',
#   'мой взгляд',
#   'мгновенная лотерейка',
#   'адекватная цена',
#   'тип',
#   'отзывы',
#   'ребята',
#   'сомнения'],
#  277: ['функция',
#   'текст',
#   'последнее обновление',
#   'уважаемые разработчики',
#   'картинка',
#   'куда',
#   'формат jpeg',
#   'реквизиты карты',
#   'текст ума'],
#  278: ['каждый пост',
#   'неологизмы сбера',
#   'ощущения',
#   'родители',
#   'раз',
#   'понимание проблемы',
#   'приложение',
#   'слово',
#   'язык написания постов сберкота',
#   'тормоза',
#   'школьники'],
#  279: ['реклама',
#   'настройки',
#   'финансы',
#   'все интересы',
#   'возможность',
#   'история',
#   'карточка',
#   'действие',
#   'главный экран'],
#  280: ['спам уведомления',
#   'переводы',
#   'приложение',
#   'обновление',
#   'отвратительный сервис',
#   'уведомление',
#   'рекламные сообщение',
#   'телефон',
#   'один банк'],
#  281: ['пользование',
#   'каждый раз',
#   'баланс',
#   'план',
#   'последнее время',
#   'счёт',
#   'какая сумма',
#   'денежка',
#   'личный кабинет'],
#  282: ['апрель',
#   'озон',
#   'вопросы',
#   'регулярные покупка',
#   'восемь месяцев',
#   'диалоги',
#   'акция',
#   'баллы',
#   'течение часа',
#   'какая причина',
#   'робот'],
#  283: ['комиссия', 'хорошее приложение'],
#  284: ['прочитанные старые уведомления'],
#  285: ['последнее обновление',
#   'приложение',
#   'код',
#   'карта',
#   'номер карты',
#   'cvc'],
#  286: ['й', 'цукк'],
#  287: ['смс/push-уведомление', 'номер', 'ошибка'],
#  288: ['сплошной мусор',
#   'социальная сеть',
#   'мусор',
#   'приложение',
#   'каждый новые обновление',
#   'сбербанк',
#   'программа'],
#  289: ['4,8 балла',
#   'мифы',
#   'переводы',
#   'прогнившая система',
#   'сплошное навязывание-ненужные кредиты',
#   'разряд',
#   'дурацкий приложение',
#   'либерализм',
#   'наличные деньга',
#   'просмотр оценок',
#   'одна звезда',
#   'приложение',
#   'предложения',
#   'зомбирование',
#   'безнал',
#   'сомнительные плюсы',
#   'автоплатежи'],
#  290: ['ipad', 'планшеты', 'приложение', 'версия'],
#  291: ['одна операция',
#   'наличие средств',
#   'приложение',
#   'толк',
#   'карта',
#   'разработчики'],
#  292: ['дно', 'планшет', 'ipad', 'версия', 'множество бизнесменов'],
#  293: ['оптимизированные приложение',
#   'другие бвнковы',
#   'полноценная поддержка ipad'],
#  294: ['банк',
#   'переводы',
#   'клиенты',
#   'воздух',
#   'клиент сбербанка',
#   'бабка',
#   'рамки региона',
#   'лимиты',
#   'очередной раз'],
#  295: ['обновление'],
#  296: ['аду', 'тварь', 'образование', 'греф', 'наши дети', 'какая стать'],
#  297: ['сбербанк', 'обновление', 'приложение'],
#  298: ['зарплата', 'какая работодатель'],
#  299: ['приложение лагает', 'серебро'],
#  300: ['худший банк',
#   'деятельность',
#   'все лагали',
#   'неудобный банк',
#   'россия',
#   'мир',
#   'твоя жизнь'],
#  301: ['дермище', 'воры'],
#  302: ['реклама', 'push-уведомление', 'приложение'],
#  303: ['комиссия', 'переводы', 'другая банк', 'разочарование', 'банка'],
#  304: ['хорошее приложение',
#   'ненужные операция',
#   'банк',
#   'переводы',
#   'множество проблем',
#   'некоторые операции',
#   'приложение',
#   'история',
#   'банкомат',
#   'счёт',
#   'оплата',
#   'услуга выписки',
#   'время'],
#  305: ['ужас',
#   'пофиги',
#   'ответ',
#   'push-уведомление',
#   'нововведение',
#   'тысяча вкладок',
#   'отговорка',
#   'переведённые средство',
#   'время',
#   'клиенты',
#   'разработчики'],
#  306: ['комиссия',
#   'ваша карта',
#   'переводы',
#   'дебильные задания',
#   'деньга',
#   'банк-шляпа',
#   'клиенты'],
#  307: ['тема',
#   'ситуация',
#   'бесчисленный негатив',
#   '20 июля',
#   '21 июля',
#   'скрины экрана',
#   'зелёная полоса',
#   'рекации',
#   'поразительная беспомощность',
#   'адрес',
#   'дневный света',
#   'каждый вход',
#   'отношение',
#   'проблема',
#   'граждане',
#   'двор',
#   'отзывы',
#   'клиенты',
#   'пора',
#   'реакция',
#   'сбер',
#   'другая ругня',
#   'подвал',
#   'жертва',
#   'проценты',
#   'состояние',
#   'почта',
#   'ноль',
#   'черта',
#   'переводы',
#   'описание проблемы',
#   'тёмная тема',
#   'засранцы',
#   'грамотный разраб',
#   'такое хамство',
#   'егэ',
#   '22 июля',
#   'петиция'],
#  308: ['разные углы',
#   'последнее обновление',
#   'галочка',
#   'откат обновлений',
#   'обновление',
#   'карточка',
#   'счёт',
#   'люди',
#   'курсы',
#   'металлы',
#   'место'],
#  309: ['знак',
#   'номер телефона',
#   'деньга',
#   'клиент сбербанка',
#   'приложение',
#   'контакт'],
#  310: ['функция',
#   'досрочное погашение кредитов',
#   'фич',
#   'деньга',
#   'приложение',
#   'хороший дизайн',
#   'сбербанк',
#   'счета',
#   'подсказка',
#   'вклады',
#   'целое',
#   'главный экран',
#   'хороший интернетом-банк',
#   'проблемы'],
#  311: ['900 рублей!!!с',
#   'вопрос!!отмазка',
#   'деньга',
#   '5000 комиссии',
#   'имя',
#   'суд',
#   'руководителем,он',
#   'размер',
#   'право',
#   'комиссия',
#   'детские деньги,которые',
#   'втб',
#   'меньше,мы',
#   'данный случае,н',
#   'бы,д времени',
#   'фирма',
#   'итог',
#   'вопрос-почему,вы',
#   'сбер',
#   'посредник',
#   'банкомат',
#   'счёт',
#   'курс',
#   'друга,дестские деньги',
#   'друг',
#   'раз',
#   'видать!руководство',
#   'карта',
#   'детские деньга',
#   'экран'],
#  312: ['последнее обновление',
#   'замечание',
#   'штраф',
#   'приложение',
#   'гибдд',
#   'номер постановления'],
#  313: ['ошибка', 'карта', 'вход', 'ближайший обновление', 'iphone xr'],
#  314: ['такая постоянная проблема приложения',
#   'подключение',
#   'сеть',
#   'деньга',
#   'приложение',
#   'третий день',
#   'проблема',
#   'плач',
#   'ваш банка'],
#  315: ['пользователь',
#   'возможность',
#   'программа',
#   'уведомление',
#   'возможность установки',
#   'хорошая программа',
#   'встроенный звук',
#   'пожелание',
#   'звук'],
#  316: ['цифра',
#   'накопительный итог',
#   'значок приложения',
#   'какой-то момент',
#   'новые сообщения',
#   'новые траты',
#   'покупка',
#   'глаза',
#   'нафиг',
#   'значок'],
#  317: ['удачное обновление',
#   'жуткое приложение',
#   'история',
#   'обновление',
#   'остаток средств'],
#  318: ['недовольство', 'деньга', 'дикие комиссии', 'политика', 'банка'],
#  319: ['месяц', 'приложение', 'баланс карты'],
#  320: ['половина штрафа',
#   'система',
#   'скидка',
#   'обновление',
#   'штрафы',
#   'кнопка'],
#  321: ['отделение',
#   'банк',
#   'просьба',
#   'все сотрудники',
#   '90-е',
#   'вопрос',
#   'чат',
#   'специалист',
#   'голосовой помощник',
#   'связь',
#   'аналогичный бот'],
#  322: ['обновление'],
#  323: ['соединение', 'интернет', 'ошибка'],
#  324: ['операторы', 'тупой робот', 'дрянь', 'проблема', 'нужная общая инф'],
#  325: ['плач', 'займ', 'кредит', 'рассрочка'],
#  326: ['денежные средства',
#   'перевод',
#   'дальнейшие перечисление',
#   'молодцы',
#   'сбербанк',
#   'денежные средство'],
#  327: ['все голос', 'накрутка', 'адекватный человек'],
#  328: ['самый отстойный банк россии', 'руслан'],
#  329: ['все вопросы',
#   'ситуация',
#   'звонок',
#   'схема',
#   'ваше умное помощник',
#   'автоответчики',
#   'отрицательный ответ',
#   'предмет передачи',
#   'чат',
#   'наплевательское отношение',
#   'ужаснейшая клиентоориентированность',
#   'онлайн-банк',
#   'плёнка',
#   'мошенники',
#   'односложные вопросы',
#   'компрометация',
#   'ужасное сервисное обслуживание',
#   'оперативная помощь',
#   'подобные входящие звонков',
#   'откровенное свинство',
#   'счёт безопасности средств',
#   'вопросы',
#   'раз',
#   'опасения',
#   'автоответчик',
#   'помощник',
#   'клиент',
#   'боты'],
#  330: ['предыдущая версия',
#   'раз',
#   'единственное пункт',
#   'меню',
#   'одно действие',
#   'верхний угол',
#   'повтор платежа',
#   'три точки',
#   'право',
#   'открывшийся меню',
#   'кнопка'],
#  331: ['дело',
#   'айпады',
#   'настройки',
#   'слово',
#   'айфон',
#   'смс уведомлений',
#   'телефоны',
#   'ваш приложение',
#   'смс уведомления',
#   'собака',
#   'случай',
#   'все пользователи',
#   'сбербанк',
#   '90 лет',
#   'ваши смс уведомления',
#   'оповещение',
#   'сотовая связь',
#   'отправка',
#   'положительный баланс',
#   'смартфон',
#   'выбор',
#   'последняя версия',
#   'сбер',
#   'смс',
#   'обе зарплатные карты',
#   'другие гаджеты',
#   'операторы',
#   'стандартные отписка',
#   'раз',
#   'приличная сумма',
#   'польза'],
#  332: ['моё кредитный потенциал',
#   'бесполезный поль',
#   'родственник',
#   'отношение',
#   'upd',
#   'дополнительное номер телефона',
#   'такие бесполезный условие',
#   'кредитный потенциал',
#   'услуга',
#   'потенциал',
#   'услуга расчёта',
#   'рабочий',
#   'расчёт',
#   'сценарий',
#   'телефон друга',
#   'предложенный вариант'],
#  333: ['сторисы(инстасбербанк',
#   'контекстная реклама',
#   'реклама',
#   'ахинея',
#   'партнёры',
#   'приложение',
#   'ваше предложение',
#   'сторисы',
#   'три точки',
#   'раклама',
#   'пользователи',
#   'банка'],
#  334: ['сотка',
#   'суть',
#   'странная статистика',
#   'система',
#   'деньга',
#   'твой платёж',
#   'слово',
#   'каждый месяц',
#   'капитализация',
#   'версия',
#   'такие платежи',
#   'зачисление',
#   'счёт вклада',
#   'неподтвержденные платежи',
#   'история платежей',
#   'информация',
#   'история',
#   'оранжевый цвет',
#   'денежка',
#   'дни',
#   'вклад',
#   'одно счёт',
#   'прошедшие',
#   'анализ финансов',
#   'коммуналка',
#   'счёт',
#   'смс',
#   'состояние',
#   'такие образ',
#   'зачисление капитализации',
#   'зачисления',
#   'iphone',
#   'раз',
#   'приложение',
#   'куча времени',
#   'ipad',
#   'списание'],
#  335: ['силы',
#   'перевыпущенная карта',
#   'дьявол',
#   'мелочи',
#   'случайный образ',
#   'смс-уведомления',
#   '2 чек-бокса',
#   'онлайн-банка',
#   'такие мелочи',
#   'план web-сервисов',
#   'галочка',
#   'начинка',
#   'сбербанк',
#   'отзывы',
#   'wtf',
#   'другое банка',
#   'банкомат',
#   'офис',
#   'главное пин-код карты',
#   'умолчание',
#   'успешные коммерческие банки',
#   'смс-уведомление',
#   'приложение',
#   'сама философия',
#   'push-уведомления',
#   'p.s',
#   'обёртка',
#   'сайт',
#   'время'],
#  336: ['город', 'обновление', 'посылка сберлогистики', 'тысяча этапов'],
#  337: ['обнова', 'обновление'],
#  338: ['комиссия', 'подписка', 'ваши переводы', 'курьеры', 'чтоли', '50000р'],
#  339: ['деньга', 'сьерегательный счёт'],
#  340: ['ipad', 'поддержка', 'приложение'],
#  341: ['отзыв', 'удобное приложение'],
#  342: ['банк',
#   'возможность',
#   'отказ',
#   'втб',
#   'приложение',
#   'кредит',
#   'заявка'],
#  343: ['3 часа',
#   'правильное время,с',
#   'все уведомление',
#   'разница',
#   'исправт',
#   'виджет'],
#  344: ['самый худший банк', 'позор', 'мир'],
#  345: ['способ сохранения чека',
#   'пользование',
#   'приложение',
#   'нужное действие'],
#  346: ['пин кода',
#   'ввод',
#   'приложение',
#   'последнее время',
#   'счёт',
#   'вклады',
#   'первое раза',
#   'время'],
#  347: ['апрель',
#   'баланс',
#   'приложение',
#   'такая проблема',
#   'баланс карты',
#   'виджет'],
#  348: ['сбербанк'],
#  349: ['информация', 'кредиты'],
#  350: ['приложение', 'каждый обновление', 'долгая загрузка'],
#  351: ['комиссия',
#   'перевод',
#   'все больший днище',
#   'другая банк',
#   'борьба',
#   'белые',
#   'банка',
#   'другой пользователь',
#   'грабёж',
#   'сбер',
#   'логотип',
#   'включение',
#   'свинство',
#   'зарплатный проект',
#   'умолчание'],
#  352: ['пин кода',
#   'функция',
#   'слова',
#   'приложение',
#   'карта',
#   'сбербанк',
#   'смена'],
#  353: ['деньги',
#   'переводы',
#   'оператор',
#   'оплата жкх',
#   'деньга',
#   'другое банка',
#   'поддержка',
#   'приложение',
#   'баланс',
#   'толк',
#   'карта',
#   'банкомат',
#   'такое приложение',
#   'последний месяц',
#   'платежи',
#   'баланс карты',
#   'бот'],
#  354: ['любим'],
#  355: ['кредит'],
#  356: ['два варианта просмотра',
#   'баланс',
#   'вход',
#   'виджет-уведомления',
#   'баланс карт',
#   'самая программа',
#   'виджет'],
#  357: ['средства,н',
#   'деньга',
#   'такие проблемы',
#   'счетами,раньша',
#   'перевод средств'],
#  359: ['реклама', 'приложение', 'вклад', 'карта'],
#  360: ['команда разработки',
#   'чат-бот',
#   'дизайнеры интерфейсов',
#   'оператор',
#   'клиентский опыт',
#   'сотрудники сбера',
#   'система',
#   'настройка',
#   'стор',
#   'приложение',
#   'фарс',
#   'интерфейс подключения',
#   'чат',
#   'отсутствие информации',
#   'коллеги оценки',
# ...
#   'ублюдские',
#   'кома',
#   'фантомное непрочтённое сообщение',
#   '50 тыс',
#   'переводы',
#   'карточка',
#   'нафиг',
#   'банковское приложение'],
#  858: ['молодцы', 'отзыв'],
#  859: ['комиссии', 'подписка', 'переводы', 'комиссия'],
#  860: ['тёмная тема'],
#  861: ['течение недели',
#   'секунды',
#   'деньга',
#   'имя',
#   'ужасное обслуживание',
#   'заявка',
#   'надёжность',
#   'банкомат сбербанка',
#   'псевдо',
#   'сервис',
#   'итог',
#   'удобный случай',
#   '5тыс',
#   'банкомат',
#   'такая ситуация',
#   'свет',
#   'поддержка пользователей',
#   'карта',
#   'возврат',
#   'данный банк',
#   'банкомат деньги'],
#  862: ['200мбы',
#   'анимация',
#   'переводы',
#   'бесполезные функции',
#   'баланс',
#   'приложение'],
#  863: ['быстрые переводы',
#   'номер телефона',
#   'служба',
#   'возможность',
#   'сбербанк',
#   'кнопка',
#   'шаблон',
#   'слабое приложение',
#   'тинькова'],
#  864: ['вклады',
#   'функция',
#   'процентные ставка',
#   'рестораны',
#   'само приложение',
#   'магазины',
#   'банк',
#   'доставка продуктов',
#   'технологичный банка',
#   'услуга',
#   'сбербанк',
#   'такси',
#   'возможность инвестиций',
#   'отправка посылок',
#   'отличная экосистема',
#   'p.s'],
#  865: ['зелёный некрасивые цвет', 'бред', 'нижний бар'],
#  866: ['тёмная тема'],
#  867: ['отключение историй', 'показ историй', 'такая настройка'],
#  868: ['раздел',
#   'остаток',
#   'сумма операций',
#   'список',
#   'история операций',
#   'совершенные операции',
#   'карта',
#   'недоработка',
#   'обновление'],
#  869: ['лента уведомлений', 'функция', 'вход'],
#  870: ['тёмная тема',
#   'приложение',
#   'крутая тёмная тема',
#   'молодцы',
#   'новые функции'],
#  871: ['крутое обновление', 'фишки'],
#  872: ['свайп', 'половина разделов'],
#  873: ['смс-услуга',
#   'карты',
#   'push-уведомление',
#   'настройки',
#   'последнее операция',
#   '60руб/мес',
#   'общая история'],
#  874: ['уведомления',
#   'реклама',
#   'важные уведомление',
#   'приложение',
#   'спамит',
#   'спам',
#   'акция',
#   'постоянные предложения',
#   'инвестиция',
#   'никакая реклама',
#   'сторизы',
#   'банка'],
#  875: ['операция пополнения счёта', 'платежи'],
#  876: ['тема приветствия',
#   'недочёт',
#   'новая тема приветствия',
#   'разработчики'],
#  877: ['тёмная тема', 'большие молодцы'],
#  878: ['тёмная тема', 'шрифты', 'последнее обновление'],
#  879: ['любопытные глаза', 'история', 'сторис', 'вопрос'],
#  880: ['комиссия',
#   'совесть',
#   'ваша компания',
#   'перевод',
#   'переводы',
#   'деньга',
#   'сбер',
#   'услуга',
#   'дорожка',
#   'ворье',
#   'мои деньги',
#   'дивизы'],
#  881: ['пароль', 'функция входа', 'upd', 'face id', 'молодцы'],
#  882: ['сбербанк', 'самый наихороший банк'],
#  883: ['разница',
#   'ответ',
#   'такая возможность',
#   'система',
#   'клиент сбербанка',
#   'приложение',
#   'выбор',
#   'вопрос',
#   'подключение услуги',
#   'жизнь',
#   'зависимость',
#   'срок кредита',
#   'частичное погашение',
#   'срок',
#   'платёж',
#   'ипотечники',
#   'ипотечный кредит'],
#  884: ['такие образ',
#   'доброе время суток',
#   'переводы',
#   'ублюдошные рожь',
#   'сектор',
#   'приложение',
#   '50 000 рублей',
#   'сбербанк',
#   'голос народа',
#   'лимиты',
#   'вся система'],
#  885: ['каждый день',
#   'высота',
#   'года',
#   'наихорошие приложения',
#   'деньга',
#   'приложение',
#   'услуга',
#   'удобство',
#   'сбербанк',
#   'разработчики'],
#  886: ['прошлое', 'заставка', 'какие-то старые', 'выбор заставки', 'пердуны'],
#  887: ['проблема', 'приложение'],
#  888: ['функция',
#   'раз',
#   'ваши предложения',
#   'косяк приложения',
#   'приложение',
#   'вечная реклама',
#   'проблема',
#   'отключение',
#   'интернет'],
#  889: ['комиссия', 'перевод', 'лимит'],
#  890: ['раздел', 'история транзакций', 'история', 'пофиксито'],
#  891: ['комиссия', 'конкуренты'],
#  892: ['какие-то бабка',
#   'природа',
#   'дед',
#   'карта',
#   'гоюк',
#   'сервис',
#   'заставка',
#   'приветствие',
#   'глюк',
#   'нормальное отображение остатков',
#   'эрмитаж'],
#  893: ['имя оценки',
#   'реклама',
#   'банк',
#   'покой',
#   'платные смс-ка',
#   'рекламные уведомление',
#   'приложение',
#   'отчёты',
#   'телевизор',
#   'пуш-оповещение',
#   'смс'],
#  894: ['0 рублей', 'верная сумма', 'карта'],
#  895: ['магазин', 'пинкод', 'рак', 'приложение', 'сбербанк', 'счёт', 'смс'],
#  896: ['оценка', 'возможность', 'основное', 'блок', 'история', 'место'],
#  897: ['ваша компания',
#   'наше народ',
#   'комиссии',
#   'грабительские комиссия',
#   'ваше банка',
#   'услуги',
#   'тяжёлые времена',
#   'выводы',
#   'клиенты',
#   'отток клиентов'],
#  898: ['уведомления',
#   'все зачисление',
#   'пуш-уведомления',
#   'оповещения',
#   'сбербанк',
#   'история',
#   'задержка',
#   'телефон',
#   'несоответствие',
#   'списание',
#   'колокольчик'],
#  899: ['приложение'],
#  900: ['порядок', 'раз', 'универсальный счёт', 'проблема'],
#  901: ['работа',
#   'ipad mini',
#   'всё время',
#   'ipad',
#   'поддержка ipad mini ios',
#   'телефон'],
#  902: ['сбербанк for your advanced application',
#   'amer m.m',
#   'сбербанк application is the best',
#   'thank you',
#   'easy comfort and safe'],
#  903: ['виджете',
#   'фиксированный выбор',
#   'возможность',
#   'баланс',
#   'основная карта',
#   'карта',
#   'последняя использованная карта',
#   'определённая карта'],
#  904: ['1 сообщение', 'приложение'],
#  905: ['банк',
#   'экран авторизации',
#   'важнейшие функции',
#   'приложение',
#   'экран аккаунта',
#   'вход',
#   'связь',
#   'экран заблерен',
#   'экстренные случаи',
#   'тинькова',
#   'кнопка'],
#  906: ['тёмная тема'],
#  907: ['соединение',
#   'руки',
#   'ios',
#   'один день',
#   'оптимизация',
#   'приложение',
#   'такие проблема',
#   'лаги',
#   'плохое интернет',
#   'б..дь',
#   'интернет',
#   'браузер',
#   'ютуба',
#   '5 месяцев',
#   'кривые',
#   'видео'],
#  908: ['класс'],
#  910: ['обновления',
#   'второй текст',
#   'озвучка',
#   'открытка',
#   'первая история',
#   'собственная озвучка'],
#  911: ['карты',
#   'каждый раз',
#   'финансы',
#   'приложение',
#   'куда',
#   'ужасное приложение',
#   'история',
#   'обновление',
#   'действие',
#   'кнопка'],
#  912: ['адрес',
#   'центр',
#   'адреса',
#   'пункт',
#   'сберлогистика',
#   'соседний дом',
#   'другие города'],
#  913: ['отзыв', 'наихорошие банковские приложения'],
#  914: ['anna0101', 'классное приложение'],
#  915: ['все операция',
#   'пароль',
#   'вкладка',
#   'конфиденциальность',
#   'приложение',
#   'вход',
#   'бог',
#   'счета',
#   'уведомление',
#   'уровень'],
#  916: ['раздел',
#   'сбой',
#   'предыдущие платежи',
#   'приложение',
#   'ошибка',
#   'сбер',
#   'программа',
#   'неделя',
#   'платежи',
#   'все заготовка',
#   'разработчики'],
#  917: ['авторизация', 'приложение', 'вкладка уведомления', 'уведомление'],
#  918: ['виза',
#   'голд',
#   'основная карта',
#   'мир',
#   'выбор карты',
#   'цифровая виза',
#   'совершение платежей',
#   'умолчание'],
#  919: ['интернет', 'неделя', 'приложение'],
#  920: ['карты',
#   'возможность установки лимитов',
#   'платёжные лимиты',
#   'возможность установки',
#   'блокировка интернет-платежей'],
#  921: ['день', 'пароль', 'приложение'],
#  922: ['ростовская области,спасибо',
#   'город шахты',
#   'нравится.сотрудники',
#   'отзыв'],
#  923: ['приложение'],
#  924: ['открытые вклады', 'мобильный приложение'],
#  925: ['дом', 'удобное приложение'],
#  926: ['обновление', 'приложение', 'три недели'],
#  927: ['автоматическое копирование номера',
#   'номер карты',
#   'карта',
#   'буфер обмена',
#   'программа',
#   'любая программа',
#   'cvv',
#   'помойка'],
#  928: ['перевод',
#   'транспондёр',
#   'деньга',
#   'сбер',
#   'коронавирус',
#   'восемь часов'],
#  930: ['перевод денег',
#   'приложение',
#   'остаточная сумма',
#   'ошибка',
#   'карта',
#   'такие примитивные ошибка',
#   'все ошибка',
#   'такая уровень',
#   'банка'],
#  931: ['комиссия',
#   'месяц',
#   'регион',
#   'перевод',
#   'переводы',
#   'просьба',
#   'клиентоориентированность',
#   '50 тысяч',
#   'отказ',
#   'слово',
#   'старый тариф',
#   '50т.р'],
#  932: ['тишина', 'надпись', 'поддержка', 'чат', 'все операторы', 'род'],
#  933: ['адрес',
#   'шаблон',
#   'лицевой счёт',
#   'каждый раз',
#   'возможность',
#   'номер',
#   'иные услуги',
#   'группа шаблонов',
#   'неудобная форма оплаты',
#   'оплата услуг',
#   'оплата',
#   'цена',
#   'сокращение времени',
#   'такая фич'],
#  934: ['функция',
#   'ваша система',
#   'голосовые роботы',
#   'палец',
#   'ваши распознавания',
#   'лицо',
#   'мой голос',
#   'сопли',
#   'согласие',
#   'ваша биометрия'],
#  935: ['ужас', 'сбербанк', 'удаление приложения'],
#  936: ['красноармейская 25 г',
#   'сотрудники сбербанка',
#   'петрозаводск',
#   'вопрос',
#   'квалифицированная помощь',
#   'специалист',
#   'сбербанк',
#   'сотрудники',
#   'ваш труд',
#   'слово благодарности'],
#  937: ['вход', 'новый iphone se', 'touch id'],
#  938: ['последнее обновление',
#   'постоянная загрузка',
#   'приложение',
#   'счёт',
#   'вклады'],
#  939: ['10 лет', 'уровень', 'ваши услуги'],
#  940: ['карты',
#   'нужная карта',
#   'список',
#   'переход',
#   'анализ финансов',
#   'iphone se',
#   'фильтр',
#   'баг',
#   'последующий выбор',
#   'нужная карточка',
#   'конец'],
#  941: ['really enjoying only some times they charge commissions',
#   'good app seberbank'],
#  942: ['карты',
#   'проверка',
#   '5 минут',
#   'итог',
#   'доступ',
#   'приложение',
#   'последнее время',
#   'счета',
#   'открытые счета',
#   'отстойное приложение'],
#  943: ['галерея', 'мелочь', 'картинка', 'молодцы', 'приветствие'],
#  944: ['интерфейс'],
#  945: ['обслуживание', 'благодарность'],
#  946: ['плохая банк',
#   'банк',
#   'переводы',
#   'наихороший банк',
#   'штрафы',
#   'газпром'],
#  947: ['push', 'данная услуга', 'интернет', 'уведомление', 'покупки'],
#  948: ['второй случай',
#   'пин',
#   'симка',
#   'ведомо',
#   'защита',
#   'одно приятель',
#   'слово',
#   'предоставление',
#   'отвратительное приложение',
#   'вклады',
#   'сити',
#   'очередной раз',
#   'банка',
#   'блевотное приложение',
#   'другая телефон',
#   '17 процентов',
#   'кредит',
#   'люди',
#   'телефон',
#   'личный кабинет',
#   'итог',
#   'сбер',
#   'счёт',
#   'с.ка',
#   'ноль',
#   'коллекторы',
#   'раз',
#   'маленький долг',
#   'приятель',
#   'карта',
#   'звонок оператора'],
#  949: ['время выполнения операции',
#   'ошибка',
#   'операция',
#   'каждое действие начала'],
#  950: ['молодцы', 'сбербанк', '30 лет'],
#  951: ['реклама', 'предложения', 'меню карт'],
#  952: ['кредит', 'переводы', 'времена'],
#  953: ['ссылка',
#   'приложение',
#   'обновление приложения',
#   'последняя версия',
#   'номер карты',
#   'глазок',
#   'версия',
#   'новая версия'],
#  954: ['получается,карта',
#   'обновление',
#   'счёт',
#   'кредиты',
#   'вклады',
#   'неприятность'],
#  955: ['открытка',
#   'последние обновления',
#   'плавный градиент',
#   'открытки входа'],
#  956: ['карточка'],
#  957: ['переводы',
#   'пролонгация',
#   'подписка',
#   'один месяц',
#   'мошенничество',
#   'навязывание услуг'],
#  958: ['комиссия', 'перевод', 'рубль', 'карта', 'счёт', 'банка'],
#  959: ['определённый период',
#   'действие автоплатежа',
#   'приложение',
#   'автоплатёж',
#   'предложение',
#   '3 месяцев',
#   'действие'],
#  960: ['аккумулятор',
#   'фоновый режим',
#   'принудительное перевод',
#   'акб',
#   'приложение',
#   'пушь уведомления'],
#  961: ['квадратные банеры', 'экран'],
#  962: ['информация', 'проблема', 'последнее обновление', 'виджет'],
#  963: ['пользование',
#   'социальная сеть',
#   'фильмы',
#   'искусство',
#   'картинка',
#   'обновление',
#   'упрощение',
#   'безопасность',
#   'банкинг',
#   'нафиг'],
#  964: ['каждый день',
#   'новое',
#   'комиссия',
#   'способ отъёма денег',
#   'информация',
#   'правило',
#   'сообщения',
#   'сбербанк',
#   'ерунда',
#   'платежи',
#   'клиенты',
#   'смс',
#   'личный кабинет'],
#  965: ['частые блокировка переводов',
#   'карты сбербанка',
#   'комиссия',
#   'бред',
#   'переводы',
#   'данный банка',
#   '2020 года',
#   'услуги',
#   'сбербанк',
#   'лето'],
#  966: ['ipad', 'планшет', 'приложение'],
#  967: ['2004 года', 'ваш клиент', 'плаха', 'банк'],
#  968: ['комиссия',
#   'чьи приложение',
#   'оплата штрафа',
#   'ряд',
#   'qr',
#   'приложение',
#   'код',
#   'скидка',
#   'другие банки',
#   'клиенты',
#   'барыги'],
#  969: ['меты',
#   'остатки',
#   'колесико',
#   'результат',
#   'металическим',
#   'обновление',
#   'счета',
#   'счёт',
#   'косяк',
#   'плиз'],
#  970: ['реклама',
#   'полоса',
#   'кнопка удаления',
#   'приложение',
#   'действия-истории-финансы',
#   'главный экран',
#   'строка'],
#  971: ['ipad2'],
#  972: ['мб', 'люди денег', 'хапуга', 'переводы'],
#  973: ['планшет',
#   'вёрстка',
#   'планшеты',
#   'ошибка',
#   'apple pay',
#   'попытка верификации карты'],
#  974: ['банк',
#   'оператор',
#   'идиотский голосовой помощник',
#   'upd',
#   'раз',
#   '2,5 мин',
#   'сожаление',
#   'ближайшие неск',
#   'разные планеты',
#   'карта',
#   'др'],
#  975: ['платные подписка',
#   'нарушение',
#   'главное',
#   'главный банк страны',
#   'переводы',
#   'комиссии',
#   'позор',
#   'люди',
#   'экран',
#   'умолчание'],
#  976: ['отличный банк'],
#  977: ['никакая польза',
#   'мусор',
#   'зависание',
#   'отвратительное приложение',
#   'переодичёска',
#   'вид информации'],
#  978: ['сбербанк'],
#  979: ['функция', 'деньга', 'какая смысл', 'сумма'],
#  980: ['подвисания', 'приложение'],
#  981: ['сумма',
#   'программисты',
#   'мотет',
#   'евровый счёт',
#   'деньга',
#   'alexey',
#   'умолчание',
#   'оплата',
#   'евро',
#   'граница',
#   'момент',
#   'приличный процент',
#   'доллары',
#   'единственная проблема',
#   'небольшая работа',
#   '2 раза'],
#  982: ['сбербанк', 'удобное приложение'],
#  983: ['секунда',
#   'последнее обновление',
#   'иконка приложения',
#   'приложение',
#   'айфон',
#   'клик',
#   'логотип сбербанка'],
#  984: ['обновление баланса'],
#  985: ['ситуация',
#   'вклады',
#   'приложение лагает',
#   'проблема',
#   'сбербанк',
#   'последние 4 дня',
#   'какие-то интересующие вопросы',
#   '1 раз',
#   '12 попытки',
#   'айос',
#   '21 час',
#   'переводы/платежи',
#   'режим',
#   'ожидание',
#   'приложение',
#   'все 4 дня',
#   'память',
#   'плюсы',
#   'интернет',
#   'многое другое минусы',
#   'заморочки'],
#  986: ['вход', 'сии поры', 'faceid', 'приложение'],
#  987: ['последнее обновление',
#   'некоторые трудность',
#   'вкладка',
#   'трудность',
#   'добрый день',
#   'счёт',
#   'вклады'],
#  988: ['мои интернет', 'сотовые данные', 'сбербанк', 'приложение'],
#  989: ['горизонтальная ориентация',
#   'переводы',
#   'самый низ',
#   'планшет',
#   'система',
#   'приложение',
#   'курьерская доставка карт',
#   'человек',
#   'самый большое банка россии',
#   'такая перевод',
#   'ipad',
#   'люди',
#   'телефон',
#   'замечания',
#   'быстрые платежи'],
#  990: ['отличное приложение', 'поиск', 'история операций'],
#  991: ['приложение', 'сбер', 'последнее время', 'счёт', 'телефон'],
#  992: ['4 раза',
#   'ответ оператора',
#   'вопросы',
#   'бесполезное приложение',
#   'поддержка',
#   'номер',
#   'чат',
#   '20 минут',
#   'данный момент',
#   'бот'],
#  993: ['размер приложения', 'вес приложения'],
#  994: ['новая карта', 'крым', 'приложение', 'какая-то сбой', 'операция'],
#  995: ['андрей',
#   'отображение',
#   'колесо',
#   'соответствующий раздел',
#   'поиск',
#   'счёт',
#   'стрелки',
#   'косяк',
#   'открытые вклады'],
#  996: ['порядок',
#   'face id',
#   'приложение',
#   'вход',
#   'запуск приложения',
#   'интернет',
#   'ввод пароля',
#   'первое раза',
#   'кеш'],
#  997: ['комиссия', 'ваша комиссия'],
#  998: ['соединение',
#   'телефон iphone xs',
#   'приложение',
#   'проблема',
#   'вход',
#   'интернет',
#   'долгий вход'],
#  999: ['iphone', 'ipad', 'обновление', 'ipad-версия приложения', 'версия'],
#  1000: ['вход', 'приложение'],
#  1001: ['фотка', 'половина экрана', 'приложение', 'вход', 'экран', 'лагать'],
#  1003: ['сбой', 'жалоба', 'вклад', 'раз', 'приложение'],
#  1004: ['сбол',
#   'фиги',
#   'зависание',
#   'приложение',
#   'неделя',
#   'вай-фай',
#   'интернет',
#   'чертовый вай-фай',
#   'объём'],
#  1005: ['новое', 'обновление', 'личный кабинет'],
#  1006: ['телефон iphone xs', 'раз', 'список карт', 'приложение'],
#  1007: ['комиссия',
#   'месяц',
#   'перевод',
#   'сбербанк',
#   'вышка',
#   'ребята',
#   'переведа'],
#  1008: ['большое экран',
#   'главное',
#   'возможность',
#   'карточка',
#   'ребята',
#   'экран',
#   'телефон'],
#  1009: ['последний вариант интерфейса',
#   'белый шрифт',
#   'ужас',
#   'пара секунд',
#   'одна куча',
#   'поиск',
#   'удобство',
#   'каждая нужная кнопка'],
#  1010: ['просьба',
#   'молодцы',
#   'неделя',
#   'автоперевод',
#   'функция автоперевода',
#   'минимальный шаг'],
#  1011: ['функция',
#   'другое банка',
#   'такая функция',
#   'приложение',
#   'номер карты',
#   'карта',
#   'сбербанк',
#   'пополнение',
#   'многие приложения'],
#  1012: ['звонок', 'подтверждение операций', 'автоплатежи', 'изменение'],
#  1013: ['полное фиаско', 'обновление', 'последнее обновление'],
#  1014: ['хиросима глаза',
#   'нормальная тёмная тема',
#   'тёмная тема',
#   'приложение',
#   'функционал',
#   'серый скины',
#   'проблема'],
#  ...}

# %%
data.iloc[3][REVIEW_COL]
# Out:
# 'Не могу скачать так как требует подключения Wi-fi'

# %% [markdown]
# ## TextRank Gensim

# %%
from gensim.summarization import keywords
import re

# %%
reviews_keywords_gensim = {}
for i in tqdm(data.index):
    reviews_keywords_gensim[i] = []
    text = data.iloc[i][REVIEW_COL]
    lemm = []
    for word in text.split(u' '):
        if re.match(u'([^a-zа-яe ̈]+)', word):
            word = morph.parse(word)[0].normal_form
        lemm.append(word)
    text = ' '.join(lemm)
    reviews_keywords_gensim[i]+=keywords(text).split('\n')
    text = data.iloc[i][TITLE_COL]
    lemm = []
    for word in text.split(u' '):
        if re.match(u'([^a-zа-яe ̈]+)', word):
            word = morph.parse(word)[0].normal_form
            lemm.append(word)
    text = ' '.join(lemm)
    reviews_keywords_gensim[i]+=keywords(text).split('\n')
#     reviews_keywords_gensim[i] = list(set(reviews_keywords_gensim[i]))
# Out:
# 100%|██████████| 11584/11584 [00:28<00:00, 407.65it/s]

# %%
reviews_keywords_gensim
# Out:
# {0: ['стала', ''],
#  1: ['пытаюсь', ''],
#  2: ['день', 'функция', ''],
#  3: ['требует', ''],
#  4: ['через', ''],
#  5: ['деньги',
#   'связаться',
#   'что',
#   'крупном банке',
#   'как',
#   'приоритетная',
#   'проблему',
#   ''],
#  6: ['дико', ''],
#  7: ['карту',
#   'внутри банка',
#   'банки',
#   'базе',
#   'доставка',
#   'переводы',
#   'тем',
#   'вид',
#   'ребят',
#   ''],
#  8: ['почему', ''],
#  9: ['', ''],
#  10: ['раньше', 'время половину', ''],
#  11: ['супер', ''],
#  12: ['', ''],
#  13: ['как', 'без', ''],
#  14: ['быстрое', ''],
#  15: ['интерфеисе', 'время', ''],
#  16: ['быть', ''],
#  17: ['остаток', 'бюджет', ''],
#  18: ['батарея', ''],
#  19: ['онлаин', ''],
#  20: ['', ''],
#  21: ['само', 'один', ''],
#  22: ['переводить', 'как', 'только', 'тыс', 'бесчеловечныи', 'сосать', ''],
#  23: ['работает', 'телефоне', ''],
#  24: ['ежемесячнои', 'этим', 'банковское', 'своего', 'повторить', ''],
#  25: ['выводить', 'где', 'равно', ''],
#  26: ['тоже', 'история', 'переходов', ''],
#  27: ['', ''],
#  28: ['версия',
#   'для планшета это',
#   'буду',
#   'версии',
#   'меню',
#   'начисления',
#   'вперед',
#   'изменятся',
#   'товара',
#   'обратиться',
#   ''],
#  29: ['что', 'уже', ''],
#  30: ['приложение', 'перевел', ''],
#  31: ['это', 'день', 'что', 'видовые', ''],
#  32: ['последнего', ''],
#  33: ['сообщении',
#   'горит',
#   'программы',
#   'это',
#   'приложение',
#   'каждыи',
#   'пожалуиста',
#   'нет',
#   'обновления',
#   'прошло',
#   ''],
#  34: ['обновления', ''],
#  35: ['пример', ''],
#  36: ['совсем', ''],
#  37: ['каждыи', ''],
#  38: ['параллельными', 'появились', 'вообще', ''],
#  39: ['только', 'через чат', 'отвечают', ''],
#  40: ['внутри', ''],
#  41: ['году', 'вашего', ''],
#  42: ['приложение', ''],
#  43: ['обновлять', 'нет', ''],
#  44: ['', ''],
#  45: ['что', 'банк', 'уже', 'банковских', ''],
#  46: ['только', ''],
#  47: ['данную', 'экране', 'обновлением', ''],
#  48: ['ощущение что',
#   'сделать',
#   'там',
#   'для',
#   'спасибо',
#   'где',
#   'есть',
#   'еще',
#   'истории',
#   'банк',
#   'вылетать',
#   'все',
#   'нет зачем',
#   'страницу выносить',
#   'ненужнои',
#   'минут пока ваше приложение',
#   'она',
#   'бесящую',
#   'многим',
#   'загружается',
#   'больше',
#   ''],
#  49: ['экране', 'темнои', 'переведено', 'зеленыи экран', 'какого', ''],
#  50: ['удобное', ''],
#  51: ['', ''],
#  52: ['как', ''],
#  53: ['', ''],
#  54: ['тысяч', 'нужно срочно', 'личного', ''],
#  55: ['увеличьте', 'месячных', 'переводы', 'между', ''],
#  56: ['разработчик', 'банк', 'хотят', ''],
#  57: ['все', 'исправить', ''],
#  58: ['так', 'весит', ''],
#  59: ['рекламои', 'скоро', ''],
#  60: ['что', ''],
#  61: ['банк', 'банке', 'узкому', ''],
#  62: ['часовои', 'пожалуиста', ''],
#  63: ['', ''],
#  64: ['проще', ''],
#  65: ['', ''],
#  66: ['скачать', ''],
#  67: ['', ''],
#  68: ['при', 'услуги', ''],
#  69: ['обновления', 'можно', ''],
#  70: ['бесконтактная', ''],
#  71: ['сам', 'это', 'что', ''],
#  72: ['', ''],
#  73: ['смс',
#   'ответ',
#   'только',
#   'интернет',
#   'устал',
#   'хламом',
#   'приложение',
#   'посчитать',
#   'быстро',
#   ''],
#  74: ['обновление', ''],
#  75: ['', ''],
#  76: ['для',
#   'приложения',
#   'разделах',
#   'связи',
#   'store',
#   'загрузить',
#   'app',
#   'программа',
#   'снятия',
#   ''],
#  77: ['онлаин', 'нужно', ''],
#  78: ['перевод', 'выполнить', 'предусмотрено', ''],
#  79: ['день', ''],
#  80: ['тратить', 'снова', 'обновленныи', 'вашим', 'программеров', ''],
#  81: ['было', 'историю', ''],
#  82: ['существенныи',
#   'замечательное',
#   'иныи',
#   'иметь',
#   'развернуть',
#   'зачислении лаконичное',
#   ''],
#  83: ['просто', 'пол', 'обновить прямо перед', 'версию', 'приложение', ''],
#  84: ['вопрос', 'оказалось надо', 'поэтому', 'сквозь', 'очень', ''],
#  85: ['карты', 'просто', 'желтыи', ''],
#  86: ['или', 'онлаин что', 'банк', 'стало', ''],
#  87: ['отображается', ''],
#  88: ['', ''],
#  89: ['пропали', ''],
#  90: ['несколько', 'пожалуиста', 'ios', 'деле', 'должен быть', 'iphone', ''],
#  91: ['ваи', 'сеть', 'через', 'нету', ''],
#  92: ['переводы',
#   'граждан оштрафовать',
#   'банков',
#   'это',
#   'получать',
#   'примитивнои',
#   'пришла',
#   'этот',
#   ''],
#  93: ['', ''],
#  94: ['apple', ''],
#  95: ['вам',
#   'это',
#   'все',
#   'будут',
#   'главное',
#   'ваш',
#   'они',
#   'надо',
#   'платных',
#   'услуг',
#   'через',
#   'нет',
#   ''],
#  96: ['намного', 'новая', 'зрения', ''],
#  97: ['скрывать', ''],
#  98: ['сделать', 'как', 'обновлением они прям', 'компании', ''],
#  99: ['', ''],
#  100: ['приложение', 'общии', 'искать', 'перед', ''],
#  101: ['так', 'вот', ''],
#  102: ['без', ''],
#  103: ['платежи', 'нет куда', ''],
#  104: ['обновления', ''],
#  105: ['дизаин', 'новыи', 'метла', 'стилистику', 'подходящие', 'такои', ''],
#  106: ['много', 'установка', 'все', ''],
#  107: ['функцию', ''],
#  108: ['приложения',
#   'более',
#   'раз',
#   'ситуации',
#   'которые',
#   'люди',
#   'через',
#   'сбербанк',
#   'один',
#   'этого',
#   'пункт',
#   'прошивке',
#   'совсем',
#   'дно',
#   'косяков',
#   'зла',
#   'может',
#   'ваши банкоматы',
#   'либо',
#   'так',
#   'перечислять',
#   'мне',
#   'других',
#   'банков',
#   'этаже торгового',
#   'постучали',
#   'снова',
#   'плавно',
#   'друга',
#   'сделать',
#   'сами',
#   'приложение',
#   'при',
#   ''],
#  109: ['карты',
#   'это',
#   'уже',
#   'почему',
#   'дизаин карт',
#   'приложение',
#   'даже',
#   'такое',
#   'его',
#   'сделать',
#   'что',
#   'вас как',
#   'или',
#   'пользователи',
#   'wallet',
#   'этот',
#   'карте',
#   'больше',
#   'такая',
#   'реализация',
#   'шаблонов',
#   'прошу',
#   'принтом',
#   'образом',
#   'выглядящии',
#   'вашеи',
#   'банка',
#   'надпись',
#   'такои',
#   'кредитная',
#   'возможность',
#   'приложения',
#   'вам',
#   'минималистично',
#   'аляпистых',
#   'кто',
#   'ужасные',
#   ''],
#  110: ['убрать', ''],
#  111: ['весом', ''],
#  112: ['', ''],
#  113: ['сбербанк', 'деньги', ''],
#  114: ['показать',
#   'мои',
#   'пока',
#   'даунское приложение',
#   'приложения',
#   'неужели',
#   'зато',
#   'смешно',
#   ''],
#  115: ['переставлять', 'обновляться', ''],
#  116: ['таких', ''],
#  117: ['приложение',
#   'мне',
#   'было',
#   'ничего',
#   'купить',
#   'после',
#   'это мешает пользоваться',
#   'несколько',
#   'отключить',
#   'нашел',
#   'кнопка',
#   'помоику',
#   'банковских',
#   'под',
#   ''],
#  118: ['', ''],
#  119: ['передает привет', ''],
#  120: ['сбп так', ''],
#  121: ['обновляется', 'рекомендации', ''],
#  122: ['', ''],
#  123: ['просто', 'последнего', 'когда', ''],
#  124: ['как', 'обновления', 'приложение', 'стандарт', 'пытается взлететь', ''],
#  125: ['висеть', 'раз', 'так', ''],
#  126: ['', ''],
#  127: ['самыи', 'россии', 'осторожны', 'других', ''],
#  128: ['просто', 'застрелиться', 'приложения', 'хлам', 'это', ''],
#  129: ['второи', ''],
#  130: ['информацию', 'уведомлении', 'списка', ''],
#  131: ['параша', ''],
#  132: ['дело', 'настроение', 'любые', 'именно', ''],
#  133: ['одноразовыи', ''],
#  134: ['', ''],
#  135: ['', ''],
#  136: ['разработчики', 'деньги', 'весило', 'что', ''],
#  137: ['банки', 'своих', ''],
#  138: ['память', 'кнопку', 'только', 'придется', 'приложение', ''],
#  139: ['оно', 'могу', ''],
#  140: ['имя',
#   'онлаин',
#   'мне',
#   'сбербанк',
#   'видно',
#   'это',
#   'программе',
#   'появляются',
#   ''],
#  141: ['', ''],
#  142: ['приложение', 'тему отлично', 'сеичас', ''],
#  143: ['чтобы',
#   'что',
#   'нужно',
#   'вообще',
#   'свои',
#   'туда',
#   'разделах',
#   'сопоставлять',
#   'потом получать истинные',
#   ''],
#  144: ['чтобы',
#   'пуш',
#   'что',
#   'остальное',
#   'раз',
#   'уведомления',
#   'бесплатные',
#   'банке',
#   'ответ',
#   'очередного',
#   'теперь',
#   'подключить',
#   'уведомление',
#   ''],
#  145: ['пожалуиста', ''],
#  146: ['сбербанк', 'теперь', 'номер', 'нет времени', 'прям бред', 'звоню', ''],
#  147: ['пришло', 'что', 'пуш', 'бог', ''],
#  148: ['выглядеть', ''],
#  149: ['', ''],
#  150: ['мое сердце', ''],
#  151: ['несовершеннолетних', 'открытием', ''],
#  152: ['больше', ''],
#  153: ['обратно', 'исчезла', ''],
#  154: ['кнопка', 'экран теперь', 'истории', ''],
#  155: ['при', ''],
#  156: ['списания', 'помощник', 'ничего', 'баланс', ''],
#  157: ['поместить', 'все', 'много', ''],
#  158: ['читать', 'отключить эту', ''],
#  159: ['нужно', 'идет', 'сберегательныи', ''],
#  160: ['', ''],
#  161: ['они', 'можно', ''],
#  162: ['только', 'после', 'точнее', 'обновления', 'все просто', ''],
#  163: ['сектора', 'условии', 'внутри', ''],
#  164: ['привыкать', 'ваш', ''],
#  165: ['что', 'его', 'еще', ''],
#  166: ['работает', ''],
#  167: ['страница', 'есть', ''],
#  168: ['более', ''],
#  169: ['все', ''],
#  170: ['очень', 'для', 'обратите', 'отзыв', 'тихии', 'как', 'хорошо', ''],
#  171: ['', ''],
#  172: ['убогии', 'навязывание', ''],
#  173: ['всегда', 'чтобы', 'уверен', ''],
#  174: ['отключить',
#   'что это',
#   'разработчики',
#   'уважаемыи',
#   'пожалуиста этим',
#   'всякои',
#   'стало',
#   ''],
#  175: ['баланс', 'делать', 'можно', ''],
#  176: ['', ''],
#  177: ['банк долгим', 'пользоваться', ''],
#  178: ['что', 'платежи', 'это', ''],
#  179: ['больше', ''],
#  180: ['получить', 'нет никому', ''],
#  181: ['прекрасно', 'хотя', ''],
#  182: ['для', 'или', 'агрегатор', 'ваши', ''],
#  183: ['можно было отключить', ''],
#  184: ['чтобы',
#   'как это',
#   'фильтр',
#   'история',
#   'все',
#   'надо',
#   'операции',
#   'перегруженным',
#   'глазами',
#   'контент',
#   ''],
#  185: ['деньги', 'это', ''],
#  186: ['нет', 'экране под', 'все', ''],
#  187: ['все', 'еще полчаса', 'добавлять картинки при', ''],
#  188: ['посмотреть',
#   'уже',
#   'бюджета',
#   'было',
#   'крупное',
#   'месяца',
#   'поправить',
#   'выпустили',
#   'версии',
#   ''],
#  189: ['таких', 'один дело', 'как', 'услугах', ''],
#  190: ['это можно', 'старые', ''],
#  191: ['кроме', ''],
#  192: ['', ''],
#  193: ['после', ''],
#  194: ['последнего', ''],
#  195: ['уведомления', ''],
#  196: ['', ''],
#  197: ['суток', 'можныи', ''],
#  198: ['радует', ''],
#  199: ['нет', 'положить деньги', 'заити', 'последнего', ''],
#  200: ['что', 'приложение', 'через', 'ios', 'очень', 'нет', ''],
#  201: ['тишина', ''],
#  202: ['намного', 'при входе', ''],
#  203: ['карты', 'нажимаешь', 'что', ''],
#  204: ['прямоугольника',
#   'два',
#   'как так',
#   'еще',
#   'экрана занимают',
#   'деиствия',
#   ''],
#  205: ['раз', 'аифон', 'тормозить', 'обновления', ''],
#  206: ['', ''],
#  207: ['быстрых', 'техподдержка', ''],
#  208: ['удобное', ''],
#  209: ['мне', 'программа весит', 'карты', ''],
#  210: ['там',
#   'говн',
#   'требует',
#   'новое приложение',
#   'аифон',
#   'пришлось восстановить',
#   'кроме',
#   'доступе',
#   ''],
#  211: ['теперь',
#   'для',
#   'или',
#   'инстаграмм',
#   'было',
#   'превращаете',
#   'взялись',
#   'обновлении',
#   ''],
#  212: ['рекомендации', 'подвижные', 'весь', 'ваши', 'тот', ''],
#  213: ['раз', 'обратно', 'через', ''],
#  214: ['интерфеису все', ''],
#  215: ['присылает', 'нормально', 'вкладов', ''],
#  216: ['после', 'push', 'виджет', 'все', 'некорректно', 'кроме', ''],
#  217: ['вашего', ''],
#  218: ['', ''],
#  219: ['одна', 'суммы', ''],
#  220: ['либо',
#   'точки',
#   'интерфеис',
#   'экран',
#   'висит',
#   'неудобно',
#   'восхищалась',
#   'сбербанк',
#   'верните',
#   'заново',
#   ''],
#  221: ['исправите', 'карту', ''],
#  222: ['', ''],
#  223: ['обновление', 'молодцы', ''],
#  224: ['вижу', 'раз', 'или', ''],
#  225: ['обновления', ''],
#  226: ['чтобы', 'виде ужасно', 'предложения', ''],
#  227: ['вам', 'без', 'приложении', ''],
#  228: ['смс', 'платить', 'карты', 'этого', 'как', 'каждыи', ''],
#  229: ['программа', 'перевести', ''],
#  230: ['жкх', ''],
#  231: ['было',
#   'его',
#   'использовать',
#   'знак',
#   'вернули',
#   'названиях',
#   'криво',
#   ''],
#  232: ['искать', 'раньше', ''],
#  233: ['gui', ''],
#  234: ['что', 'возврат', 'если', 'понятно бывает', 'нарекании', ''],
#  235: ['после', 'это', 'большая', 'просто', ''],
#  236: ['что',
#   'россиян',
#   'почему',
#   'это приложение',
#   'можно',
#   'реквизитов',
#   'греф нужно давно',
#   'голубои',
#   'свои',
#   'приложении',
#   'деньги',
#   'счет',
#   'как',
#   'технологии',
#   'все',
#   'руб чтобы',
#   'позорище',
#   'например',
#   'операции',
#   'онлаин',
#   'скоро',
#   'тебя постоянно',
#   'сбера',
#   'нет',
#   'платежа только при',
#   'невозможно',
#   'комиссия',
#   'обираешь',
#   'меню',
#   'грефа',
#   'здесь',
#   'эту',
#   'подтверждающего',
#   'комиссиеи',
#   'настоящии',
#   'после',
#   'себе',
#   'твои',
#   'кто',
#   'оплатить',
#   'банка',
#   'карты',
#   'существа подписывающие',
#   'клоунское подобие',
#   'отчитываться перед',
#   'становится',
#   'узнать',
#   'если',
#   'кривее',
#   'такои',
#   'абрамовои',
#   ''],
#  237: ['', ''],
#  238: ['скачать', ''],
#  239: ['нужно',
#   'снимать',
#   'держать',
#   'более',
#   'регионе подписка свои',
#   'теперь',
#   'без',
#   ''],
#  240: ['меня', 'ваши', 'сбербанк', 'это', 'они', ''],
#  241: ['', ''],
#  242: ['всегда', 'немного', ''],
#  243: ['', ''],
#  244: ['карты',
#   'при',
#   'заблокированные',
#   'карт',
#   'для',
#   'что',
#   'мне',
#   'даже',
#   'неудобно',
#   'день',
#   'свои персональных',
#   'все',
#   'этом',
#   'вдруг',
#   'отключенную',
#   'приложения',
#   ''],
#  245: ['пополнение счета', 'новои', 'еще', ''],
#  246: ['что нет', 'пытаться', ''],
#  247: ['чаты', 'менее', ''],
#  248: ['возможностями', 'вижу', 'под', 'вкладки', 'при', ''],
#  249: ['', ''],
#  250: ['приложение', 'тоже', 'ничего', 'аифон', 'загружаться', ''],
#  251: ['баланса', ''],
#  252: ['', ''],
#  253: ['цифра', 'диалоги', 'когда открываю', 'исправить', ''],
#  254: ['все', ''],
#  255: ['нет', ''],
#  256: ['стало', 'иметь', 'приходится ждать', ''],
#  257: ['', ''],
#  258: ['цветовую', 'зеленыи', 'других', 'включения', ''],
#  259: ['очень', 'быстрыи', 'под', 'свои', 'дело', 'классное', 'каждыи', ''],
#  260: ['день', 'восхитительные', 'вернуть', ''],
#  261: ['посмотреть', ''],
#  262: ['здорово банк полностью', 'свои', ''],
#  263: ['', ''],
#  264: ['рекламное', 'агенство', 'многие', 'приложение', 'очень', ''],
#  265: ['баланс', 'хорошее', 'осталось', 'переводишь', ''],
#  266: ['иметь', 'день', ''],
#  267: ['темную', 'светлое', ''],
#  268: ['что это',
#   'лимит',
#   'весь',
#   'человек',
#   'уже',
#   'комиссию',
#   'если',
#   'пятая точка',
#   'бешанные',
#   'как',
#   'пользователеи',
#   'какому',
#   ''],
#  269: ['разберется', 'лучше', ''],
#  270: ['уже', 'непрочитанное', ''],
#  271: ['что',
#   'так как',
#   'сформировать',
#   'выписку',
#   'недавно',
#   'банках',
#   'понятное',
#   'при',
#   'одно досадное',
#   'приложение',
#   'хорошее',
#   'после долгих',
#   'сложностеи',
#   ''],
#  272: ['отключить', 'напрягает', 'хочу', 'полностью', 'там', ''],
#  273: ['свои', 'расчитывать', 'оплатить', 'добавить кнопку', ''],
#  274: ['были', 'копится', 'ненужного', 'при', ''],
#  275: ['все', 'еда', ''],
#  276: ['взгляд идея',
#   'чего',
#   'подобного молодец',
#   'мгновеннои',
#   'адекватную',
#   'неплохо',
#   ''],
#  277: ['текст', 'jpeg', 'сохранить', 'удобно', 'зачем', ''],
#  278: ['читать', 'каждыи', 'почти', 'написания постов', 'раз', ''],
#  279: ['эти', 'возможность', 'все', ''],
#  280: ['отвратительныи', 'еще', 'банк', ''],
#  281: ['плане', 'баланс', 'сколько', 'перевести', 'какая', ''],
#  282: ['причине', 'хочу', 'говорил', 'почему', 'нет', 'ничего', ''],
#  283: ['брать', ''],
#  284: ['отмечаться', ''],
#  285: ['последнего', 'cvc', 'номер', ''],
#  286: ['', ''],
#  287: ['изменить', ''],
#  288: ['новым', 'больше', ''],
#  289: ['забавное',
#   'прогнить',
#   'наличныи',
#   'зло',
#   'навязывание',
#   'вас',
#   'балла',
#   ''],
#  290: ['версии', ''],
#  291: ['что', 'обновила', 'дажа', 'искренне', ''],
#  292: ['бизнесменов пользуются', ''],
#  293: ['оптимизированные', ''],
#  294: ['хоть', 'региона', ''],
#  295: ['', ''],
#  296: ['стати', 'тварь', ''],
#  297: ['работала', ''],
#  298: ['перечисляет', ''],
#  299: ['лагает', ''],
#  300: ['максимально', 'все сделано', ''],
#  301: ['', ''],
#  302: ['реклама', 'push', ''],
#  303: ['башенные', 'вам', 'комиссию', ''],
#  304: ['операции', 'иди', 'аплпеи', 'можно', 'решать', 'услуга', ''],
#  305: ['последнего', 'push', 'вкладок', ''],
#  306: ['отпугивать', 'деньги', ''],
#  307: ['июля',
#   'отзывы',
#   'ноль',
#   'свету',
#   'скрины',
#   'тема',
#   'что',
#   'проснитесь',
#   'исправить',
#   'ситуацию',
#   'прочитать',
#   'полосу',
#   'поразительная',
#   'тему',
#   'уже',
#   'именно',
#   'при',
#   ''],
#  308: ['теперь', 'металлы', 'обновление', 'писать', 'углах', 'только', ''],
#  309: ['работает', 'один', 'равно', ''],
#  310: ['что сбп',
#   'все',
#   'тоже',
#   'без',
#   'экран при этом',
#   'сами',
#   'очень',
#   'фичу',
#   ''],
#  311: ['втб',
#   'что',
#   'снять',
#   'вопрос',
#   'почему',
#   'деньги',
#   'комиссии',
#   'решали',
#   'как сняли',
#   'друга',
#   'денег',
#   'такие',
#   ''],
#  312: ['штраф', 'последнего', ''],
#  313: ['обновлении это', 'про', ''],
#  314: ['уже', 'писать нет', 'постояннои', 'проблемои', ''],
#  315: ['звук', 'возможность', 'программа все', ''],
#  316: ['уже глаз', 'пропадает', 'совершить', 'зачем', 'сеичас', 'все', ''],
#  317: ['проследить', 'средств', ''],
#  318: ['хранить', 'вынужденно', ''],
#  319: ['мне сделать', ''],
#  320: ['оплатить', 'скидка', 'обновления', 'должно', ''],
#  321: ['вопрос', 'осталось', 'только', 'аналогичныи', ''],
#  322: ['', ''],
#  323: ['как', ''],
#  324: ['тупои', 'суть', 'проблемы', ''],
#  325: ['все', ''],
#  326: ['перечисления', 'очень', ''],
#  327: ['этим', ''],
#  328: ['', ''],
#  329: ['нет',
#   'когда',
#   'данных',
#   'безопасности',
#   'отрицательном',
#   'везде',
#   'которые',
#   'откровенное',
#   'вопросов',
#   'все',
#   'вопросы',
#   'ситуация',
#   'звонок',
#   'максимально',
#   'как',
#   ''],
#  330: ['меню', 'нужно', 'зачем', 'повторить', 'оставить', 'раз', 'версии', ''],
#  331: ['смс',
#   'сбербанк',
#   'что',
#   'все',
#   'пуш',
#   'почему',
#   'выбор',
#   'зарплатные',
#   'операторам',
#   'сотовои',
#   'написали',
#   'мне',
#   'положительныи',
#   'версия',
#   'приличную',
#   ''],
#  332: ['кредитного',
#   'его',
#   'завершить',
#   'этого',
#   'номера',
#   'потенциал',
#   'неуместным',
#   'расчета',
#   ''],
#  333: ['которую',
#   'для',
#   'которыи',
#   'ага',
#   'точки',
#   'пользователеи',
#   'будем',
#   ''],
#  334: ['для',
#   'что',
#   'как',
#   'уже',
#   'счет',
#   'зачисление',
#   'платежи',
#   'кучу',
#   'красивое',
#   'происходит',
#   'просто',
#   'вкладу',
#   'списания несколько',
#   'еще',
#   'сотку',
#   'вам',
#   'высвечиваться',
#   'вклада',
#   ''],
#  335: ['через',
#   'все',
#   'web',
#   'потому что',
#   'осталось',
#   'коммерческих',
#   'перевыпущенную',
#   'сил',
#   'это только',
#   'смс',
#   'мес',
#   'push',
#   'для',
#   'другого банка',
#   'наверное ориентируется',
#   'говориться дьявол',
#   ''],
#  336: ['долго', 'неудобно', ''],
#  337: ['', ''],
#  338: ['чтоли', ''],
#  339: ['пропали', ''],
#  340: ['работает', 'это', ''],
#  341: ['', ''],
#  342: ['это', 'посылать', 'добавить', ''],
#  343: ['уведомления', ''],
#  344: ['', ''],
#  345: ['чека', 'совсем', ''],
#  346: ['время приложение работает', 'времени', 'приходится', ''],
#  347: ['баланс', ''],
#  348: ['', ''],
#  349: ['', ''],
#  350: ['все', ''],
#  351: ['банк',
#   'другому пользователю',
#   'тоже выглядит',
#   'выключили',
#   'днищем',
#   'сбер',
#   ''],
#  352: ['слов', 'нет', ''],
#  353: ['совершать',
#   'деньги',
#   'никакого',
#   'приходиться',
#   'поддержка обещали',
#   'оплату',
#   'месяц',
#   ''],
#  354: ['', ''],
#  355: ['имеется', ''],
#  356: ['приватным', 'баланс', 'варианта', ''],
#  357: ['нужны', ''],
#  358: ['', ''],
#  359: ['закрыть', ''],
#  360: ['ради',
#   'максимально',
#   'опыт',
#   'быстрыи',
#   'интерфеис подключения',
#   'вызвать',
#   ''],
#  361: ['ждать', 'перевести', 'если', 'своими', 'обновления', ''],
#  362: ['', ''],
#  363: ['сделали', ''],
#  364: ['полнеишая', ''],
#  365: ['просто', 'делаться', 'инфа', 'выписку', ''],
#  366: ['слишком',
#   'спасибо',
#   'банально нельзя',
#   'хотел поставить',
#   'брать',
#   ''],
#  367: ['обновления', 'сразу это', ''],
#  368: ['все', 'теперь', ''],
#  369: ['уведомления', 'сторис', ''],
#  370: ['приложение', 'появилась', 'при', 'проблемои', ''],
#  371: ['реквизиты', ''],
#  372: ['меня',
#   'для',
#   'что',
#   'спасибо',
#   'партнера',
#   'банк',
#   'услуг после',
#   'даже ругаться',
#   'тсп',
#   'это',
#   'начисляете',
#   ''],
#  373: ['иногда',
#   'обновите',
#   'кредиты писать',
#   'нужно',
#   'раз',
#   'начальная',
#   'долго',
#   ''],
#  374: ['нет', 'добавить', ''],
#  375: ['приложение', 'очень', ''],
#  376: ['банк', 'месяц', 'порядке', 'или', ''],
#  377: ['как содрать', 'должна', ''],
#  378: ['', ''],
#  379: ['уведомлении без', ''],
#  380: ['данныи', 'частичном погашение', ''],
#  381: ['нужно', 'нельзя', ''],
#  382: ['приложение',
#   'заказать',
#   'было',
#   'надо',
#   'редактировать удалять',
#   'некоторым категориям',
#   ''],
#  383: ['для', 'стать', 'это', 'удобства', 'только', 'ответ', ''],
#  384: ['последнего', 'интерфеис', 'кредитах', 'новыи', ''],
#  385: ['', ''],
#  386: ['отображаться', 'кредите', ''],
#  387: ['уведомления', ''],
#  388: ['сбербанк берет', ''],
#  389: ['приложение', 'проблема возникла после', ''],
#  390: ['соединить', 'жалкии попытка', 'линии', ''],
#  391: ['перебор', ''],
#  392: ['онлаин', 'тип', ''],
#  393: ['вопросы', ''],
#  394: ['были', 'всегда', 'последнего обновления появился', 'cvc', ''],
#  395: ['теме градиенты', 'далее', 'потом', ''],
#  396: ['', ''],
#  397: ['лучшее', 'кластера', 'над', ''],
#  398: ['написании номера', ''],
#  399: ['посмотреть', 'только', 'день', ''],
#  400: ['ежемесячным платежам', ''],
#  401: ['желаю', ''],
#  402: ['сеть', 'отключение этих', ''],
#  403: ['постоянно', ''],
#  404: ['', ''],
#  405: ['ощущение', 'запуск', 'над', 'стал', 'вообще', ''],
#  406: ['все', 'поменять', 'открываться', 'скачиваться', ''],
#  407: ['вообще прошу', ''],
#  408: ['это', 'стало', ''],
#  409: ['', ''],
#  410: ['уже',
#   'раз',
#   'тема',
#   'если',
#   'художников постоянно',
#   'звука',
#   'великое',
#   ''],
#  411: ['приложение', 'функциональное', ''],
#  412: ['все', ''],
#  413: ['они',
#   'только',
#   'наконец',
#   'раз',
#   'благо',
#   'которыи',
#   'что',
#   'минимальныи',
#   'снимаю',
#   ''],
#  414: ['пользователеи', 'отлично всегда', 'неплохо', ''],
#  415: ['хоть', ''],
#  416: ['приложение',
#   'все',
#   'при',
#   'помочь',
#   'верните',
#   'операторов',
#   'работы',
#   'мало',
#   ''],
#  417: ['меня', ''],
#  418: ['баланс', 'включено', ''],
#  419: ['уже', 'надо', 'версия', ''],
#  420: ['', ''],
#  421: ['провести', 'приложение', 'его', ''],
#  422: ['', ''],
#  423: ['услуг', ''],
#  424: ['последнего', ''],
#  425: ['последнего обновления', ''],
#  426: ['последнего', 'просто', ''],
#  427: ['чтобы', 'интернета', 'предыдущую', 'нет', 'версию', ''],
#  428: ['', ''],
#  429: ['скрыть', 'бессмысленныи', 'глаза', 'маркетинг', 'при', 'треть', ''],
#  430: ['наше', ''],
#  431: ['показывает', ''],
#  432: ['перестало', 'неприятная', ''],
#  433: ['', ''],
#  434: ['push', 'уведомления', 'вас', 'без платных', 'это', ''],
#  435: ['хуже', 'приложение', 'сложнее', ''],
#  436: ['ваших', 'одну', 'далее', 'выполняется', 'после', ''],
#  437: ['', ''],
#  438: ['три', 'антинародныи', ''],
#  439: ['apple', ''],
#  440: ['ничего', 'все', ''],
#  441: ['операции', 'отдельно', ''],
#  442: ['при', 'хуже', ''],
#  443: ['баланс', 'виджете', 'настроики', 'виджета', ''],
#  444: ['официальныи', 'теперь', ''],
#  445: ['без',
#   'приложения',
#   'как',
#   'для',
#   'приложение',
#   'вес',
#   'так',
#   'сильно',
#   'контактов',
#   'раз',
#   'поменять',
#   'нужных',
#   'много',
#   'обновления',
#   'могу',
#   'plus это',
#   'нужно',
#   'темного',
#   'деньги',
#   'застряли',
#   'между своими',
#   'меня',
#   ''],
#  446: ['возможность', ''],
#  447: ['один', ''],
#  448: ['глаза', ''],
#  449: ['последнеи', ''],
#  450: ['', ''],
#  451: ['push', ''],
#  452: ['или',
#   'что',
#   'мои',
#   'чтобы',
#   'более',
#   'магазина',
#   'днеи',
#   'как',
#   'трех',
#   ''],
#  453: ['prime', ''],
#  454: ['хорошо', ''],
#  455: ['тихии', 'убивать', ''],
#  456: ['сделали', 'было', ''],
#  457: ['после', 'изменении', ''],
#  458: ['', ''],
#  459: ['обновляться', ''],
#  460: ['карты', 'приложение', 'деньги', 'обновления', 'уже дважды', ''],
#  461: ['что', 'версии', 'для меня', ''],
#  462: ['возможность скрыть', 'пароль просто', 'можно', ''],
#  463: ['скачать себе', ''],
#  464: ['', ''],
#  465: ['через',
#   'погрузится',
#   'кроме лишнего',
#   'которыи ничего',
#   'лишнии',
#   'зачем',
#   'мне',
#   ''],
#  466: ['нравится', ''],
#  467: ['', ''],
#  468: ['каждыи раз прокручивать', ''],
#  469: ['очень', 'приложение', ''],
#  470: ['', ''],
#  471: ['было', ''],
#  472: ['каждыи', 'приходится', ''],
#  473: ['когда', 'нормально', ''],
#  474: ['приложение', 'версии', 'просто', 'черныи', ''],
#  475: ['маленькие', ''],
#  476: ['понимать', 'это', ''],
#  477: ['восстановить', ''],
#  478: ['открыть', 'карте', 'совершить', 'исправить', ''],
#  479: ['последнего', 'виджет', ''],
#  480: ['приложуха', 'банков', ''],
#  481: ['бывает просто', 'постоянно', ''],
#  482: ['после', 'просмотра', 'история', ''],
#  483: ['после', 'баланс', 'период вручную', ''],
#  484: ['для', 'сделаите', ''],
#  485: ['ваи', 'что', 'просить', 'как', 'объем', ''],
#  486: ['чтоб', 'обновления', ''],
#  487: ['или',
#   'все',
#   'лучше',
#   'намного',
#   'карту',
#   'обновление',
#   'работало',
#   'исправить',
#   ''],
#  488: ['удобную', 'всех', 'доверял', 'все', 'сбербанку', ''],
#  489: ['открываться', ''],
#  490: ['альбомнои', 'оптимизации', ''],
#  491: ['внутри', ''],
#  492: ['вот',
#   'поимите',
#   'без',
#   'нам',
#   'боюсь',
#   'визуальная',
#   'скоро догадаются',
#   'сделать отдельно классическую',
#   ''],
#  493: ['работать', 'очень', ''],
#  494: ['приложение', 'кнопки', 'мне', 'раздражает', 'сильно', ''],
#  495: ['менять',
#   'кто',
#   'тестируете',
#   'группах',
#   'было нормальное стабильное',
#   ''],
#  496: ['', ''],
#  497: ['обновил', 'перести', ''],
#  498: ['пользоваться приложением', 'переть отличном', 'хорошо', 'другого', ''],
#  499: ['что нет',
#   'приложением',
#   'приложение',
#   'уже',
#   'источника получаю',
#   'идеально',
#   ''],
#  500: ['', ''],
#  501: ['убирать', ''],
#  502: ['обновления стало', ''],
#  503: ['приложение', 'могу', ''],
#  504: ['раздутое', ''],
#  505: ['много', 'приложение', 'налепить', 'наняли', 'так', ''],
#  506: ['сделали', ''],
#  507: ['', ''],
#  508: ['это', 'только', ''],
#  509: ['что',
#   'очень',
#   'свои',
#   'темы',
#   'так',
#   'тратить',
#   'возможность',
#   'задать',
#   'звезду',
#   'банке появилась клиентская',
#   ''],
#  510: ['', ''],
#  511: ['наличными вылетать', ''],
#  512: ['', ''],
#  513: ['всего что', 'испортить', ''],
#  514: ['можно', 'день', 'все', 'операции', 'просить', ''],
#  515: ['сумма', 'исправить', ''],
#  516: ['надо', 'это', 'денег', ''],
#  517: ['', ''],
#  518: ['раз', 'плохо', 'работать', 'без', ''],
#  519: ['преложение', ''],
#  520: ['перезагрузка', ''],
#  521: ['доступ', 'попытке', ''],
#  522: ['', ''],
#  523: ['все', 'даже', 'перевод', ''],
#  524: ['старую', ''],
#  525: ['мобильная', 'неприлично', ''],
#  526: ['день', 'история', 'сколько', 'оплатить', 'картои', 'завис', ''],
#  527: ['только', ''],
#  528: ['ноль', 'очень', 'приложение стало', 'было', ''],
#  529: ['это',
#   'что',
#   'приложение',
#   'шаблон',
#   'операции',
#   'как',
#   'карты',
#   'все',
#   'часть',
#   'если',
#   'два',
#   'шаблоны',
#   'мочь там',
#   'выписывать',
#   'история',
#   'создать',
#   'можно',
#   'пор',
#   'тобыть',
#   'при',
#   'другом',
#   'банка',
#   'регионов',
#   'сбербанк',
#   'скорее',
#   'контролировать свои',
#   'гаджета',
#   'прежде',
#   'достаточно',
#   ''],
#  530: ['версия', ''],
#  531: ['вам', 'для бабушек', ''],
#  532: ['все',
#   'очень',
#   'онлаин',
#   'сбербанк',
#   'приложения',
#   'используемых',
#   'денежные',
#   'ошибки',
#   ''],
#  533: ['что',
#   'это',
#   'прогресса',
#   'этот',
#   'геморрои',
#   'отправлять большие',
#   'считаете себя',
#   'вам жадные',
#   'карты',
#   'только',
#   ''],
#  534: ['они',
#   'баланс',
#   'сверху эти',
#   'только карты',
#   'приложение',
#   'работы',
#   'обновляется',
#   'более',
#   'подключены',
#   'виджет',
#   'больше',
#   'появится',
#   ''],
#  535: ['', ''],
#  536: ['удобное', ''],
#  537: ['маркетинге', 'рекламе', 'куча', 'алик релевантнее', ''],
#  538: ['некорректно', 'остаток', ''],
#  539: ['картои', 'так', ''],
#  540: ['возможность скрывать карточки', ''],
#  541: ['была',
#   'начинает',
#   'когда регулярно',
#   'про',
#   'начинают',
#   'кадров',
#   'приложение',
#   'лагает',
#   'быстро',
#   'так',
#   'полностью',
#   ''],
#  542: ['при', 'меня', 'статья', ''],
#  543: ['баланс', ''],
#  544: ['очень',
#   'такая важная',
#   'сервисов самого',
#   'быстрых',
#   'используемая',
#   'как',
#   ''],
#  545: ['быстрых', ''],
#  546: ['', ''],
#  547: ['услугами', ''],
#  548: ['скачать', 'что', ''],
#  549: ['один', 'это', 'сильно раздражает', ''],
#  550: ['все', 'пути', 'рябит', 'вкладок', 'вызвать', ''],
#  551: ['меня', ''],
#  552: ['обновления', ''],
#  553: ['очень', 'чувствуется', 'девушка', 'выразить', ''],
#  554: ['что', 'поколения версия', ''],
#  555: ['', ''],
#  556: ['ничего', 'после', 'неудобное', 'неудобство', 'версии все было', ''],
#  557: ['приложение', 'раз', 'много', 'невозможно', ''],
#  558: ['вернуть', ''],
#  559: ['как', 'пальца', 'приложение', 'это', ''],
#  560: ['пониже', 'все', ''],
#  561: ['нарекании', ''],
#  562: ['приложения', 'несколько', ''],
#  563: ['вообще', 'которыи', 'смс для', ''],
#  564: ['второи номер', ''],
#  565: ['только', ''],
#  566: ['сразу', 'экрана', 'возможность', 'инфа', ''],
#  567: ['переводами',
#   'внутри',
#   'чтобы',
#   'тысяча',
#   'это',
#   'сбербанк',
#   'банки перевод',
#   'последнего',
#   'неудобным',
#   'даже',
#   ''],
#  568: ['', ''],
#  569: ['помощник', 'ужасныи', 'позвонить оператору', 'тратишь время', ''],
#  570: ['', ''],
#  571: ['приложение', 'информации', 'много', ''],
#  572: ['сборы', 'подписки', 'для', 'непонятно', ''],
#  573: ['мне',
#   'еще',
#   'зачем',
#   'запилить',
#   'мусор',
#   'страдать',
#   'сторисов',
#   'операции без ваших',
#   'карты',
#   'комбаин',
#   'кнопки',
#   'чекнуть',
#   'полноты',
#   ''],
#  574: ['три', 'норм', ''],
#  575: ['показывает', ''],
#  576: ['мне', 'все', 'скрыл', 'для чего', 'обновление', ''],
#  577: ['карте', 'часть', 'было', 'для', ''],
#  578: ['стало', ''],
#  579: ['это',
#   'все',
#   'меню',
#   'быть',
#   'назоиливого',
#   'мое',
#   'коммерческими',
#   'приложения',
#   'работу',
#   'создания более',
#   'предложениями',
#   'они',
#   ''],
#  580: ['прежнии', ''],
#  581: ['обновления', ''],
#  582: ['приложение', 'проверить несколько', 'телефона', 'использовать', ''],
#  583: ['ввели', ''],
#  584: ['перестало', ''],
#  585: ['', ''],
#  586: ['уже фото', 'теперь', 'при', 'темная', ''],
#  587: ['', ''],
#  588: ['обслуживание', ''],
#  589: ['убрать', 'сестра', 'проценты', ''],
#  590: ['данные', ''],
#  591: ['как', ''],
#  592: ['это', 'клиентам', ''],
#  593: ['дизаин', 'вонючим', 'сберкота', ''],
#  594: ['', ''],
#  595: ['надеяться', 'вывести', 'последнего', 'отдельного', ''],
#  596: ['пальца пропадают', 'заказывать', 'открывается', ''],
#  597: ['кабинете услуга очень', ''],
#  598: ['если', 'очень', 'достаточно', 'такая', 'уже', 'когда', ''],
#  599: ['для', 'быстрыи', ''],
#  600: ['понравилось', ''],
#  601: ['', ''],
#  602: ['только', ''],
#  603: ['apple', ''],
#  604: ['будьте', 'надумаите решить', 'поддержки', ''],
#  605: ['свою', 'вопросов', 'банк', ''],
#  606: ['прогружается очень', 'закрывать', 'каждыи', ''],
#  607: ['', ''],
#  608: ['', ''],
#  609: ['оплатила', ''],
#  610: ['вторые', ''],
#  611: ['для', 'стать', 'оплачивать', 'теперь', 'денежные', ''],
#  612: ['что делать', 'остался без', 'тоже', 'вам ничего', ''],
#  613: ['', ''],
#  614: ['для чего',
#   'кнопки',
#   'отрисованная',
#   'было',
#   'лаконичную',
#   'писать',
#   ''],
#  615: ['что', 'несколько', ''],
#  616: ['вклад', 'отвечает', 'оператора', 'ужасное', ''],
#  617: ['обновлении', ''],
#  618: ['последнего', ''],
#  619: ['это', 'было', 'дережабль хотите', 'все', ''],
#  620: ['пенсионеров', ''],
#  621: ['наезжают', 'иногда неприятно', ''],
#  622: ['после', 'актуальная', 'пополнении', ''],
#  623: ['приложение', ''],
#  624: ['обновления', ''],
#  625: ['', ''],
#  626: ['номер карты', 'слетел', 'последнего', 'социальная карта', 'или', ''],
#  627: ['так', 'значит это', ''],
#  628: ['', ''],
#  629: ['english', ''],
#  630: ['возможность',
#   'постоянные',
#   'это',
#   'деиствие',
#   'верхние вкладки',
#   'вкладов',
#   ''],
#  631: ['', ''],
#  632: ['ниже', ''],
#  633: ['приложение', 'сегодня', 'они', 'нельзя', 'отображает', 'вообще', ''],
#  634: ['дня', ''],
#  635: ['', ''],
#  636: ['тупои', 'минут', 'равно', ''],
#  637: ['деньги', 'может', 'больше', 'которыи', ''],
#  638: ['вас', ''],
#  639: ['вам', ''],
#  640: ['время', 'месте', ''],
#  641: ['', ''],
#  642: ['оформление', ''],
#  643: ['теперь', 'карточки', ''],
#  644: ['посмотреть график', ''],
#  645: ['полностью',
#   'чтоб',
#   'когда',
#   'суммы',
#   'так',
#   'карты',
#   'приложении',
#   'карте',
#   'изменения',
#   'перевод',
#   'туда',
#   'использовать',
#   'как',
#   ''],
#  646: ['', ''],
#  647: ['', ''],
#  648: ['', ''],
#  649: ['еще', 'евы', 'переворачивать', 'установке', ''],
#  650: ['перестало', ''],
#  651: ['быть', ''],
#  652: ['тупит', ''],
#  653: ['других', 'сравнить', ''],
#  654: ['', ''],
#  655: ['просто', 'себя хорошо', ''],
#  656: ['есть', ''],
#  657: ['вернуть', 'которого', 'дает', 'пусто', ''],
#  658: ['', ''],
#  659: ['предыдущии', 'сеичас', ''],
#  660: ['старыи', 'или', 'можно выпускать', ''],
#  661: ['как', ''],
#  662: ['версия', 'обновления исчезла', ''],
#  663: ['которыи', ''],
#  664: ['части', ''],
#  665: ['', ''],
#  666: ['', ''],
#  667: ['глаза', 'версии', 'приложение', 'дизаин', 'сделали', 'белым', ''],
#  668: ['', ''],
#  669: ['дружно', 'прога', ''],
#  670: ['только',
#   'пуши',
#   'приложение',
#   'нет',
#   'все',
#   'быть',
#   'сделали',
#   'ставить',
#   'потому',
#   ''],
#  671: ['обновляется', 'плохо', ''],
#  672: ['так экран',
#   'хочу',
#   'черныи',
#   'логотип',
#   'просто полностью',
#   'равно',
#   ''],
#  673: ['негативные', 'совсем', ''],
#  674: ['функция', 'приложение', 'раионах', 'версии все пункты', ''],
#  675: ['все',
#   'что',
#   'менять',
#   'люди',
#   'пользоваться',
#   'как',
#   'вот',
#   'экран',
#   ''],
#  676: ['банк', 'хорошую', 'кредит', 'дают', 'зарплаты', ''],
#  677: ['все эти',
#   'такж хочется',
#   'использовать его для',
#   'добавить',
#   'акции',
#   'внутри',
#   'анализ',
#   'нет',
#   'так как',
#   'интерфеис',
#   'приложение',
#   'сценариях',
#   'вас',
#   'приложения',
#   'банков',
#   'спасибо',
#   'дизаин',
#   'соидет',
#   'сторис',
#   'если',
#   'сбербанк',
#   'контент',
#   'скидки',
#   'есть',
#   'торговать',
#   ''],
#  678: ['', ''],
#  679: ['', ''],
#  680: ['что', 'это', 'пополнить', 'ему', 'типо попытка', 'cvv', 'было', ''],
#  681: ['эту', 'зеленая', 'строка стала', ''],
#  682: ['', ''],
#  683: ['', ''],
#  684: ['классное', 'приложении', ''],
#  685: ['быстрых', 'переводить', 'без', 'спрятали', ''],
#  686: ['iphone', ''],
#  687: ['', ''],
#  688: ['перестало', ''],
#  689: ['надо', ''],
#  690: ['после', 'прежнии', ''],
#  691: ['ввести', 'это', 'там', 'собственных', 'введут', ''],
#  692: ['более', ''],
#  693: ['обновлении', 'интернете', ''],
#  694: ['последнии', 'вклад', ''],
#  695: ['вывести', 'последнии', ''],
#  696: ['поддержку', ''],
#  697: ['мне', 'можно было просто', ''],
#  698: ['как', 'идеальныи', ''],
#  699: ['при', 'карту', 'убрали', ''],
#  700: ['написано', 'днеи', 'вознаграждения', ''],
#  701: ['зачем', 'ваш', 'нормально', ''],
#  702: ['нет',
#   'возможность',
#   'перезапустить',
#   'раздел',
#   'окажется',
#   'досрочного закрытия',
#   'состоянии если',
#   'карту',
#   'себе',
#   'экране',
#   ''],
#  703: ['телефона', 'рекомендую этот', ''],
#  704: ['', ''],
#  705: ['сбербанка', 'теперь', ''],
#  706: ['это', ''],
#  707: ['зачем', 'последнего', 'просто', ''],
#  708: ['', ''],
#  709: ['', ''],
#  710: ['услугами', 'счетах свои', 'может', 'хула', 'так', ''],
#  711: ['все', ''],
#  712: ['все', 'очень', ''],
#  713: ['', ''],
#  714: ['очень', 'хотя', 'при', ''],
#  715: ['', ''],
#  716: ['снова', 'оно', 'уведомления', 'настроить', 'приятныи', ''],
#  717: ['либо', 'косяк', 'темнои', 'говоря', 'доп', 'версию', ''],
#  718: ['списали', 'объяснить', 'компания', 'сказать', 'классное очень', ''],
#  719: ['проблема что', 'теперь', 'тянут', 'обновление', ''],
#  720: ['только', 'история', ''],
#  721: ['', ''],
#  722: ['', ''],
#  723: ['', ''],
#  724: ['', ''],
#  725: ['это',
#   'совсем',
#   'пользователеи',
#   'онлаин',
#   'приходит',
#   'некоторое',
#   'скоро платную версию',
#   ''],
#  726: ['карта', 'супер', ''],
#  727: ['мало', ''],
#  728: ['история', ''],
#  729: ['подписаться просто', 'это нужно', 'псевдоним', ''],
#  730: ['про', 'профильных', 'везде', 'контент', 'только', ''],
#  731: ['платежеи', 'операции', ''],
#  732: ['бизнес', 'двигать', 'раньше отображалась', 'исправить', ''],
#  733: ['это', ''],
#  734: ['', ''],
#  735: ['', ''],
#  736: ['комиссии', 'так', 'каждом чихе', ''],
#  737: ['если', 'или', 'еще', 'вывести', 'был', ''],
#  738: ['спасибо', 'покупки', 'все', ''],
#  739: ['это',
#   'все',
#   'постоянно',
#   'уже',
#   'или',
#   'зачем мне',
#   'экрана',
#   'скрыть',
#   'инструменте',
#   'ярлыки',
#   'разделы',
#   'себе курс',
#   'переходят',
#   'металлы',
#   'где',
#   'plus',
#   'сделать',
#   'быть',
#   'классическии',
#   'хочу',
#   'ваши',
#   ''],
#  740: ['переставлять', ''],
#  741: ['кода так это',
#   'оплатить',
#   'или',
#   'успеть',
#   'меня',
#   'что',
#   'уже',
#   'кнопку',
#   'секунды',
#   'мне',
#   'приложение',
#   'снимок',
#   'только',
#   'бумажку',
#   'еще',
#   'каждыи раз',
#   'сколько',
#   'нормально',
#   'офигенно',
#   'если',
#   ''],
#  742: ['загрузить', 'получил', 'перед', ''],
#  743: ['мобильнои', 'экран', 'как', ''],
#  744: ['что', 'ноль', ''],
#  745: ['', ''],
#  746: ['подключить', ''],
#  747: ['выдавать', 'переустановила', ''],
#  748: ['прекратите', 'весь', ''],
#  749: ['равно', 'темои', 'черные', 'темную', ''],
#  750: ['при', 'beta', 'суммы', ''],
#  751: ['', ''],
#  752: ['топовое', ''],
#  753: ['', ''],
#  754: ['поставил', 'получить', ''],
#  755: ['только',
#   'сделаите',
#   'клик',
#   'карте',
#   'приложение',
#   'его тогда',
#   'был',
#   'для',
#   'интерфеису',
#   'заняться',
#   'делаите',
#   ''],
#  756: ['', ''],
#  757: ['саит',
#   'нельзя',
#   'уже',
#   'якобы',
#   'через',
#   'количество',
#   'тупая',
#   'приложения',
#   'меня',
#   'для',
#   'оплаты',
#   ''],
#  758: ['создавать', ''],
#  759: ['только', ''],
#  760: ['было', ''],
#  761: ['черныи', 'если развернуть', 'сверху', ''],
#  762: ['что', 'больше ста через', 'платное', 'удачное', 'спасибо', ''],
#  763: ['интерфеис', ''],
#  764: ['весь', 'сбер', 'слепящии', ''],
#  765: ['', ''],
#  766: ['дистрибутива', 'чем', 'скоро', ''],
#  767: ['слово',
#   'хотел',
#   'все реквизиты',
#   'больше',
#   'обновления появилась следующая',
#   'выходит',
#   'внесите',
#   ''],
#  768: ['истории', 'нельзя', ''],
#  769: ['через', 'бамыи', ''],
#  770: ['', ''],
#  771: ['стал', 'только хуже', 'кнопками', ''],
#  772: ['отлично', ''],
#  773: ['пользоваться', 'начнут', 'так хаотично', 'как', 'прежнии', ''],
#  774: ['оформление', ''],
#  775: ['сбербанк', 'рад', 'всех', 'вам', ''],
#  776: ['тупого', ''],
#  777: ['нужно', 'раз', 'график', ''],
#  778: ['деиствия', ''],
#  779: ['приложение работающее', 'месяц', ''],
#  780: ['нибудь', ''],
#  781: ['обновлении', 'исправить', ''],
#  782: ['возможность', ''],
#  783: ['', ''],
#  784: ['хватить', ''],
#  785: ['информации', 'убрать', ''],
#  786: ['все', 'дадут', 'возмещать', 'будете', ''],
#  787: ['телефона', 'очень', ''],
#  788: ['', ''],
#  789: ['открытии', 'пароль', 'видна', 'где', ''],
#  790: ['тема', ''],
#  791: ['все', 'теперь', 'восхищался', 'экране напихано', 'всякии', 'тут', ''],
#  792: ['', ''],
#  793: ['момент', 'предельно', 'довольна', ''],
#  794: ['после', ''],
#  795: ['темы', 'тоже была', ''],
#  796: ['постоянно', ''],
#  797: ['карты', 'долго', 'при', 'скоростнои', ''],
#  798: ['версия', 'все', 'которыи', ''],
#  799: ['language', ''],
#  800: ['просто', 'оформление поставил', ''],
#  801: ['', ''],
#  802: ['анимация', 'входе', 'непонятно', 'дело', ''],
#  803: ['мир', ''],
#  804: ['приложение', 'его', ''],
#  805: ['уведомления', 'уже', 'карьерныи', ''],
#  806: ['видное', 'ввели', 'слелаите', ''],
#  807: ['без', 'вообще', 'деньги', 'тыи', ''],
#  808: ['приложение', ''],
#  809: ['надо', 'уже', 'приложение', 'нигде', 'сделать', ''],
#  810: ['уже',
#   'рекламы',
#   'приложение',
#   'своим',
#   'при',
#   'сервиса',
#   'бесплатную',
#   'они',
#   'спамят',
#   'мусора',
#   'поиграть',
#   'этот',
#   'отп',
#   ''],
#  811: ['онлаин', ''],
#  812: ['справку', 'операции', ''],
#  813: ['они', 'неужели', 'сложно', 'возможность', ''],
#  814: ['для',
#   'сбп',
#   'банки',
#   'место',
#   'самыи',
#   'комиссии',
#   'начнете',
#   'людям',
#   'больше',
#   'может',
#   ''],
#  815: ['как',
#   'что',
#   'карту',
#   'операции',
#   'информации',
#   'скрытои',
#   'карты скрываются',
#   'попытка изменить',
#   'самыи',
#   'провести',
#   'получу',
#   'какои',
#   ''],
#  816: ['быстрыи', 'греф', 'тоже', 'обновления приложение перестало', ''],
#  817: ['чтобы', ''],
#  818: ['', ''],
#  819: ['', ''],
#  820: ['неудобно', 'вернуть', ''],
#  821: ['например', 'ведь', 'может быть', 'удобно', ''],
#  822: ['оповещения', 'приложении', 'невозможно', 'раз', ''],
#  823: ['полностью', 'ios', ''],
#  824: ['стали', ''],
#  825: ['тему', 'работу', 'приложения', 'было', 'мне', 'деиствия', 'карты', ''],
#  826: ['банков', 'крутое мобильное', ''],
#  827: ['текст', 'черныи', 'фоне', 'при', ''],
#  828: ['мне', 'год', 'обновлении', 'прошел', 'больше', 'него', ''],
#  829: ['обновления', 'отображая', 'менее', ''],
#  830: ['пишет', ''],
#  831: ['', ''],
#  832: ['это', ''],
#  833: ['все', 'без', 'возможность', ''],
#  834: ['upd',
#   'аипад',
#   'нет',
#   'воспользоваться',
#   'ровно',
#   'приложение под',
#   'это',
#   'срочно',
#   'куда надо',
#   'обновления',
#   'для',
#   'вообще',
#   ''],
#  835: ['при', ''],
#  836: ['приложение', 'минут', 'перевести', ''],
#  837: ['молодцы', ''],
#  838: ['придется закрыть', ''],
#  839: ['что', 'комиссиями', 'закрываю карты', ''],
#  840: ['обновлением', ''],
#  841: ['даже', 'карты если', 'это', ''],
#  842: ['облачным', ''],
#  843: ['они', 'день', 'произошли', ''],
#  844: ['скрытую', 'следующем', 'посмотрите', ''],
#  845: ['', ''],
#  846: ['', ''],
#  847: ['запрос', ''],
#  848: ['историю', ''],
#  849: ['', ''],
#  850: ['дизаины настоящих', ''],
#  851: ['', ''],
#  852: ['pay', 'весь', 'появится', ''],
#  853: ['свою', ''],
#  854: ['отображаться', ''],
#  855: ['перебор', ''],
#  856: ['просмотр', 'искать', ''],
#  857: ['это что',
#   'нужно',
#   'людям',
#   'непрочтенное',
#   'эти',
#   'истории',
#   'людеи',
#   'возможность скрыть',
#   'наверху прям очень',
#   'никакои',
#   ''],
#  858: ['', ''],
#  859: ['', ''],
#  860: ['', ''],
#  861: ['банкомат деньги',
#   'все',
#   'что',
#   'данныи банк',
#   'при удобном',
#   'итог',
#   'недели',
#   'меня псевдо надежность',
#   ''],
#  862: ['тормозят', 'приложение', ''],
#  863: ['есть', 'отправить', 'номер', 'постоянно', ''],
#  864: ['только',
#   'технологичного',
#   'возможности',
#   'отправке',
#   'другое',
#   'регулярно',
#   ''],
#  865: ['что', 'верните', 'делаете', ''],
#  866: ['', ''],
#  867: ['раньше можно', ''],
#  868: ['операции', 'список', 'когда', ''],
#  869: ['почините', ''],
#  870: ['что', 'функции', ''],
#  871: ['', ''],
#  872: ['', ''],
#  873: ['подключить', 'push', 'смс', 'предлагается', ''],
#  874: ['спамит постоянными', 'это нельзя', ''],
#  875: ['пополнения', ''],
#  876: ['приветствия', 'разработчики', ''],
#  877: ['тему', ''],
#  878: ['последнего', ''],
#  879: ['истории', ''],
#  880: ['это', 'зарабатываем', 'нет', 'скатился', 'требует', ''],
#  881: ['включена функция', ''],
#  882: ['лучшии', ''],
#  883: ['чтобы',
#   'это',
#   'услуги',
#   'видеть как изменится либо',
#   'возможность',
#   'вопрос',
#   'платеж',
#   'если',
#   ''],
#  884: ['что', 'если', 'как этот', 'рожь', 'вас', ''],
#  885: ['услуги', 'спасибо', 'переводить', ''],
#  886: ['будут', 'пердуны', 'выбор', ''],
#  887: ['почему', 'проблема', ''],
#  888: ['добавить', 'реклама', 'приложение', 'вечно', ''],
#  889: ['очень', ''],
#  890: ['', ''],
#  891: ['надоест', ''],
#  892: ['выбрать', 'нельзя', 'приходиться', ''],
#  893: ['реклама', 'или', 'рекламные', 'подключить', ''],
#  894: ['потом вообще', ''],
#  895: ['сколько осталось', 'назад', 'счету', 'просто', 'было', 'оно', ''],
#  896: ['все', 'оценка', 'можно', 'блок', ''],
#  897: ['клиентов', 'народа', 'тяжелые', 'пользоваться', ''],
#  898: ['показывает все', 'это', ''],
#  899: ['', ''],
#  900: ['это происходит', 'тогда', ''],
#  901: ['для', 'ipad', ''],
#  902: ['easy', ''],
#  903: ['карты', 'есть основная', ''],
#  904: ['сообщение', ''],
#  905: ['позвонить',
#   'так',
#   'открыть',
#   'функции',
#   'этыи',
#   'блин',
#   'юзабилисты',
#   ''],
#  906: ['уже', ''],
#  907: ['что', 'просто', 'даже', 'кривыми', 'интернет соединение', 'как', ''],
#  908: ['', ''],
#  909: ['', ''],
#  910: ['текст', 'слетели', 'без', ''],
#  911: ['переехала', 'выскакивает ужасно', 'кнопка', ''],
#  912: ['несколько', 'городах видят', 'адреса', 'соседнии', ''],
#  913: ['', ''],
#  914: ['', ''],
#  915: ['пароль для', ''],
#  916: ['нормально', 'посоветовали переустановить', 'сам пользуется', ''],
#  917: ['позволяет', ''],
#  918: ['мир', 'выбор', ''],
#  919: ['загружает', 'интернет', ''],
#  920: ['интернет', ''],
#  921: ['день пытаюсь', 'даже', ''],
#  922: ['все', 'области', ''],
#  923: ['долго', 'очень', ''],
#  924: ['раннии', ''],
#  925: ['оплачиваю', ''],
#  926: ['уже', ''],
#  927: ['буфер обмена', 'автоматическое копирование номера', ''],
#  928: ['раннии', 'восемь', ''],
#  929: ['', ''],
#  930: ['примитивные', 'остаточная', 'нужно', 'денег', ''],
#  931: ['тысяч', 'клиентоориентированность', 'вернуть', 'регионе', ''],
#  932: ['что', 'чат', 'даже', ''],
#  933: ['услуг', 'оплаты', 'для', 'или', 'зачем', ''],
#  934: ['вашеи', 'согласие', 'пальцу', 'эту', ''],
#  935: ['ужас', 'удаления', ''],
#  936: ['спасибо', 'вопросу', 'сказать', ''],
#  937: ['вход', ''],
#  938: ['идти постоянная', 'грузится', ''],
#  939: ['планирую', 'вашими', ''],
#  940: ['нужную', 'невозможно', 'где', 'своих', 'список', ''],
#  941: ['', ''],
#  942: ['время', 'мне приложение перестало', ''],
#  943: ['пожалуиста', 'раньше', 'можно', ''],
#  944: ['интерфеис', ''],
#  945: ['', ''],
#  946: ['банк постоянно', ''],
#  947: ['уведомления', 'услуга', ''],
#  948: ['его',
#   'поменяли',
#   'приятеля был',
#   'просто без',
#   'приложение',
#   'совсем',
#   'они',
#   'раз',
#   'карты',
#   'так',
#   'через',
#   'банка',
#   ''],
#  949: ['произошла', 'выполнения', 'постоянно', ''],
#  950: ['', ''],
#  951: ['карт', 'эту рекламу', 'уже', ''],
#  952: ['что', ''],
#  953: ['последнеи', 'номер', 'говорят', 'приложения', ''],
#  954: ['обновления какого', 'долго', ''],
#  955: ['плавныи', ''],
#  956: ['', ''],
#  957: ['месяц', ''],
#  958: ['', ''],
#  959: ['деиствие', 'было', 'подключить', ''],
#  960: ['принудительного', 'уведомления', ''],
#  961: ['', ''],
#  962: ['последнего', ''],
#  963: ['эти', 'над', 'долго', 'открывается', ''],
#  964: ['уведомить', 'отъема', 'нашел', 'ввести', 'взимать', ''],
#  965: ['между', 'пользоваться', 'данного', ''],
#  966: ['появится', ''],
#  967: ['вашем', ''],
#  968: ['штрафа', 'ввести', 'скидка', 'своих', ''],
#  969: ['счетам', 'нет', 'косяк', ''],
#  970: ['эта', 'надоели', 'так', 'было', ''],
#  971: ['', ''],
#  972: ['деньги', ''],
#  973: ['карты', ''],
#  974: ['планетах', 'пока карты', 'неск мес', ''],
#  975: ['для', 'главныи банк', 'подключить', ''],
#  976: ['', ''],
#  977: ['информации', 'никакои', ''],
#  978: ['', ''],
#  979: ['если', 'это', 'очень', 'зашли', ''],
#  980: ['все', 'следом', ''],
#  981: ['быть',
#   'что',
#   'деньги',
#   'приличныи',
#   'раза',
#   'иначе приходится',
#   'единственныи',
#   'если',
#   ''],
#  982: ['онлаин', ''],
#  983: ['после', 'приложение', ''],
#  984: ['', ''],
#  985: ['дня приложение',
#   'что',
#   'мне',
#   'вопросы открывать',
#   'заново',
#   'уже',
#   'эту',
#   'интернет',
#   'можно',
#   ''],
#  986: ['настроить', ''],
#  987: ['вкладка', 'последнего', 'день', ''],
#  988: ['сотовым', ''],
#  989: ['для',
#   'планшет',
#   'приложение',
#   'быстрых',
#   'платежеи запрятали',
#   'низ',
#   'сделали',
#   'сразу',
#   ''],
#  990: ['сделаите', ''],
#  991: ['скрывать', ''],
#  992: ['ждала', 'недоступна', 'момент', 'писали', 'после', ''],
#  993: ['уже', ''],
#  994: ['нельзя', 'воити', 'написано', ''],
#  995: ['открытых', 'поиск', 'только', ''],
#  996: ['приложение', 'раза что', 'пишет', ''],
#  997: ['', ''],
#  998: ['долгии', ''],
#  999: ['iphone', ''],
#  ...}

# %% [markdown]
# ## Conclusion:
#
# Gensim works worse for keywords extracting than library

# %% [markdown]
# # Common words baseline

# %%
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity
from numpy import argmax
import sklearn.preprocessing
import numpy as np

# %% [markdown]
# ## One hot encoding

# %%
def transform(review_keywords, groups_keywords):
    tokens = []
    for key in review_keywords:
        tokens+=review_keywords[key]
    for key in groups_keywords:
        tokens+=groups_keywords[key]
    print()
    print('All Tokens:')
    print(len(tokens))

    results = []
    label_enc = sklearn.preprocessing.LabelEncoder()
    onehot_enc = sklearn.preprocessing.OneHotEncoder()
    
    encoded_all_tokens = label_enc.fit_transform(list(set(tokens)))
    encoded_all_tokens = encoded_all_tokens.reshape(len(encoded_all_tokens), 1)
    
    onehot_enc.fit(encoded_all_tokens)
    
    review_keywords_transformed = {}
    for key in tqdm(review_keywords):
        
        encoded_words = label_enc.transform(review_keywords[key])
        
        
        encoded_words = onehot_enc.transform(encoded_words.reshape(len(encoded_words), 1))
        

        review_keywords_transformed[key]=(np.mean(encoded_words.toarray(), axis=0))
        
    groups_keywords_transformed = {}
    for key in tqdm(groups_keywords):
        
        encoded_words = label_enc.transform(groups_keywords[key])
        
        
        encoded_words = onehot_enc.transform(encoded_words.reshape(len(encoded_words), 1))
        

        groups_keywords_transformed[key]=(np.mean(encoded_words.toarray(), axis=0))
    
    return review_keywords_transformed, groups_keywords_transformed

# %% [markdown]
# ## Groups classification

# %%
review_keywords_transformed, groups_keywords_transformed = transform(reviews_keywords, groups_keywords)
# Out:
#   0%|          | 11/11139 [00:00<01:46, 104.53it/s]
# All Tokens:
# 65731
# 100%|██████████| 11139/11139 [01:36<00:00, 114.88it/s]
# 100%|██████████| 26/26 [00:00<00:00, 107.68it/s]

# %%
predictions = {}

for key in tqdm(review_keywords_transformed):
    predictions[key] = {}
    for group in groups_keywords_transformed:
        score = euclidean_distances([groups_keywords_transformed[group]], [review_keywords_transformed[key]])[0][0]
        predictions[key][group] = score
# Out:
# 100%|██████████| 11139/11139 [00:52<00:00, 211.49it/s]

# %%
import random
from collections import Counter,OrderedDict

#sampling with replacement
sampling = random.choices(list(reviews_keywords.keys()), k=20)

# %% [markdown]
# ### Eucleadean distance

# %%
for sample in sampling:
    print('---')
    print('Review')
    print(data.iloc[sample][TITLE_COL], data.iloc[sample][REVIEW_COL])
    print()
    scores = OrderedDict(sorted(predictions[sample].items(), key=lambda kv: kv[1]))
    print('Nearest team')
    print(list(scores.keys())[0], scores[list(scores.keys())[0]])
    print('---')
# Out:
# ---
# Review
# Стало очень громоздким Отличное приложение, прекрасно выполняет свои функции, но с годами становится все более и более громоздким. Последнее обновление не несло ничего по сути кроме украшений а весило больше 250мб. Лично у меня на телефоне места всегда не хватает.. Эти открытки и сторис мне лично не нужны, я была бы счастлива отключить и скрыть их и тем освободить немного места на телефоне, пока что удалось в настройках скрыть часть не нужного мне контента на главном экране приложения, но на занимаемый объем памяти это никак не повлияло.. Сейчас это одно из самых громоздких приложений, но оно необходимо так что приходится терпеть.
# Была бы безмерно благодарна за лайт-версию без всяких поющих отрыток, стикеров, сторисов, и тому подобного а только с базовыми функциями или за возможность отключить и скрыть их в текущей версии освободив тем немного места. Думаю я не одна такая..
#
# Nearest team
# Госуслуги 5.0
# ---
# ---
# Review
# Третий день не работает ! Третий день не работает ! Возможно только зайти в приложение и все, дальше не реагирует на нажатия!
#
# Nearest team
# Госуслуги 2.0
# ---
# ---
# Review
# Баг Внизу на вкладке «диалоги» постоянно висит уведомление о непрочитанных диалогах, хотя их там нет. Когда открываешь вкладку, уведомление исчезает, после повторного входа в приложение появляется снова
#
# Nearest team
# Госуслуги 2.8284271247461903
# ---
# ---
# Review
# Куда делись раздел расход по счету Пропала в начале страницы расход по карте ??????
#
# Nearest team
# Госуслуги 2.6457513110645907
# ---
# ---
# Review
# Роуминг 1 звезда за межрегиональный роуминг 👎
#
# Nearest team
# Госуслуги 2.0
# ---
# ---
# Review
# Загрузка Сделайте приложение меньшим размером. Требуется подключение к WiFi, так как файл весит более 200 мб.
#
# Nearest team
# Госуслуги 2.8284271247461903
# ---
# ---
# Review
# Нет отображения истории платежей.(((( Спасибо, исправили.
#
# Nearest team
# Госуслуги 1.7320508075688772
# ---
# ---
# Review
# Проблема есть Не работает оплата по штрих-коду и QR-коду! Не найден лицевой счет!
#
# Nearest team
# Госуслуги 2.449489742783178
# ---
# ---
# Review
# Не стабильная работа Постоянно зависает
#
# Nearest team
# Госуслуги 1.4142135623730951
# ---
# ---
# Review
# Выбор карты для платежей «по умолчанию» Буквально сегодня обнаружили, что сменилась карта по умолчанию для платежей. Подсовывает кредитную вместо дебетовой. И нигде выбрать нельзя карту «по умолчанию». Стало больше кликов. Очень неудобно.
#
# Nearest team
# Госуслуги 2.449489742783178
# ---
# ---
# Review
# Пожелания в отношении обновлений Пожалуйста адаптируйте приложение для альбомной ориентации (при его использовании с планшета ;)
#
# Когда поддерживалось приложение Сбербанк для iPad было весьма удобно ;) :)
#
# Nearest team
# Госуслуги 3.0
# ---
# ---
# Review
# Тема полотна Эрмитажа Добрый день,хотелось бы попросить вернуть прекрасное приветствие в виде картин Эрмитажа,приятно было зайти в он-лайн Сбербанк и видеть восхитительные шедевры☺️🙏🏼
#
# Nearest team
# Госуслуги 2.6457513110645907
# ---
# ---
# Review
# 1 Приложение полностью устраивает ,очень удобное !
#
# Nearest team
# Госуслуги 1.4142135623730951
# ---
# ---
# Review
# После обновления , переходя в кредиты , приложение вылетает Из-за того , что приложение стало вылетать, стало неудобно в нем работать
#
# Nearest team
# Госуслуги 2.0
# ---
# ---
# Review
# Предложение для оптимизации отображения В общем всем доволен, комфортное приложение, но есть пожелание.
# В разделе «вклады и счета» при создании  нового оно автоматически отображается сверху, а ранние ниже и если их много создано то становится неудобно и хотелось бы их сортировать в порядке каком захочется.
#
# Для этого предлагаю с помощью долгого нажатия и удержания включить режим перемещения строчки счета внутри этого раздела чтоб отсортировать так как хочется.
# А то приходится для этого делать перегонку средств между ними и переименовывать. Очень долго и не удобно.
#
# Заранее спасибо за комфортную поддержку
#
# Nearest team
# Госуслуги 4.0
# ---
# ---
# Review
# Ничего хорошего В приложении перестали отображаться кредиты, видимо очередное их «шикарное» обновление. Приложение, собственно как и сам банк, полный отстой.
# В том же Тинькоффе все интуитивно понятно и просто, а любая проблема решается за 2 минуты в чате. Со сбером же придётся часами висеть на телефоне в ожидании своей очереди, а чат вообще бестолковый! Жаль что привязана к этому дурацкому банку зарплатным проектом...
#
# Nearest team
# Госуслуги 4.0
# ---
# ---
# Review
# отличное приложение доработайте приложение для айфон 10, чтобы при входе не вводить пароль. чтобы можно было войти через face id
#
# Nearest team
# DDA Profile 2.6457513110645907
# ---
# ---
# Review
# Глючит , зависает и потом выкидывает из приложения ! Глючит , зависает и потом выкидывает из приложения !
#
# Раньше в списке произведённых переводов отображалась дата совершения операции , сейчас надо войти в каждый перевод , что бы увидеть дату совершения , это очень неудобно , когда в день их больше десятка , а в неделю около сотни ....надо ткнуть каждую операцию , что бы увидеть дату совершения ((
#
# Хотелось бы , что бы в каждой строчке отображалась дата и время совершения перевода , иначе приходится открывать каждую строку , что бы посмотреть дату совершения операции , а когда этих операций набирается сотни за месяц , то отследить и подытожить получается с большим трудом , особенно если операций за короткий период , на одинаковые суммы,  было много . Они просто сливаются и неизвестно, какую строчку открывал , а какую нет . Сделайте это для удобства людей , если сами не пользуетесь !
#
# Эти просьбы уже писал на протяжении нескольких месяцев в самом приложении консультантам , но реакции ноль (((
#
# Ответ консультанта : Михаил Анатольевич, "История" разбита на даты. Вы когда листаете, даты наверху написаны. Но нет конкретного только времени перевода, соглашусь. Интерфейс приложения для всех клиентов одинаковый и мы не сможем поменять настройки именно для вас.
#
# Я уточняю : История разбита только в общем списке , а когда я отслеживаю по конкретному человеку (набрав в поисковике  имя отчество ф.) , то все сливается
#
# Nearest team
# Госуслуги 6.557438524302
# ---
# ---
# Review
# Не могу зайти в шаблоны Пропал раздел шаблонов, вместо меню голубые прямоугольники. iPhone SE, iOS 13.3
#
# Nearest team
# Госуслуги 2.6457513110645907
# ---
# ---
# Review
# Загрузка Сделайте приложение меньшим размером. Требуется подключение к WiFi, так как файл весит более 200 мб.
#
# Nearest team
# Госуслуги 2.8284271247461903
# ---

# %% [markdown]
# ### Conclusion:
# Not weighted eucleadean distance predict best scores for groups with the smallest number of keywords (Госуслуги)

# %%
predictions_cos = {}

for key in tqdm(review_keywords_transformed):
    predictions_cos[key] = {}
    for group in groups_keywords_transformed:
        score = cosine_similarity([groups_keywords_transformed[group]], [review_keywords_transformed[key]])[0][0]
        predictions_cos[key][group] = score
# Out:
# 100%|██████████| 11139/11139 [01:30<00:00, 122.74it/s]

# %%
for sample in sampling:
    print('---')
    print('Review')
    print(data.iloc[sample][TITLE_COL], data.iloc[sample][REVIEW_COL])
    print()
    scores = OrderedDict(sorted(predictions_cos[sample].items(), key=lambda kv: kv[1], reverse = True))
    print('Nearest team')
    print(list(scores.keys())[0], scores[list(scores.keys())[0]])
    print('---')
# Out:
# ---
# Review
# Стало очень громоздким Отличное приложение, прекрасно выполняет свои функции, но с годами становится все более и более громоздким. Последнее обновление не несло ничего по сути кроме украшений а весило больше 250мб. Лично у меня на телефоне места всегда не хватает.. Эти открытки и сторис мне лично не нужны, я была бы счастлива отключить и скрыть их и тем освободить немного места на телефоне, пока что удалось в настройках скрыть часть не нужного мне контента на главном экране приложения, но на занимаемый объем памяти это никак не повлияло.. Сейчас это одно из самых громоздких приложений, но оно необходимо так что приходится терпеть.
# Была бы безмерно благодарна за лайт-версию без всяких поющих отрыток, стикеров, сторисов, и тому подобного а только с базовыми функциями или за возможность отключить и скрыть их в текущей версии освободив тем немного места. Думаю я не одна такая..
#
# Nearest team
# интерфейс приложения 0.0
# ---
# ---
# Review
# Третий день не работает ! Третий день не работает ! Возможно только зайти в приложение и все, дальше не реагирует на нажатия!
#
# Nearest team
# интерфейс приложения 0.0
# ---
# ---
# Review
# Баг Внизу на вкладке «диалоги» постоянно висит уведомление о непрочитанных диалогах, хотя их там нет. Когда открываешь вкладку, уведомление исчезает, после повторного входа в приложение появляется снова
#
# Nearest team
# Sberbank ID B2C 0.1690308509457033
# ---
# ---
# Review
# Куда делись раздел расход по счету Пропала в начале страницы расход по карте ??????
#
# Nearest team
# операции с картами 0.09901475429766744
# ---
# ---
# Review
# Роуминг 1 звезда за межрегиональный роуминг 👎
#
# Nearest team
# интерфейс приложения 0.0
# ---
# ---
# Review
# Загрузка Сделайте приложение меньшим размером. Требуется подключение к WiFi, так как файл весит более 200 мб.
#
# Nearest team
# интерфейс приложения 0.043937477516374675
# ---
# ---
# Review
# Нет отображения истории платежей.(((( Спасибо, исправили.
#
# Nearest team
# интерфейс приложения 0.08219949365267865
# ---
# ---
# Review
# Проблема есть Не работает оплата по штрих-коду и QR-коду! Не найден лицевой счет!
#
# Nearest team
# платежи 0.05923488777590924
# ---
# ---
# Review
# Не стабильная работа Постоянно зависает
#
# Nearest team
# интерфейс приложения 0.0
# ---
# ---
# Review
# Выбор карты для платежей «по умолчанию» Буквально сегодня обнаружили, что сменилась карта по умолчанию для платежей. Подсовывает кредитную вместо дебетовой. И нигде выбрать нельзя карту «по умолчанию». Стало больше кликов. Очень неудобно.
#
# Nearest team
# операции с картами 0.21693045781865616
# ---
# ---
# Review
# Пожелания в отношении обновлений Пожалуйста адаптируйте приложение для альбомной ориентации (при его использовании с планшета ;)
#
# Когда поддерживалось приложение Сбербанк для iPad было весьма удобно ;) :)
#
# Nearest team
# интерфейс приложения 0.04109974682633932
# ---
# ---
# Review
# Тема полотна Эрмитажа Добрый день,хотелось бы попросить вернуть прекрасное приветствие в виде картин Эрмитажа,приятно было зайти в он-лайн Сбербанк и видеть восхитительные шедевры☺️🙏🏼
#
# Nearest team
# интерфейс приложения 0.0
# ---
# ---
# Review
# 1 Приложение полностью устраивает ,очень удобное !
#
# Nearest team
# интерфейс приложения 0.0
# ---
# ---
# Review
# После обновления , переходя в кредиты , приложение вылетает Из-за того , что приложение стало вылетать, стало неудобно в нем работать
#
# Nearest team
# интерфейс приложения 0.06711560552140244
# ---
# ---
# Review
# Предложение для оптимизации отображения В общем всем доволен, комфортное приложение, но есть пожелание.
# В разделе «вклады и счета» при создании  нового оно автоматически отображается сверху, а ранние ниже и если их много создано то становится неудобно и хотелось бы их сортировать в порядке каком захочется.
#
# Для этого предлагаю с помощью долгого нажатия и удержания включить режим перемещения строчки счета внутри этого раздела чтоб отсортировать так как хочется.
# А то приходится для этого делать перегонку средств между ними и переименовывать. Очень долго и не удобно.
#
# Заранее спасибо за комфортную поддержку
#
# Nearest team
# общение 0.0563436169819011
# ---
# ---
# Review
# Ничего хорошего В приложении перестали отображаться кредиты, видимо очередное их «шикарное» обновление. Приложение, собственно как и сам банк, полный отстой.
# В том же Тинькоффе все интуитивно понятно и просто, а любая проблема решается за 2 минуты в чате. Со сбером же придётся часами висеть на телефоне в ожидании своей очереди, а чат вообще бестолковый! Жаль что привязана к этому дурацкому банку зарплатным проектом...
#
# Nearest team
# общение 0.0563436169819011
# ---
# ---
# Review
# отличное приложение доработайте приложение для айфон 10, чтобы при входе не вводить пароль. чтобы можно было войти через face id
#
# Nearest team
# DDA Profile 0.2357022603955159
# ---
# ---
# Review
# Глючит , зависает и потом выкидывает из приложения ! Глючит , зависает и потом выкидывает из приложения !
#
# Раньше в списке произведённых переводов отображалась дата совершения операции , сейчас надо войти в каждый перевод , что бы увидеть дату совершения , это очень неудобно , когда в день их больше десятка , а в неделю около сотни ....надо ткнуть каждую операцию , что бы увидеть дату совершения ((
#
# Хотелось бы , что бы в каждой строчке отображалась дата и время совершения перевода , иначе приходится открывать каждую строку , что бы посмотреть дату совершения операции , а когда этих операций набирается сотни за месяц , то отследить и подытожить получается с большим трудом , особенно если операций за короткий период , на одинаковые суммы,  было много . Они просто сливаются и неизвестно, какую строчку открывал , а какую нет . Сделайте это для удобства людей , если сами не пользуетесь !
#
# Эти просьбы уже писал на протяжении нескольких месяцев в самом приложении консультантам , но реакции ноль (((
#
# Ответ консультанта : Михаил Анатольевич, "История" разбита на даты. Вы когда листаете, даты наверху написаны. Но нет конкретного только времени перевода, соглашусь. Интерфейс приложения для всех клиентов одинаковый и мы не сможем поменять настройки именно для вас.
#
# Я уточняю : История разбита только в общем списке , а когда я отслеживаю по конкретному человеку (набрав в поисковике  имя отчество ф.) , то все сливается
#
# Nearest team
# интерфейс приложения 0.0
# ---
# ---
# Review
# Не могу зайти в шаблоны Пропал раздел шаблонов, вместо меню голубые прямоугольники. iPhone SE, iOS 13.3
#
# Nearest team
# интерфейс приложения 0.09491579957524991
# ---
# ---
# Review
# Загрузка Сделайте приложение меньшим размером. Требуется подключение к WiFi, так как файл весит более 200 мб.
#
# Nearest team
# интерфейс приложения 0.043937477516374675
# ---

# %% [markdown]
# ### Conclusion:
# Cosine distance predict scores as zero as number of keywords in groups is small, but predicts "карты" not bad

# %% [markdown]
# # Cosine distance for teams

# %%
review_keywords_transformed, teams_keywords_transformed = transform(reviews_keywords, team_names_keywords)
# Out:
#   0%|          | 8/11139 [00:00<02:28, 74.71it/s]
# All Tokens:
# 65764
# 100%|██████████| 11139/11139 [01:35<00:00, 116.24it/s]
# 100%|██████████| 42/42 [00:00<00:00, 110.13it/s]

# %%
predictions_cos_teams = []

for key in tqdm(review_keywords_transformed):
    predictions_cos_teams.append({})
    predictions_cos_teams[-1]['review'] = data.iloc[key][TITLE_COL]+' '+data.iloc[key][REVIEW_COL]
    scores = {}
    for team in teams_keywords_transformed:
        score = cosine_similarity([teams_keywords_transformed[team]], [review_keywords_transformed[key]])[0][0]
        scores[team] = score
    scores = OrderedDict(sorted(scores.items(), key=lambda kv: kv[1], reverse = True))
    predictions_cos_teams[-1]['label']=list(scores.keys())[0]
# Out:
# 100%|██████████| 11139/11139 [02:33<00:00, 72.79it/s]

# %%
pd.DataFrame(predictions_cos_teams).to_csv(os.path.join(DATA_PATH,'tfidf_cos_preds.csv'))

# %%
predictions_cos_teams
# Out:
# {0: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1: {'iOS Platform': 0.07624928516630233,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.15075567228888181,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  2: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  3: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  4: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.22360679774997896,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.18898223650461363,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.13363062095621217,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  5: {'iOS Platform': 0.038124642583151166,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.049999999999999996,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.14433756729740643,
#   'СБОЛ. Классические переводы': 0.22941573387056177,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.14433756729740643,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.07537783614444091,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.08333333333333333,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.07905694150420947,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.05590169943749474,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.06681531047810609,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  6: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  7: {'iOS Platform': 0.03327791628198609,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.05006261743217589,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0657951694959769,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.07273929674533079,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.06900655593423541,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.05832118435198042,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  8: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  9: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  10: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.18257418583505536,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  11: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.3162277660168379,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  12: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  13: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  14: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  15: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  16: {'iOS Platform': 0.08804509063256237,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.17407765595569782,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  17: {'iOS Platform': 0.0,
#   'Global Navigation': 0.06537204504606134,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.12598815766974242,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  18: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  19: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.22360679774997896,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  20: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  21: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  22: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.13483997249264842,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.06030226891555272,
#   'Платежи. Штрафы': 0.08058229640253801,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.06917144638660747,
#   'ЕФС.Автоплатежи': 0.08362420100070908,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  23: {'iOS Platform': 0.0,
#   'Global Navigation': 0.07412493166611012,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  24: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.12649110640673514,
#   'Платежи. Штрафы': 0.08451542547285164,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  25: {'iOS Platform': 0.0,
#   'Global Navigation': 0.16012815380508713,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  26: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.3162277660168379,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  27: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.2357022603955158,
#   'DBP.Витрины продаж': 0.40824829046386296,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  28: {'iOS Platform': 0.0576390417704235,
#   'Global Navigation': 0.03706246583305506,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.11396057645963796,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.08451542547285167,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  29: {'iOS Platform': 0.06819943394704735,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.13483997249264842,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.08944271909999157,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  30: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.28867513459481287,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  31: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  32: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.1386750490563073,
#   'Автопереводы': 0.28867513459481287,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  33: {'iOS Platform': 0.03251280443811776,
#   'Global Navigation': 0.08362420100070907,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.07537783614444091,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  34: {'iOS Platform': 0.15249857033260467,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.30151134457776363,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  35: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  36: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.22360679774997896,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.09999999999999999,
#   'Платежи. Штрафы': 0.13363062095621217,
#   'ПДВ в Digital': 0.28867513459481287,
#   'СБОЛ. Классические переводы': 0.34412360080584264,
#   'ЕФС.Автоплатежи': 0.1386750490563073,
#   'Автопереводы': 0.28867513459481287,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  37: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  38: {'iOS Platform': 0.0576390417704235,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
# ...
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1003: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.19999999999999998,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1004: {'iOS Platform': 0.050832856777534886,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.06666666666666665,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1005: {'iOS Platform': 0.08804509063256237,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.3333333333333333,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.17407765595569782,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.23570226039551584,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1006: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1007: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.16903085094570333,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.07559289460184544,
#   'Платежи. Штрафы': 0.10101525445522107,
#   'ПДВ в Digital': 0.2182178902359924,
#   'СБОЛ. Классические переводы': 0.260132990857236,
#   'ЕФС.Автоплатежи': 0.10482848367219184,
#   'Автопереводы': 0.2182178902359924,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1008: {'iOS Platform': 0.0,
#   'Global Navigation': 0.07412493166611012,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.11396057645963796,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.12598815766974242,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.10101525445522107,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1009: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1010: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.23570226039551584,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1011: {'iOS Platform': 0.050832856777534886,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.1529438225803745,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.20100756305184242,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.1111111111111111,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.10540925533894596,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.08908708063747478,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1012: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1013: {'iOS Platform': 0.08804509063256237,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.17407765595569782,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  1014: {'iOS Platform': 0.0,
#   'Global Navigation': 0.0,
#   'DDA Profile': 0.0,
#   'PFM': 0.0,
#   'PFMMPLACE': 0.0,
#   'PUSH IOS': 0.0,
#   'DBP.Витрины продаж': 0.0,
#   'Госуслуги': 0.0,
#   'iOS Release Engineer': 0.0,
#   'Мессенджер': 0.0,
#   'store-n-sales': 0.0,
#   'Integration Platform': 0.0,
#   'Data Driven App': 0.0,
#   'Краудфандинг': 0.0,
#   'DBP.Подарки': 0.0,
#   'Sberbank ID B2C': 0.0,
#   'История операций': 0.0,
#   'Редактируемый профиль клиента': 0.0,
#   'ЕФС Выписки и справки. Mobile': 0.0,
#   'ЕФС.Платежи МП': 0.0,
#   'Платежи. Штрафы': 0.0,
#   'ПДВ в Digital': 0.0,
#   'СБОЛ. Классические переводы': 0.0,
#   'ЕФС.Автоплатежи': 0.0,
#   'Автопереводы': 0.0,
#   'Digital Сбербанк Премьер': 0.0,
#   'Развитие лояльности в МП СБОЛ': 0.0,
#   'Дебетовые карты в мобильном приложении': 0.0,
#   'Карта в телефоне': 0.0,
#   'Плановый и досрочный перевыпуск дебетовых карт': 0.0,
#   'Самозанятые': 0.0,
#   'Цифровой Кредит': 0.0,
#   'ВС.МП вклады': 0.0,
#   'Комиссионные продукты': 0.0,
#   'PFM Бюджет': 0.0,
#   'Mobile Online POS (Розничный кредит)': 0.0,
#   'Текстовый чат': 0.0,
#   '[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)': 0.0,
#   'ЕФС. Брокеридж. Мобайл': 0.0,
#   '[ЕФС] Б.УБ.СБОЛ.Баллонг': 0.0,
#   'ЕФС. Страхование': 0.0,
#   'Телеком': 0.0},
#  ...}

# %%
for sample in sampling:
    scores = OrderedDict(sorted(predictions_cos_teams[sample].items(), key=lambda kv: kv[1], reverse = True))
    if scores[list(scores.keys())[0]]!=0:
        print('---')
        print('Review')
        print(data.iloc[sample][TITLE_COL], data.iloc[sample][REVIEW_COL])
        print()
        print('Nearest team')
        print(list(scores.keys())[0], scores[list(scores.keys())[0]])
        print('---')
# Out:
# ---
# Review
# Баг Внизу на вкладке «диалоги» постоянно висит уведомление о непрочитанных диалогах, хотя их там нет. Когда открываешь вкладку, уведомление исчезает, после повторного входа в приложение появляется снова
#
# Nearest team
# Sberbank ID B2C 0.16903085094570333
# ---
# ---
# Review
# Куда делись раздел расход по счету Пропала в начале страницы расход по карте ??????
#
# Nearest team
# Плановый и досрочный перевыпуск дебетовых карт 0.13608276348795434
# ---
# ---
# Review
# Загрузка Сделайте приложение меньшим размером. Требуется подключение к WiFi, так как файл весит более 200 мб.
#
# Nearest team
# Global Navigation 0.07412493166611012
# ---
# ---
# Review
# Нет отображения истории платежей.(((( Спасибо, исправили.
#
# Nearest team
# iOS Platform 0.10783277320343841
# ---
# ---
# Review
# Проблема есть Не работает оплата по штрих-коду и QR-коду! Не найден лицевой счет!
#
# Nearest team
# ЕФС.Платежи МП 0.08944271909999157
# ---
# ---
# Review
# Выбор карты для платежей «по умолчанию» Буквально сегодня обнаружили, что сменилась карта по умолчанию для платежей. Подсовывает кредитную вместо дебетовой. И нигде выбрать нельзя карту «по умолчанию». Стало больше кликов. Очень неудобно.
#
# Nearest team
# Дебетовые карты в мобильном приложении 0.26967994498529685
# ---
# ---
# Review
# Пожелания в отношении обновлений Пожалуйста адаптируйте приложение для альбомной ориентации (при его использовании с планшета ;)
#
# Когда поддерживалось приложение Сбербанк для iPad было весьма удобно ;) :)
#
# Nearest team
# iOS Platform 0.053916386601719206
# ---
# ---
# Review
# После обновления , переходя в кредиты , приложение вылетает Из-за того , что приложение стало вылетать, стало неудобно в нем работать
#
# Nearest team
# iOS Release Engineer 0.17407765595569782
# ---
# ---
# Review
# Предложение для оптимизации отображения В общем всем доволен, комфортное приложение, но есть пожелание.
# В разделе «вклады и счета» при создании  нового оно автоматически отображается сверху, а ранние ниже и если их много создано то становится неудобно и хотелось бы их сортировать в порядке каком захочется.
#
# Для этого предлагаю с помощью долгого нажатия и удержания включить режим перемещения строчки счета внутри этого раздела чтоб отсортировать так как хочется.
# А то приходится для этого делать перегонку средств между ними и переименовывать. Очень долго и не удобно.
#
# Заранее спасибо за комфортную поддержку
#
# Nearest team
# Текстовый чат 0.05773502691896258
# ---
# ---
# Review
# Ничего хорошего В приложении перестали отображаться кредиты, видимо очередное их «шикарное» обновление. Приложение, собственно как и сам банк, полный отстой.
# В том же Тинькоффе все интуитивно понятно и просто, а любая проблема решается за 2 минуты в чате. Со сбером же придётся часами висеть на телефоне в ожидании своей очереди, а чат вообще бестолковый! Жаль что привязана к этому дурацкому банку зарплатным проектом...
#
# Nearest team
# iOS Release Engineer 0.07784989441615231
# ---
# ---
# Review
# отличное приложение доработайте приложение для айфон 10, чтобы при входе не вводить пароль. чтобы можно было войти через face id
#
# Nearest team
# iOS Platform 0.24902912254587614
# ---
# ---
# Review
# Не могу зайти в шаблоны Пропал раздел шаблонов, вместо меню голубые прямоугольники. iPhone SE, iOS 13.3
#
# Nearest team
# СБОЛ. Классические переводы 0.0936585811581694
# ---
# ---
# Review
# Загрузка Сделайте приложение меньшим размером. Требуется подключение к WiFi, так как файл весит более 200 мб.
#
# Nearest team
# Global Navigation 0.07412493166611012
# ---
