# %% [markdown]
# # Get review data and teams keywords

# %%
import pandas as pd
import os
from tqdm import tqdm
import json

# %%
REVIEW_PATH = '../Resources/1_clean_review_data'

KEYWORDS_PATH = '../Resources/2_keywords_for_teams_data'

DATA_PATH = '../Resources'

REVIEW_COL = 'Review'
TITLE_COL = 'Title'

# %%
data = pd.read_csv(os.path.join(REVIEW_PATH,'cleanAppStore.csv'))

# %%
with open(os.path.join(KEYWORDS_PATH,'team_keywords.json'),'r') as f:
    team_names_keywords = json.load(f)

with open(os.path.join(KEYWORDS_PATH,'grouped_team_keywords.json'),'r') as f:
    groups_keywords = json.load(f)
    
with open(os.path.join(KEYWORDS_PATH,'grouped_team_mapping.json'),'r') as f:
    mapping = json.load(f)

# %% [markdown]
# # Sampling of reviews for quality measurements

# %%
sample_size = 100
num_of_subsets = 4

# %%
import random
subsets = []
for i in range(num_of_subsets):
    subset_ind = random.choices(range(len(list(data[REVIEW_COL]))), k=sample_size)
    subset = [data.iloc[j][TITLE_COL]+' '+data.iloc[j][REVIEW_COL] for j in subset_ind]
    subsets.append(subset)

# %%
data_marked = []
for subset in tqdm(subsets):
    for review in subset:
        data_marked.append({})
        data_marked[-1]['review']=review
        print(review)
        label = input()
        data_marked[-1]['label'] = label
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Сбербанк Отличное приложение! Пользуюсь им уже давно и все устраивает!
# iOS Platform
# Отстой Верните оповещение при снятии и поступлении денег на карту в смс!!! Очень неудобное нововведение!!! 🤦🏻‍♀️🤦🏻‍♀️🤦🏻‍♀️
# iOS Release Engineer;PUSH IOS
# Не ожидала Выкидывает из приложения даже не успев зайти(((
# iOS Platform
# Жадность Спасибо за комиссии. Теперь жене только наличкой и надобность в картах отпала.
# Sberbank ID B2C;ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы
# Переделайте историю операций Нельзя посмотреть именно историю в мобильном приложении за определённый период, только выписку, если делать, а это неудобно. Приходится пролистывать много времени, чтобы отыскать в прошлом нужную операцию .
# История операций;iOS Platform;ЕФС Выписки и справки. Mobile
# Спам рекламы в уведомлениях! Как можно было в уведомления запихнуть рекламу? Я хочу чтобы мне приходила информация о транзакциях, а не реклама говнобонусов и говноакций, срочно уберите это или сделайте возможность отключить!
# PUSH IOS;DBP.Витрины продаж
# Отличный банк!!!! Сбербанк, один из самых востребованных банков, супер обслуживание, максимум привелегий!!!
# iOS Platform
# Обновление баланса в приложении Зачем в приложении реализовано обновление баланса, если оно не работает?
# Поправьте, пожалуйста
# iOS Release Engineer;iOS Platform;PFM Бюджет
# Отстойное обслуживание!!! Сливают Контакты мошенникам! Ужасный банк!
# Data Driven App;DDA Profile;Редактируемый профиль клиента
# Тормоз Тормозит в последнее время конкретно
# iOS Platform;iOS Release Engineer
# В какой-то момент стало зависать при входе(iphone6) В какой-то момент стало зависать при входе(iphone6). Переустановил , не помогло. Хотя у жены все Работает на таком же телефоне
# iOS Release Engineer;iOS Platform
# Денис Перестал отображаться баланс через виджет(
# iOS Platform;PFM Бюджет;Global Navigation
# Старый баланс по карте Сегодня показывает баланс месячной давности
# PFM Бюджет
# Bonjour Forte
# None
# Сбербанк и его сервис платежей Все хорошо, но брать комиссию за платежи ЖКХ(квартплата) при выплате акционерам супердиведентов в этом году(16 руб на акцию) верх бессовестности!!!С пенсионеров особенная наглость!!!Я так думаю!!!
# С ув.
# Sberbank ID B2C;ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы
# Сбербанконлайн -это очень удобно .супер! ь
# None
# Комиссия на переводы Тупая система с комиссией за переводы. Я постоянно перевожу, и платить комиссию за перевод в вашем же банке я не буду. В Альфабанке этого нет. Перехожу на другой банк
# Sberbank ID B2C;ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы
# Самое четкое приложение Продолжайте работа
# None
# Отзыв Неудобно теперь контролировать расходы и приход денег, смс было удобнее чем пуш уведомление
# PFM Бюджет;PUSH IOS
# Топ Топ
# None
# Сбербанк Отлично все у вас! Так держать и вперёд!!!
# None
# Обратная совместимость в API Ребята, а может будете обратную совместимость поддерживать? Уже не первый случай, когда некоторый функционал приложения просто отваливается, при том в самый неподходящий момент, спасает только обновление. Не всегда есть возможность обновить сразу приложение.
# iOS Platform;iOS Release Engineer
# Комиссия Почему берёте комиссию, ведь я плову online. Обкрадываете народ. Живу в Америке больше 20 лет и никогда за это не платила. Да и ещё чтоб вам отправить сообщение, надо пойти кучу нюансов. Будьте проще и люди к вам потянуться.
# Sberbank ID B2C;ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы;Текстовый чат;Мессенджер
# Все работает и не глючит Регестрирйтесь на сайте 1xbet вводите промо код 265050 и получи бонус в 100% от суммы.
# None
# Зависает на 5-й секунде после запуска Дорогие разработчики! Что случилось! Третий день как прога зависает после запуска. Снес, переустановил - не помогло! iPhone SE 128 (Model MP882RU/A),  iOS 12.4.1 (16G102)
# iOS Platform;iOS Release Engineer
# Плохо Моей матери Дали книжку . В приложении книжки не котируются . Вводятся карты
# Дебетовые карты в мобильном приложении;Плановый и досрочный перевыпуск дебетовых карт
# Вылетает из приложения после обновления Не могу даже зайти
# iOS Platform;iOS Release Engineer
# Виджет баланс 1. Нет у вас виджета с балансом!
# У вас есть виджет «Уведомления», который работает только с платной подпиской уведомления (на PUSH в том числе). А виджета с балансом без платных подписок у вас нет. Обратите внимание как это сделано у Альфа-Банка.
#
# 2. Платные PUSH? За что? Тинькофф шлёт push бесплатно! Ладно бы за СМС, но пуш?!
# iOS Platform;PFM Бюджет;Global Navigation;Sberbank ID B2C;ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы
# Справка и Движение д/с. Спасибо Вам за такое прекрасное приложение!!!
# Есть одна просьба к справке о доступном остатке, мне нужна была эта справка для визы и посольство требовало остаток по карте в рублях переведённый в евро на момент выдачи справки. Если бы  в справке автоматически указывался остаток не только в рублях ,но и  в долларах и евро переведённый на момент выдачи справки , я был бы очень вам благодарен,что бы не ехать в офис за ней.
# Подписывайте справки электронной цифровой подписью, распечатанную подпись и Печать на принтере во многих местах не принимают( требуют оригинал печати и подписи)!
# Если приложение Сбербанк открыто и производились какие- то операции ( списание пополнение д/с), что бы увидеть изменение приходиться закрывать приложение и входить в него заново , сделайте возможность просто обновить экран в приложении и увидеть изменения по движению д/с.
# Сделайте возможность упорядочить Карты и вклады , в каком порядке надо пользователю !
# Дебетовые карты в мобильном приложении
# Искусственный интеллект - по факту теперь нет поддержки совсем Кричат на каждом углу про искусственный интеллект, по факту по телефону «умная» помощница не может ничего и пересылает тебя на IVR, откуда выпилили вариант соединения с живым оператором.
# В чате поддержка тоже не может ничего - говорит, идите в офис. Хотя вопрос был простой - от кого пришёл перевод.
# То есть любой вопрос, который я сама не могу прочитать на их сайте - иди в офис. По факту поддержка просто исчезла, и любой может отправить тебе деньги непонятно за что, подставить перед налоговой - ну а ты или в офис.
# Текстовый чат;Мессенджер
# Вылетает после обновления! Вылетает после обновления! iPhone 7
# iOS Platform;iOS Release Engineer
# Сбербанк онлайн Лучшее банковское приложение!
# None
# Плохое обновление После последнего обновления на моем iPhone 6 и на iPhone 6 моей супруги при входе в приложение вместо вкладов отображает крутящееся колесо (поиск вкладов). Если выйти и зайти снова - отображает вклад. Теперь постоянно по два раза входить?
# iOS Platform;iOS Release Engineer
# Комиссия Во всех банках можно пополнить карту картой стороннего банка без комиссии, а сбере все не как у людей, за все надо содрать деньги!
# Sberbank ID B2C;ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы
# Ди7373838 Он ужасно зависает!!!
# iOS Platform;iOS Release Engineer
# Благодарность всему коллективу! Быстро качественно своевременно❣️благодарю за отличную работу ❣️❣️❣️
# None
# Исправление ошибок Здравствуйте, очень удобное приложение, но большая просьба исправить ошибки, после обновления не удобно контролировать анализ финансов, перестали отображаться категории зачисление зарплаты, зачисление пенсии, и так далее. Также желательно обратно сгруп пивать коммунальные платежи, чтобы удобно было контролировать итоговую сумму расходов на телефон, интернет. Заранее большое спасибо
# iOS Release Engineer;PFM Бюджет
# Лагает На айфонXr очень лагает, долго загружается приложение, а иногда и вылетает! С другими приложениями такого не бывает! Плюс ко всему требует включить геолокацию( она включена и доступна для приложения). Не показывает операции с бонусами СПАСИБО( а я из проводил). Исправляйте
# iOS Platform;iOS Release Engineer;Развитие лояльности в МП СБОЛ
# Досрочное погашение кредита Добрый день! Очень не хватает в приложении возможности делать досрочное погашение с уменьшением срока кредита.
# Mobile Online POS (Розничный кредит);[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы);Цифровой Кредит
# Amazing Amazing app
# None
# 😕 Здравствуйте, верните пожалуйста функцию скрытие не часто используемых карт... для того чтобы меньше посторонние глаза глядели на мои финансы... а то так открываешь где-нибудь в общественном месте или в присутствие третих лиц и все сразу глазами косятся на то что в приложении указано (((
# iOS Platform;DDA Profile;Редактируемый профиль клиента;iOS Release Engineer
# Виджет Не нравится , что не возможно установить виджет в телефоне, требует подключения мобильного банка. А ведь на андроиде всё нормально и без оплат. Также хочу уточнить, когда отправка смс с текстом «перевод _номер Карты_сумма» будет возможна не только на платный номер 900, а ещё и на стандартный федеральный
# Global Navigation;Мессенджер;iOS Platform
# Теряется сотовая связь. Айфон 7. Три раза произошёл неприятный случай- при входе в приложение (как я заметил с третьего раза) телефон теряет сотовую связь и очень долго не может её найти. Сначала я думал проблема в телефоне, но оказалось это как то связано с вашим приложением.
# iOS Platform
# Заказ наличных Вопрос к разработчику ПО и управлению банка:
# Единственный банк в котором для заказа крупной суммы для снятия в кассе нужно посетить отделения дважды: для заказа и самого снятия!
# По телефону ЗАКАЗ НЕ ВОЗМОЖЕН!!!!
# ИСПРАВЛЯЙТЕСЬ!!!!
# iOS Platform;ЕФС.Платежи МП
# Сбербанк Мне нравится сотрудничать с вами. Спасибо.
# None
# Поправьте виджет Поправьте пожалуйста ночной виджет. Черное на темно-сером читается не очень.
# Global Navigation;iOS Platform
# Нет возможности пополнить проездную карту Не могу пополнить проездную карту «Социальная система». Появляется сообщение: «Оплата временно недоступна. Попробуйте позже». А когда пытаюсь через какое-то время снова пополнить счёт, ничего не выходит... хотя с другого телефона получается спокойно.
# iOS Platform;ЕФС.Платежи МП
# Перестал входить по отпечатку пальца Не могу входить в приложение по отпечатку пальца, раньше все работало. Теперь приходится каждый раз вводить пароль. В настройках все включено, но это не работает. Что делать???
# iOS Platform;iOS Release Engineer
# Активно пользуюсь! Всё устраивает!
# None
# не показывает уведомления После обновления ios не показывает уведомления значок есть а уведомления нету
# iOS Release Engineer;PUSH IOS;iOS Platform
# Подписка платная очередное дно Вы что там вообще ку ку!
# Sberbank ID B2C;ЕФС.Платежи МП;iOS Release Engineer
# Новое обновление зависает на iPhone после каждого в второго или третьего шага Новое обновление зависает после входа в приложение после второго или третего касания - что случилось
# iOS Release Engineer;iOS Platform
# Ms.Elena Очень удобно пользоваться приложением
# Сбербанк!!! Спасибо вам большое за отличную работу!!!
# None
# СБЕРБАНК онлайн Удобно, быстро, экономия времени
# None
# У вас ум есть??? После обновления можно легко посмотреть номер карты и cvs. У вас ум то есть, вы такое делаете??? А если кому то по башке дадут, зайдут в приложение и мошенники все узнают, вы потом будете деньги возмещать? Уберите!
# iOS Release Engineer;Редактируемый профиль клиента;DDA Profile
# Остаток по карте в ИСТОРИИ Куда делась информация об остатке в карте после каждой покупки и транзакции в разделе Истории платежей??? Это вызывает некие сомнения о прозрачности !!! Верните остаток по карте в истории покупок (в динамике)!
# iOS Release Engineer;PFM Бюджет;История операций
# Огонь Все четко
# None
# Темный режим Не хватает темного режима в приложении. Прорабы запилить это...
# iOS Release Engineer;iOS Platform
# Баги Не показывает истории операций денежных средств
# iOS Platform;История операций
# Супер Ребята! Вы знаете чего делаете! Спасибо вам! Так держать!
# None
# Отзыв Отличный сервис. Без него уже не обойтись.
# None
# Проблема Почему не работает Face ID???
# iOS Platform
# Вылет При подтверждении перевода/платежа вылетает до начального экрана. Каждый раз.
# При пополнении счета приходится перезаходить, что бы сумма на остатке обновилась.
# iOS Platform;PFM Бюджет;История операций
# Приложение После обновления нельзя сворачивать виджеты вверху приложения (действия,истории,финансы) от этого сразу 1/3 экрана занята и отображается не вся инфа как ранее.
# Верните возможность сворачивания!!!
# iOS Release Engineer;iOS Platform
# Сбербанк Осень много стало навязчивой рекламы и это при всём том что приложение и так много собирает личных данных о человеке , так ещё и прибавилось о всех его действиях , геопозиции, транзакциях, покупках.
# iOS Platform;DDA Profile;Редактируемый профиль клиента;iOS Release Engineer
# 👍 Обновление по дизайну 👍
# None
# Плохо! Косая версия! У меня 5 счётов, но в диаграмме «всего средств» отражается только 4. В прошлой версии все было корректно.
# PFM Бюджет;iOS Release Engineer
# Для разработчиков!! Вроде работает Пока приложение работает без нареканий, либо на серверах сбера наладилась работа, либо на серверах мегафона, ничего не удалял и не переустанавливал.
# iOS Release Engineer;iOS Platform
# После обновления пропал провайдер ЭЛЛКО. Верните пожалуйста как было провайдера ЭЛЛКО. Я всегда оплачиваю через приложение. А в этот раз не обнаружила.
# iOS Release Engineer
# Отзыв о СБРоссии. Всё нормально !
# Только проценты на всём у Вас больше чем зарубежом.
# ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы;ЕФС.Автоплатежи
# Вылетает после ввода пароля. iPhone 11 XS mas pro - после запуска приложения и ввода пароля или (Face ID) приложение сразу вылетает. Все обновили, версии телефона и сбера самые новые. Приложение сносили и ставили заново, не помогает. Началось с 16 января. Сбербанк в чем может быть проблема. Оценку поставлю за само приложение 5 после ответа. Спасибо.
# iOS Release Engineer;iOS Platform
# Обновление После обновления, приложение все равно подвисает.
# iOS Release Engineer;iOS Platform
# Не открывается приложение Спасибо вам.Приложение работало долгое время и после обновления не открывается.Просто супер!!!
# iOS Release Engineer;iOS Platform
# Сбербанк Интернет хороший,а пишет ,что нет его .Исправте пожалуйста этот недочёт
# iOS Platform
# Неаеруша Безобразие, не открывается, все хуже и хуже обновления
# iOS Release Engineer;iOS Platform
# Приложение Все супер
# None
# Отзыв Приложение испортилось! Не показывает точную сумму, которая на карте. Чтобы узнать сколько у тебя средств на карте нужно отправить платную смс!!! Только после этого она отобразится в приложении. Потянуть страницу свайпом или перезагрузить приложении недостаточно! Спустя неделю баланс все ещё неверный показывает.
# PFM Бюджет;iOS Release Engineer;iOS Platform;
# Спасибо Любимый!!!
# None
# Не обновляются остатки средств В версиях ранее и текущей, в случае если в момент когда приложение открыто и было поступление средств, остаток не обновляется, даже через свайп вниз. Обновление происходит только после закрытия и повторного открытия приложения.
# PFM Бюджет;iOS Release Engineer;iOS Platform
# ENGLISH Добрый день! Было бы лучше иметь русскоязычный и англоязычный интерфейс. Вариант-выбрать один или другой.
#
# Спасибо!
# iOS Platform
# Вкладка Диалоги Каждый раз при запуске приложения на iPhone 7 (iOS 13.5.1) во вкладке Диалоги постоянно появляется цифра 1. Исчезает когда открываешь вкладку, но при следующем запуске снова появляется.
# Исправьте пожалуйста! Надоело постоянно её видеть, отвлекает внимание.
# Мессенджер;Текстовый чат;iOS Release Engineer;iOS Platform
# Функция сбора статистики включается сама по себе Очередной раз замечаю, что постоянно, без моего ведома, в настройках обратно включается функция сбора статистики. Каждый раз собственноручно её выключаю, и каждый раз, через некоторое время, она опять активна.
#
# Что за насильственное принуждение к передаче своих личных данных?!
# DDA Profile;Редактируемый профиль клиента;iOS Release Engineer
# Тормозит Здравствуйте! Исправьте пожалуйста ошибку. После входа в приложение тормозит, долго думает прежде чем начать какую либо операцию!
# Тормозит !
# iOS Release Engineer;iOS Platform
# Спасибо Отлично мне нравится.
# None
# Спасибо добавление уменьшения срока в мп сбол!!! Огромное спасибо, что добавили досрочное погашение кредита с уменьшением срока кредита, давно ждала эту функцию. Только было замечательно, если была бы возможность просмотра графика платежей перед сохранением операции, как это сделано в отделение банка.
# Mobile Online POS (Розничный кредит);Цифровой Кредит;[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы);iOS Release Engineer
# После обновления не работает приложение Не работает!!!
# iOS Release Engineer;iOS Platform
# Место на телефоне Оптимизируйте размер приложения, 250 мегабайт против Тинькоффских 120 никуда не годится
# iOS Release Engineer;iOS Platform
# Развод на курсе € Развод продолжается. Писал жалобу 19.02.2020, ничего не изменилось. 10.03.2020 курс обмена евро в приложении 83,03, но при попытке купить считает по курсу 84,39. Скрины имеются.
# ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы;ЕФС.Автоплатежи
# Не работает вообще После последнего обновления iOS 13 не работает вообще 🤯🤬🤬🤬🤬🤬
# iOS Release Engineer;iOS Platform
# Эй, разрабы. А вы пробовали тестировать ПО перед тем как выкладывать в релиз? Или пользователи и это гов..но схавают?
# iOS Release Engineer;iOS Platform
# Благодарность 🙏🏻 Спасибо большое! В обновлённой версии ещё стало доступнее и понятней👍🏻🙏🏻
# None
# Слишком сложно для простых действий 1. Комиссия показывается на последнем шаге
# 2. После перевода между счетами деньги все равно не видны, нужно перезапускать приложение
# 3. Я вводил 2 раза ФИО которое вы и так знаете
# 4. Данные об организации после поиска показываются на последнем шаге
# 5. Потратил 30 минут чтобы заплатить за садик
# ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы;ЕФС.Автоплатежи
# . Часто приложение зависает, счета дублируются, не получается выполнить операцию! Интернет у меня отличный, все остальные приложения работают хорошо.
# iOS Platform
# Неплохая игрушка Всё отлично, но вот только деньги бесплатно не выдают, было бы хорошо)))
# None
# Проблемма Выкидывает из приложения
# iOS Platform
# Сбербанк Окей и гуд
# None
# Ошибка Хотел ознакомиться с условиями перед расчётом своего кредитного потенциала, при нажатии получил «ошибка, не удалось загрузить документ».
# iOS Platform
# Неудобное приложение Приятный цвет, стилистика, тем не менее, в части отображения самих движений по счету - огромный минус. Во-первых, половину экрана занимает остаток, из-за чего транзакции отображаются по одной-две за пролистывание. Во-вторых - списание комиссий, которое появляется задним числом, либо вообще не появляется, не смотря на то, что остаток в минусе.
#
# В продолжение, на ответ о списании годовой комиссии: нет, после погашения задолженности в истории транзакция не появляется. Просто списана сумма, и на остатке плюс только из-за пополнения счета. Вы планируете добавить какие-либо документы, указывающие на такие списания, или так и нужно постоянно выяснять, не мошенническое ли это действие?
# Global Navigation;PFM Бюджет
# Верните смс 900 Верните назад оповещены в смс 900!!!! Стало очень не удобно, постоянно заходить в приложение сбербанк онлайн и смотреть сколько осталось на счету. Когда стоишь в магазине и не помнишь сколько у тебя осталось на счету. Приходится заходить в приложение, вводить пинкод, пока оно загрузиться и рак на горе свиснет!!!
# А так было просто, зашел в смс 900, посмотрел быстренько сколько там на счету осталось и отличненько!
# iOS Release Engineer;iOS Platform
# На планшете На планшете стало неудобно пользоваться- окно только вертикально и маленькое
# iOS Release Engineer;iOS Platform;Global Navigation
#  10%|█         | 1/10 [32:10<4:49:34, 1930.52s/it]
# Супер услуга Благодарю
# None
# Вылетает постоянно Обновила приложение сегодня и вообще Сбербанк не могу открыть, постоянно вылетает, даже не загружается. Интернет работает стабильно, даже телефон перезагружала, все равно вылетает!!
# iOS Release Engineer;iOS Platform
# почему? после обновления не открывается приложение вообще.
# iOS Release Engineer;iOS Platform
# Карты и кредиты Просьба не присылать мне никаких кредитных предложений ни под какие проценты ближайшие 26 лет. Спасибо.
# Дебетовые карты в мобильном приложении;[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)';Цифровой Кредит;Mobile Online POS (Розничный кредит)
# Выписка Стало просто невозможно создать быструю выписку по карте. Делается запрос и приходит отчёт. Ранее просто на экране в ту же секунду инфа отображалась. В принципе стало трудно найти эту выписку. Очень неудобно
# ЕФС Выписки и справки. Mobile;iOS Release Engineer
# Отличный банк лучший в Мире Отлично лучше всех
# None
# Сбербанк Сбербанк Сбербанк
# None
# Все отлично, но... Добавьте же наконец поддержку темного режима экрана!!!
# iOS Release Engineer;Global Navigation;iOS Platform
# Карта в виджете Сейчас там отображается баланс последней использованной карты, хотелось бы что бы была возможность фиксированного выбора определенной карты (у меня есть основная карта).
# Global Navigation;Дебетовые карты в мобильном приложении
# Вылетает ! Вылетает Сбербанк онлайн на iPhone 5s iOS 12. После установки всё нормально работает, но стоит закрыть приложение, выгрузить из памяти и попытаться снова зайти -  не запускается. Что-то сломали, раньше всё хорошо было. Исправьте пожалуйста
# iOS Release Engineer;iOS Platform
# Не работает Приложение перестало открываться по мобильной сети  ! Вход возможен только по wi-fi или через раздачу!
# iOS Release Engineer;iOS Platform
# разделы на главном убираю ненужные разделы на главном, но через пару заходов в приложение они опять появляются, началось с последним обновлением, испрате
# iOS Release Engineer;iOS Platform
# Отзыв Самый лучший банк))нравится все, и услуги, и интерфейс.
# None
# Интернет банк Очень нравится услуга QR code и оповещение смс о приходе счета и возможности оплатить автоматически с помощью смс. Удобно и быстро
# iOS Release Engineer;iOS Platform
# Сбербанк супер!!!! Все всегда ясно и понятно.
# None
# Обновил... Все супер, переустановил приложение и заработало отлично👍🏽
# iOS Release Engineer;iOS Platform
# Touch id iphone 7 Не работает и не отображается в настройках функция touch id Iphone 7.
# iOS Release Engineer;iOS Platform
# Сломано Вылетает iPhone 6S
# iOS Release Engineer;iOS Platform
# Очень сильно греется телефон!!! Разработчики, я не знаю что у вас там происходит и как вы делали приложение. Но у меня последний на данный момент айфон и он безумно сильно греется именно в вашем приложении. Это издевательство для процессора и рук, которые просто телефон держать не могут. Криворукие разрабы, чес слово
# iOS Release Engineer;iOS Platform
# За что я плачу по 150₽ в месяц?!?!!??!😡 Разрабочики этого приложения, за что платить деньги, за обслуживание карты, если ВЫ ВСЕ РАВНО СМС-УВЕДОМЛЕНИЕ ОТКЛЮЧИЛИ!!!!!! Мне НЕ интересно каждый раз заходить в вообще приложение и смотреть остаток на карте!!!!! Сделай обратно, чтоб можно было смс читать с номера 900, как раньше!!!!!!!!😡😡😡😡😡😡😡😡😡😡😡😡😡😡😡
# PUSH IOS;Мессенджер;iOS Release Engineer
# Обновление ноябрь 2019 Очень плохо! Стало зависать приложение! Не запускается!
# iOS Release Engineer;iOS Platform
# Лишний контент Здравствуйте! Как отключить весь контент в приложении? Везде  понажимал "не интересно", а воз и ныне там.  Меня интересуют только открытые банковские продукты. Контент про почему полезен завтрак и про космос я предпочту потреблять на более профильных ресурсах.
# DBP.Витрины продаж
# Бардак с уведомлениями! Ну было же удобно и информативно!  Теперь непонятно как приходят уведомления, а иногда и совсем не приходят. Иногда, как раньше, приходят смс.
# При этом изменится ли стоимость обслуживания карты?- естественно нет)
# PUSH IOS
# Без коментарий Машенники
# None
# Системные требования - iOS 11 У меня стоит ios 10, обновиться нет возможности. А потом вы сделаете так, что приложение без обновления станет недоступно, что мне предлагаете делать?
# iOS Release Engineer;iOS Platform
# Когда починят? Долго ещё приложение будет сбрасывать настройки при каждом входе?
# iOS Release Engineer;iOS Platform
# Не работает Зависает как только проходишь авторизацию. Прошивка последняя. iPhone XR
# iOS Release Engineer;iOS Platform
# Неудобно При переводе средств со счета на счёт нет возможности вставить длинные номера счетов копипастом, приходится вводить руками
# СБОЛ. Классические переводы;Автопереводы
# Глючит Уже вторую неделю сразу после запуска зависает и ни на что не реагирует!
# iOS Release Engineer;iOS Platform
# Best Лучшее банковское приложение, молодцы разработчики и продукты 🤩
# None
# Сбербанк онлайн Удобное приложение, работает очень быстро, но если возможно сделайте пожалуйста возможность удалять ненужную историю и, чистить историю переводов и т.д.
# История операций
# Ирина СберСупер👍👍👍!!! Кроме кредитования🙃
# Цифровой Кредит;Mobile Online POS (Розничный кредит);[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)
# Сдаете позиции!!!! После обновления перестали отображаться оформленные металлические счета!!!!
# iOS Release Engineer;iOS Platform
# Рекомендации Сделали бы ещё, чтобы можно было на айфоне добавить в виджеты и не заходя в приложение смотреть баланс на карте.
# Global Navigation;PFM Бюджет
# Сбербанк Замечательное приложение, мне очень нравится)
# None
# Полезное приложение Приложение класс!!! Всегда под рукой твои финансы. Радуюсь невозможно. Хоть коммуналку оплати на раз, хоть телефон, или сделай перевод, а также налоги и штрафы. Полностью все устраивает 100% советую всем, кто дружит со Сбером. Самое удобное приложение
# iOS Platform;ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы
# Приложение Поменяйте иконку. Эта уже задрала
# Global Navigation;iOS Platform
# Услуг Как можно пополнит баланс телефона зарубежье (узбекистан) спасибо за ответ.
# ЕФС.Платежи МП;СБОЛ. Классические переводы
# Навязывают кредиты ... Очень навязчиво навязывают свои .... кредиты ... да ещё по якобы по низкой ставке ... не говоря клиентам о страховке этих кредитов , которая увеличивает кредит до немыслимых процентов ...
# [ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы);Цифровой Кредит;DBP.Витрины продаж
# Не запускается приложение! Весь день не отвечает приложение, разблокируется и всё! Ни чего дальше...
# iOS Platform
# оформление карт в разных областях оформив карту в Воронежской обл., я не вижу средства на моем лицевом счете, оформленном в Белгородской обл.
# Дебетовые карты в мобильном приложении
# Странная недоработка На 11 айфоне не работает фэйс ай ди, причем не на 1 телефоне. Вход только по паролю)))!
# Обновления все стоят последние, в том числе и операционка. Ползунок активен с фэйс ай ди...
# iOS Platform
# тяжелое приложение, еле ползает Приложение работает с сильными перебоями. Если ты чуть подальше от центра города либо за границей, то катастрофа, приложение еле ползает и нужны танцы с бубнами минимум на полчаса. За последний год не заметила улучшений в скорости работы. При этом приложения Тинькоффа и зарубежных банков летают просто...
#
# P.S. Разумеется, подключен скоростной интернет 4G от МТС.
# P.P.S. Если бы приложение того же Тинькоффа также ползало, вопросов к разработчикам бы не было.
# iOS Platform
# Хорошее приложение. Постоянно развивается. Давно использую.  Постоянно развивается. Я доволен.
# None
# Все как надо! Спасибо!
# None
# Обновление Не пишу отзывы , но последнее обновление просто ужас, все поменяли , теперь ничего не найдёшь , приложение перегружено информацией , я не смог найти сколько сколько у меня бонусов спасибо , и т.д , вообщем делайте проще и удобнее
# iOS Release Engineer;iOS Platform
# Удобно! Ненавижу банки, но приходится пользоваться. Приложение очень удобное, спасибо на этом!
# None
# ЖАЛОБА Перезапустила приложение и снова не показывает вклад.
# ВС.МП вклады
# Обновление всё испортило. После вчерашнего обновления приложение не открывается. Вылетает со стартовой страницы.
# iOS Release Engineer;iOS Platform
# Перевод Перевода мелких сумму почему надо подтверждать звонком ??(
# СБОЛ. Классические переводы;Автопереводы
# Сбер приложение Очень удобно и надёжные
# None
# яндекс деньги перестал работать перевод на яденьги,автоматом добавляется 111 к номеру счета
# СБОЛ. Классические переводы;Автопереводы;ЕФС.Платежи МП;iOS Release Engineer
# Отзыв: Брать с нас деньги при оплате счёта за квартплату, особенно во время пандемии, бесчеловечно и бессовестно
# ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы
# Молодцы Занимаются приложением, все на уровне, мелких недочетов и неудобств не встретил
# None
# Не могу зайти! Не заходит в приложение после последнего обновления!
# iOS Release Engineer;iOS Platform
# Гуд Хорошее приложение
# None
# Удобно 4276500022652802
# None
# Проблема со входом Приложение не работает около двух недель.пишет:нет соединения с интернетом, хотя если зайти через браузер проблем со входом нет
# iOS Release Engineer;iOS Platform
# Не заходит !!!! После обновления не могу зайти !
# iOS Release Engineer;iOS Platform
# Минус Зависает независимо от трафика и качества связи
# iOS Platform
# Виноват всегда клиент В конце июля Хотел досрочно погасить кредит через приложение, дата списания платежа стояла 9 августа! И о чудо деньги списали на конец июля, а остаток дней ещё начислили %. Ещё и должен остался! Оператор 900 сказала что можно выбрать дату списания, как она ошибалась! Тех поддержка приложения не смогла мне ответить! Виноват всегда клиент! Очень разочарован, нужно ходить ножками в банк и оформлять все лично через заявление!
# Цифровой Кредит;Mobile Online POS (Розничный кредит);ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)
# Обновление После сегодняшнего обновления не запускается ,заходишь и вылетает.  Сделайте что то с этим !!!
# iOS Release Engineer;iOS Platform
# Приложение Сбера Пользуюсь тремя приложениями банков. Приложение Сбербанка самое понятное и стабильное в работе.
# None
# Отзыв Отличный сервис
# None
# Сбербанк онлайн Очень удобно! Мне нравится... 😊
# None
# Не приходят одноразовые коды по смс на оплату онлайн Не приходят одноразовые коды по смс на оплату онлайн Не работает бот
# Мессенджер.
# Отображается некорректный остаток средств. Что сделали с приложением??? Историю посмотреть невозможно. Деньги перевела, они списались. А в остатке по карте как будто бы нет!!!
# История операций;PFM Бюджет;iOS Release Engineer
# Что случилось? Чем я так провинилась, что теперь цифра на значке приложения, которая показывает новые сообщения (новые траты) отображает мне накопительный итог с какого-то момента? Сейчас пишет 29. Блин, я захожу, все просматриваю, цифра со значка пропадает, непросмотренных нет. Совершу покупку и увижу значок с цифрой 30?!!! Зачем, нафиг блин у меня уже глаз дергается.
# Global Navigation;Мессенджер;PUSH IOS;PFM Бюджет
# ... Последнее время только расстраивают, нормально смс не приходят, Оповещения  приложения тоже через раз, баланс на на определенное время покупки ни где не посмотришь, выписки из банка тоже не читабельны. Пока 2-!
# За мобильный банк платим, услуга нормально не предоставляется
# PUSH IOS;ЕФС Выписки и справки. Mobile
# Ovenn312 Пока все нравится
# None
# Гнилой банк Подчистили негативные отзывы и мой в том числе. Молодцы!
# Закрываю все счета и ухожу в другой банк. Вы уже совсем обнаглели!
# iOS Platform
# Очень Удобно
# None
# Так держать Молодцы! Хорошее приложение
# None
# Руслан Самый отстойный банк России
# iOS Platform
# Сбер Это потрясающе
# None
# Нет темной темы Нет темной темы.
# Нельзя скрыть плитки в верхней части главного экрана.
# Global Navigation,iOS Platform
# СРОЧНО!! Обновите приложение, после обновления на IOS13.3 все слетело, приложение не устанавливается
# iOS Release Engineer;iOS Platform
# Личный кабинет После Нового года изменился интерфейс, слишком мелкий шрифт. Теперь приходится пользоваться очками что не удобно
# iOS Release Engineer;iOS Platform;Global Navigation
# Платежи Читабельно и оч оперативно
# Благодарю
# None
# Висит. Месяц уже почти. В команде, работающей над приложением сбера либо не платят зарплаты, либо сидят идиоты. Почти месяц не могут исправить ситуацию с зависанием приложения. Давно бы откат сделали на прошлую версию и пилили ошибки на тестовом сервере. 🤦🏻‍♂️
# Просто Алес. И так банк как сервис полное уг, так ещё и подобные финты ушами. Полгода, чтобы добавить темную тему (10 минут в новом Xcode) и месяца, чтобы сделать откат балованной сборки приложения, видимо, недостаточно. 🤦🏻‍♂️
# iOS Release Engineer;iOS Platform
# Вы лучшие ! Очень удобно !
# None
# После обновления Стал искать интерне для входа,а по сути связь норм
# iOS Release Engineer;iOS Platform
# Сбербанк Пожалуйста добавьте возможность оплаты коммунальных платежей по адресу, было бы очень удобно
# ЕФС.Платежи МП;Платежи. Штрафы;iOS Release Engineer
# Темная тема Планируете ли вы добавить темный режим в приложение ? Было бы идеально
# iOS Release Engineer;iOS Platform
# История пополнений К сожелению не устраивает много кого делать по фильтрам историю, я просто хочу взять и удалить какой перевод не хочу видеть. Будьте добры сделать, и у людей будет выбор, удалять или фильтровать. iOS
# История операций;СБОЛ. Классические переводы
# Огорчили! Какая деградация!
# None
# Комиссия внутри банка Самое дно из банковского сектора. Комиссия за переводы внутри банка 1% пздц. Без согласования условий договора. На..й Вас перехожу на Альфа Банк
# ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы;ЕФС.Автоплатежи;Автопереводы
# Пропала оплата по QR code Куда дели оплату по QR code?!
# ЕФС.Платежи МП;iOS Release Engineer
# Сбер Глупый банк!! С 1841г только ухудшения в работе! Работа на оценку 1 !!
# iOS Release Engineer;iOS Platform
# Подвисает после ввода пароля на секунд паять Подвисает после входа в приложение
# iOS Release Engineer;iOS Platform;Global Navigation
# Спасибо Спасибо за мобильность, за высококлассное обслуживание!!!
# None
# Лишний контент Здравствуйте! Как отключить весь контент в приложении? Везде  понажимал "не интересно", а воз и ныне там.  Меня интересуют только открытые банковские продукты. Контент про почему полезен завтрак и про космос я предпочту потреблять на более профильных ресурсах.
# DBP.Витрины продаж;PUSH IOS
# Вклады и счета ПОСЛЕ ПОСЛЕДНЕГО ОБНОВЛЕНИЯ НЕ ОТРАЖАЮТСЯ ВКЛАДЫ И СЧЕТА!!!!! Исправьте пожалуйста не возможно вывести деньги на карту!!!!! Вклады и счета висят и не грузятся
# iOS Release Engineer;ВС.МП вклады;PFM Бюджет
# Лучшее Хорошее приложение , пожалуй одно из лучших , среди банков .
# None
# Не могу открыть цель Хотела открыть цель с возможностью снимать с неё деньги. Первый взнос 0 рублей, я подтверждаю открытие и мне положение выдаёт ошибку: «сумма вклада, не соответсвует условиям вклада» Это как вообще? Если изначально условия вклада на цель 0 рублей, и ничего не надо пополнять. Исправьте пожалуйста, а то уже как неделю не могу открыть цель😒
# ВС.МП вклады;iOS Platform
# Благодарность Спасибо за четкую работу онлайн )))
# None
# Do you wanna raise downloads and revenue over 100 times? Worldwide promote your apps and rapidly increase downloads and revenue above 100 times! We are app marketing experts with rich experience, please contact us on Facebook: aso8866 .or Ping me at Skype/WhatsApp: +8615982207105 .Everyone can enjoy 3-day trial now!
# None
# Сбервсе Анимации тормозят, баланс не обновляется после переводов. Много бесполезных функций, которыми я не пользуюсь, из-за чего приложение весит более 200мб!
# PFM Бюджет;СБОЛ. Классические переводы;Автопереводы
# Вопрос Почему карта «Мир» не принимется в Apple Pay?
# Дебетовые карты в мобильном приложении;Карта в телефоне
# Обновление После обновления перестало отображаться вклады и счета, просто крутиться значок и всё, я хз как смотреть свои накопления. все очень плохо после обновления
# ВС.МП вклады;iOS Release Engineer
#  20%|██        | 2/10 [1:01:17<4:10:02, 1875.36s/it]
# Добрый день Верните раздел карта чтоб смотреть ближайшие банкоматы в приложении
# iOS Release Engineer;iOS Platform
# С обновлением начались проблемы... Ребят, у вас было очень классное приложение. Супер-удобно, ни у одного из ваших конкурентов чьими услугами удалось воспользоваться нет настолько продуманного и качественного софта. НО! С последними обновлениями начались очень неприятные моменты. Приложение постоянно вылетает по 5 раз в 10 секунд! С каких пор счёт может уходить в ноль? Почему в истории не пишутся все операции, проводимые со счётом? Куда с плюсового баланса деньги ушли в минус отследить невозможно быстро, не запрашивая полную детализацию... Пофиксите пожалуйста проблему хотя бы с вылетами... Пока не выше 2ки...
# iOS Release Engineer;iOS Platform
# Отзыв Не плохое удобное приложение
# None
# Венец костыльного кода Как можно было сделать этот идиотизм под названием приложение Сбербанк онлайн. Уже как несколько лет, когда ты обновляешь внутри приложения счета, после перевода или других операций сумма не меняется и только если заново выйти и запустить приложение, то о чудо сумма счетов обновится.
#
# Спасибо за платные платежи внутри банка. Это то что не хватает сейчас клиентам. Всем настоятельно не рекомендую пользоваться услугами этого банка.
# СБОЛ. Классические переводы;Автопереводы;iOS Platform
# Отлично Приложение стало удобное, красивое, быстрое особенно с 10 версии. Багов не заметил.
# None
# А у другого банка... Добрый день. В приложении другого банка есть очень удобная функция при частичном досрочном платеже по кредиту-пишешь сумму платежа и сразу показано на сколько уменьшится следующий платёж. Было бы здорово, если у вас тоже появилась такая функция.
# Цифровой Кредит;[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы);PFM Бюджет
# Плохо Сделайте возможность уменьшения срока кредита при досрочном погашении в приложении!
# Цифровой Кредит;[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)
# Снятие денег Я не понимаю , у меня списываются деньги  не за что  , и в истории нет никакой информации . Хочется добавить , я не одна такая , у многих моих знакомых списывать  по 150-200₽ . И в истории никакой информации
# История операций;PFM Бюджет
# Приложение. Невозможно убрать открытки с главного экрана. В предыдущей версии их можно было спрятать.
#
# Фон (графитовый) только на главном экране. Почему бы не сделать во всем приложении одинаково?
#
# В чате, когда необходимо пообщаться с оператором, автоматически выскакивают сообщения системы (не относящиеся к теме).
#
# Заставки с природой удачно вписались в приложение, глаз радуют. Можно побольше картинок.
# Global Navigation;iOS Release Engineer;iOS Platform
# , Большая благодарность.
# None
# Оплата кредита Оплата кредитов через историю - самая плохая идея, которую можно было только придумать!
# Цифровой Кредит;[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы);История операций
# Отзыв Все хорошо, все без проблем!
# None
# Сбой Обновила приложение, после этого оно перестало работать, постоянно вылетает.
# iOS Release Engineer;iOS Platform
# Онлайн Огонь)
# None
# Не работает микрофон Почему в приложениях которые запрашивает доступ Сбербанк онлайн отсутствует микрофон,я не могу звонить по этой причине и меня не слышат????
# iOS Release Engineer;iOS Platform
# Пропал анализ расходов После закрытия основной карты (одной из трёх) в приложении пропали данные по анализу расходов. Очень не удобно
# iOS Release Engineer;PFM Бюджет;iOS Platform
# Отсутствие уведомлений Отсутствие оповещения об изменении годового процента
# PUSH IOS
# Не люди Горите в аду за то что за перевод между сбер процент берете раньше не взяли теперь всех держите в лаушка и процент берете вы просто официальный бандиты
# ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы;ЕФС.Автоплатежи
# Фоновая работа! Приложение периодически после очередного запуска начинает работать в фоне и сжирает батарейку! И это не исправляется ни с одним исправлением! Может даже и инфу собирает с телефона! Отвратно!
# iOS Release Engineer;iOS Platform;DDA Profile
# Барахлит поиск Раньше была такая  сложность - при поисковом запросе в истории по имени выдаёт данные только за последний месяц, если нужны данные за больший срок - приходится вручную мотать вниз историю, чтобы подгрузить ранние транзакции, это долго и неудобно.
# После недавних обновлений появился глюк, даже подгружение истории вручную не позволяет поиску найти двухмесячный перевод, в общем списке он есть, а поиск его не видит. iPhone 7, iOS обновлена, поправьте, пожалуйста
# iOS Release Engineer;iOS Platform;История операций
# Макрушина Л.М. Очень полезная и лёгкая в работе программа !
# None
# СБП подключить и использовать тот еще квест! Систему быстрых переводов специально запрятали и сделали все, чтобы пользоваться было ей неудобно.
# СБОЛ. Классические переводы;Автопереводы;Global Navigation
# Вполне удобно для использования Для разработчиков: неплохо сделать если при наличии нескольких карт, можно было бы одну вручную привязать к номеру, потому что никто не может перевести деньги по номеру, система пишет, что к номеру карты не привязаны.
# Каждый раз для перевода приходиться скидывать номер карты.
# А если бы одна из карт была привязана для перевода, было бы удобно. Для тех, кто не хочет, можно не привязывать. Но опции такой не хватает.
# Дебетовые карты в мобильном приложении;СБОЛ. Классические переводы;Автопереводы
# Лучшее приложение Всё бы так работало в России, как приложение Сбера!
# None
# КАКОГО ЧЕРТА Я ДОЛЖНА ПЛАТИТЬ ЗА УВЕДОМЛЕНИЯ ОТ ТЕЛЕФОНА??? КАКОГО ЧЕРТА Я ДОЛЖНА ПЛАТИТЬ ЗА УВЕДОМЛЕНИЯ ОТ ТЕЛЕФОНА??? Вы совсем?!! Я какого должна платить за Push уведомления!!!??? Я отправлю письмо кому надо. А Вы уже не знаете как содрать деньги с людей.
# PUSH IOS
# Будет ли темная тема? Приложение нравится, но ночью открывать его очень не комфортно. Яркий белый свет прямо в глаза. Отсюда вопрос - будет ли темная тема?
# iOS Platform;Global Navigation;iOS Release Engineer
# Артём Главное надёжно
# None
# Отзыв Стабильно и честно.
# None
# 🙁 На айфоне се тормозит
# iOS Platform
# Всего средств В версии от 01.03.20 так и не исправлено: В «всего средств» показывает только информацию о вкладе, мои карты и средства на них не учитывает.
# PFM Бюджет;iOS Release Engineer
# Не все проработано Привяжите раздел Анализ финансов к счету, а не к карте, потому что при замене карты по окончании срока действия все данные, вся история стирается и отчеты начинаются заново со дня выдачи новой карты, хотя счёт один
# PFM Бюджет;История операций
# Не очень Очень часто слетают сохраненные шаблоны
# ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы
# Приложение Сбербанка Очень удобное приложение! Проблем ни разу не возникало .
# None
# Супер Удобное приложение, всем советую
# None
# Сбербанк онлайн Вот теперь меня всё устраивает! Приложение на 5+ и с бюджетом полный порядок)
# PFM Бюджет
# Обновление Почему после обновления все сбилось и нужно вводить данные Карты ?
# iOS Release Engineer;Дебетовые карты в мобильном приложении
# Просьба У меня в приложении не отображается, от кого пришёл перевод. Не в истории. Не в других окнах.
# История операций;СБОЛ. Классические переводы;Автопереводы
# Конвертация Предложение: сделайте наконец таки возможность обмена «баллов спасибо» на рубли, как это устроено во многих банках.
# Таким образом у вас увеличиться количество клиентов
# Развитие лояльности в МП СБОЛ;iOS Release Engineer
# Плохо Приложение зависает невозможно оплатить за питание в школе и создать шаблон
# iOS Platform;ЕФС.Платежи МП;Платежи. Штрафы
# Лагает Здравствуйте уважаемые разработчики , После последнего обновление приложение тормозит и зависает на iPhone SE , будьте добры исправьте этот лаг , спасибо!
# iOS Release Engineer;iOS Platform
# Глюк После обновления все равно зависает!!!
# iOS Release Engineer;iOS Platform
# Карта Сбербанк МИР Когда появится apple pay для карт МИР??? Сколько можно ждать?! Всех переводят на эти карты, а apple pay сделать не могут!!!
# Дебетовые карты в мобильном приложении;Карта в телефоне
# Дмитрий А что стало с уведомлениями?
# Приходят через одно и непонятно кто перевел деньги
# PUSH IOS;СБОЛ. Классические переводы;Автопереводы
# Катимся на дно Максимально неудобное приложение. После обновления теперь надо выполнить 4 действия вместо одного, чтоб узнать количество бонусов спасибо. Плюс эти диалоги, зачем они вообще нужны, в приложении, где я веду свой баланс, меньше всего хочется отправлять или принимать Сообщения.
# PUSH IOS;Развитие лояльности в МП СБОЛ;Мессенджер;Текстовый чат
# Что с приложением? После обновления сначала все тормозило, показывало неправильный остаток, теперь вообще не входит! Господа, исправьте, пожалуйста.
# iOS Release Engineer;iOS Platform
# Оформление Измените фон! Зелёные цифры на зелёном фоне - это изыскано!
# Global Navigation;iOS Release Engineer;iOS Platform
# Face ID Добрый день!Сменил телефон на 11 про перестал работать Face ID. В настройках все включено,звонил в апл сказали обращаться к вам.
# iOS Platform
# Предложение Здравствуйте. В разделе «Анализ финансов» при использовании фильтра можно выбрать все карты, либо одну карту для просмотра анализа. Имею 4 карты, двумя пользуюсь чаще всего, но график по ДВУМ картам я посмотреть не могу.
# Предлагаю сделать возможность строить график для нескольких выбранных карт ( к примеру: один график расходов для двух выбранных карт в фильтре.
# PFM Бюджет;Дебетовые карты в мобильном приложении
# Негатив В последнюю неделю Сбербанк вызываем массу неудобств. Сначала внезапно воткнули комиссию. Теперь  приложение глючит.
# По пунктам:
# 1)Без информирования по факту и предупреждении клиентов заранее, хотя для этого разумеется есть техническая возможность, банк ввёл комиссию на переводы. Это вызывает резонный вопрос к организации и недоверие. Сначала вы внедряете комиссию, а потом также, без предупреждения счета заморозите? В общем, отношение к клиенту понятно! Впрочем, есть другие банки: Альфа, Тинькофф, Райфайзен... из принципа снял все деньги. Не много, 400 тыс, но даже их я больше не намерен держать в вашей организации.
# 2) приложение перестало корректно отображать остаток. Зависло на 500 рублях, хотя на счете чуть больше двух тысяч. Попробую переустановить, надеюсь поможет. Годами все работало нормально, а сейчас начинаются какие-то танцы с бубном. Создается впечатление, что все это как-то связанно с изменением собственника банка.
# В России все государственное работает через ж... а теперь ещё и Сбербанк.
# iOS Release Engineer;iOS Platform;СБОЛ. Классические переводы;Автопереводы;PFM Бюджет
# Размер Всё прекрасно, но размер приложения всё больше и больше. Уже 271 мб. При плохом интернете приложение не работает.
# iOS Platform
# Супер Спасибо что вы есть! Я пошутил..
# None
# сбрасываются настройки версия 10.0
# iOS Release Engineer;iOS Platform
# Вы Лучшие!
# None
# Удивили👍 Разработчики, вы превзошли сами себя, обновление супер, ну наконец-то!!!!
# 👍👍👍👍👍
# iOS Release Engineer;iOS Platform
# Отлично!+ пожелание Было бы круто иметь возможность самому выставлять сумму в предложениях (  на экране оплаты телефонной связи к графе сумма предлагают 100 300 500 ) или чтобы приложение запоминало что я кладу 310 и предлагало эту сумму в дальнейшем
# Платежи. Штрафы;ЕФС.Платежи МП
# Сбербанк Очень удобно использовать Сбербанк чем другие банки, особенно старым пожилым все понятно всем банкам бы так попроще удачи Сбербанк у во всем
# None
# Задержка поступивших средств Муж перечислил с Карты на карту сбера а оплатить сразу с Карты коммунальные услуги нельзя пишет не достаточно средств? Т.е. своими средствами я сразу воспользоваться не могу...
# СБОЛ. Классические переводы;ЕФС.Автоплатежи;Платежи. Штрафы;ЕФС.Платежи МП
# Что случилось с приложением Постоянно начал моросить, переводы с нескольких попыток только получается всегда. Устал
# iOS Release Engineer;iOS Platform;СБОЛ. Классические переводы
# Не работает виджет На iPhone 6+, iOS 12.4.6 после обновления перестал работать виджет «Уведомления». Ждёт операций, push приходит, в виджете без изменений.
# По совету разработчиков удалил виджет и приложение, переустановил, подключил push - проблема осталась, push приходят, виджет не работает.
# Global Navigation;PUSH IOS;iOS Platform;iOS Release Engineer
# Карточки... Истории... БУЭЭЭ... Большое спасибо, что оставили возможность скрыть уродские карточки. Никчёмная летающая лажа с бесполезной информацией — только место на экране занимала и мешала работать с аппой.
# DBP.Витрины продаж;Global Navigation;iOS Platform
# Вам Слелайте платёж с уменьшением срока платежа в мобильном приложении.
# Мне не удобно приезжать из за операции в отделение Сбербанка.
# Я уже оставлял это пожелание, но увы ничего не изменилось.
# И пожалуйста информируйте лучше про ваши Акции по кредитным ставкам. Я только после 12 ноября узнал что мог взять кредит под 11% или 12% годовых
# DBP.Витрины продаж;Mobile Online POS (Розничный кредит);Цифровой Кредит;[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)
# Почему у меня нету реквизитов карты ? В предыдущих версиях было
# ...
# iOS Release Engineer;iOS Platform
# Что за лаги со звуком При обновлении (свайп вниз) постоянные лаги со звуком, в наушниках слышно особенно хорошо. Что не есть хорошо)
# PUSH IOS
# Не работает После последнего обновления зависает на главном экране
# iOS Release Engineer;iOS Platform
# Плата за обучение Долго водила реквизиты чтобы за учебу заплатить если свернуть приложение все слетает приходится заново набирать, ФГБОУ ВО ИВГПУ не находит! Приходится в ручную набирать реквизиты тогда находит
# ЕФС.Платежи МП;Платежи. Штрафы
# Неужели у сбера нет средств на нормальных дизайнеров и разработчиков С каждым обновлением все хуже и хуже, наверное дизайнеры и разработчики студенты начальных курсов. 1. Выбрать номер телефона из адресной книги для перевода получается с 5 раза, приходятся вбивать вручную, в настройках вообще лабиринт, что бы подключить Систему быстрых платежей или вообще что либо там найти нужно гуглить!!!!! Вы издеваетесь?! Скажите честно, просто хотите избавится от клиентов таким образом? От Вас что стали уходить нормальные разработчики? Просто кошмар! Приложением скоро станет невыносимо пользоваться!!!
# iOS Release Engineer;iOS Platform;СБОЛ. Классические переводы
# Вылетает Вылетает из приложения через 3 сек после входа, айфон 7+, не могу сделать перевод
# iOS Release Engineer;iOS Platform
# Конфиденциальность- уровень БОГ При входе в приложение, не вводя пароль для входа, во вкладке «Уведомления» можно увидеть все операции по счетам!!!
# DDA Profile;Редактируемый профиль клиента
# Приложение запускается очень долго Ужасно долго запускается приложение, вернее запускается раза с пятого. Даже если и запустится, то список карт может и вовсе не прогрузить. Телефон iPhone XS
# iOS Release Engineer;iOS Platform;Дебетовые карты в мобильном приложении
# Обновление После последнего обновления невозможно зайти в приложение, вылетает.
# iOS Release Engineer;iOS Platform
# Обновление отстой После последнего обновления не грузится информация о действующих кредитах(постоянно пишет обновите страницу), вот зачем ваять новый интерфейс(который не всегда удобен), но не проверять основное?!🤨
# iOS Release Engineer;iOS Platform;Цифровой Кредит;[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы);Цифровой Кредит
# Объём приложения всё больше и ... Уважаемые разработчики! Не превращайте приложение в ленту Дзен.. как мыть руки, куда мне поехать, и кому какую рожицу отправить))). Функция приложения в другом. Объём всё увеличивается с каждым обновлением, придётся сносить за неимением места на смартфоне. Доведёте людей своим информационно-развлекательно-спамическим направлением и будем, как по старинке снимать деньги с карты и платить наличкой))) Прислушивайтесь к разумным отзывам и просьбам. С ув. Андрей)
# iOS Release Engineer;iOS Platform
# Пропала загрузка своей заставки Раньше можно было поставить свою заставку на загрузку приложения. Сейчас приходится смотреть на это безвкусное корпоративное убожество каждый раз когда открываешь приложение. Очень плохо😤
# Global Navigation;iOS Release Engineer;iOS Platform
# Не видно кто сделал перевод!!! Не удобно! После обновления не видно кто перевел деньги!  Очень не удобно! Верните обратно!  Необходимо  хотя бы имя,
#  кто делает перевод!
# СБОЛ. Классические переводы;Автопереводы
# Перестал работать перевод на Яндекс.деньги Совсем обнаглели!
# СБОЛ. Классические переводы;Автопереводы
# Вы мошенники В приложении настроены смс уведомления, но почему то при поступлении средств они не приходят !!!!
# А вот о списании приходят!!!
# КАК ТАК ?
# PUSH IOS;Мессенджер
# Классное приложение. Очень удобно пользоваться.
# None
# Обновление После последнего обновления,не могу войти в приложение!Подключаюсь к WiFi и просто от мобильной сети- безрезультатно,нет подключения и все...Как исправить?
# iOS Release Engineer;iOS Platform
# Обновления Обновления отстают от обновление айфон, соответственно приложение начинает работать некорректно.
#
# Научитесь читать внимательнее😂
# iOS Release Engineer;iOS Platform
# Разочарование.😒 Очень огорчило что не государственное учреждение, позволяет приставам  не просто блокировать Карты но и позволяете самостоятельно снимать деньги счётов превышенную сумму ареста .А потом возвращать по частичкам .Не давая отчета вашему клиенту
#
# И ещё один момент деньги которые попадают через терминал Сбербанка зачисляются очень долго .Почти пять дней это не правильно .
# ВС.МП вклады;Дебетовые карты в мобильном приложении
# Не открывается приложение После последнего обновления не открывается приложение
# iOS Release Engineer;iOS Platform
# 👍Сбербанк👎 👍 приложение вне конкуренции
# 👎 нет cash back деньгами
# 👎 нет % на остаток по карте
# Итог: пока все ещё остаюсь на  ВТБ
# DBP.Витрины продаж;Дебетовые карты в мобильном приложении
# Не отображается дата платежа по кредиту После обновлений не вижу, когда следующая дата кредита или ипотеке
# Цифровой Кредит;[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы);iOS Release Enginee
# Четко Ахуенная прога
# None
# Перестал работать чат поддержки Приложение становится все лучше и лучше - это факт. Но ситуация с чатом поддержки от Сбера ставит в ступор: чат есть, ответа от банка нет. Если чат больше не работает, надо оповестить об этом пользователей и убрать его.
# Мессенджер;Текстовый чат
# Настройки экрана слетают После обновления ничего не изменилось — настройки разделов главного экрана все так же слетают.
# Global Navigation;iOS Platform
# Обновление Как же классно обновили приложение круто мне безумно нравится!!!👍🏻👍🏻👍🏻👍🏻
# iOS Release Engineer;iOS Platform
# Александр Господа разработчики,в последнем обновлении Вы добавили кучу не нужного,куда делась вкладка карты???,теперь не возможно посмотреть работает банкомат или нет!!!!!!!!!,вместо того чтобы делать проще и понятно вы делаете наоборот!!!!,УЖАС!!!!!
# iOS Release Engineer;iOS Platform;Дебетовые карты в мобильном приложении
# 🤷‍♂️ Почему убрали кнопку «не учитывать в расходах/зачислениях» на позициях в меню «анализ расходов и зачислений»?
# PFM Бюджет
# Вылетает последние два дня Заходишь с айфона, 3 секунды и закрывается, постоянно, буд-то какой-то алгоритм сбит последним обновлением.
#
# Ваша рекомендация помогла, переустановил, всё заработало. Спасибо
# iOS Release Engineer;iOS Platform
# Уведомления в приложении С 25.09.2019 перестали приходить уведомления в Сбербанк онлайн. Сейчас по старой схеме, все приходит на смс. Очень неудобно. Подскажите, из за чего проблема?
# PUSH IOS;Мессенджер;Текстовый чат
# Крутое Отличное приложение!!!
# None
# Сбой У меня какой то непонятный сбой в приложение мне не зайти в онлайн и даже пароль не вводится ,3 часа пытаюсь уже(
# iOS Platform
# Ебантяи На кой болт вы изменили дизайн?!
# С этим вонючим обновлением ни чего не понятно
# Верните старый дизайн!!!!!
# Или я вашего сберкота отвезу к ветеринару и чик- чик сделаем!!!!!
# iOS Release Engineer;iOS Platform;Global Navigation
# Переводы Свыше 50 тыс рублей взимается комиссия? В 2020 году? Между своими клиентами Сбербанка? Вы серьезно? А перевёл со Сбербанка в втб без комиссии! Браво! Клиентоориентированность «высший класс». И спасибо этому приложению, который украл мои деньги!
# СБОЛ. Классические переводы;Автопереводы
# Устраните лаг. На айфон 11 я захожу в приложение и вижу свой счёт на карте, мне делают перевод, приходит смс о зачислении денег я в приложении обновляю данные а баланс остаётся прежним. Чтобы увидеть обновлённый баланс приходится закрывать приложение и снова входить тогда он отображается корректно.
# PUSH IOS;PFM Бюджет;СБОЛ. Классические переводы
# Сбербанк Отличное приложение!!!
# Всё предельно ясно и понятно.
# Работает без накладок и сбоев.
# None
# Верните шаблоны В прошлых версиях при создании шаблонов в интернет-банке они отображались и в мобильном приложении. Сейчас же их не видно, очень не удобно(
# Исправьте, пожалуйста!
# ЕФС.Платежи МП;Платежи. Штрафы;iOS Release Engineer
# Не работает Не работает
# iOS Platform
# Суперрррр Суперрр
# None
# Выкидывает Когда захожу в приложение, выкидывает сразу
# iOS Platform
# Сбербанк онлайн Все хорошо, только очень мало денег.
# None
# Отсутствует информация по кредиту В информации по кредиту нет данных по проведённым платежам. Отсутствует информация по погашению основного кредита и по процентам.
# Цифровой Кредит;Mobile Online POS (Розничный кредит);[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)
# Сбербанк Супер 👏🏼 💓Удобное и стильное приложение
# None
# Нравятся диалоги Очень рада, что есть диалоги. Вижу историю, общаюсь, перевожу деньги, прикольные смайлики.
# Мессенджер;История операций;СБОЛ. Классические переводы;Автопереводы
# Отзыв Почему убрали возможность досрочного погашения кредита?
# Цифровой Кредит;Mobile Online POS (Розничный кредит);[ЕФС].Кредитные карты.Космонавты (Доп. услуги и сервисы)
# Дурдом Как изменить сумму в шаблоне почему так сложно
# СБОЛ. Классические переводы;ЕФС.Автоплатежи;Автопереводы
# Зачем платить за дизайн карты Зачем платить за дизайн карты если она не отображается  с твоим дизайном. Не в банке онлайн не в wallet
# Даже тенькоф и то умудрился это сделать оправданной затратой. Жирный минус Вам
# Плановый и досрочный перевыпуск дебетовых карт
# Комиссия Очень сожалею, что стали брать комиссию за перевод более 50 тысяч в месяц.
# СБОЛ. Классические переводы;ЕФС.Автоплатежи;Автопереводы;Платежи. Штрафы;ЕФС.Платежи МП
# Банкоматы Мне не понравилось то что я закинула деньги в банкомат, а они поступили через 5 дней. Это не приемлемо для столь огромного банка . Решите проблему так как убытки понесла я, а не банк
# ЕФС.Платежи МП;Платежи. Штрафы;СБОЛ. Классические переводы;ЕФС.Автоплатежи;Автопереводы
# Комиссия Комиссия за переводы , разочаровала был лучший банк, стал как все
# СБОЛ. Классические переводы;Автопереводы
# Не могу загрузить приложение После обновления Приложение не грузится. Требует вайфай. Но к сожалению вайфая у меня нет. Не знаю что делать.
# iOS Release Engineer;iOS Platform
# Ошибки После обновления тормозит , не реагирует на попытки открыть карту, сделать перевод
# iOS Release Engineer;iOS Platform
# Вход в приложение Сделайте доступ к приложению по отпечатку пальца
# iOS Release Engineer;iOS Platform
# Отзыв Звук монет отключается сам по себе. При каждом входе сами по себе раскрываются вкладки ( кредиты вклады и тд)
# PUSH IOS;ВС.МП вклады;Цифровой Кредит
# Оплата по Qr коду Куда делась оплата по Qr коду?
# ЕФС.Платежи МП
# Обновление Ещё быстрее? Вообще перестало работать
# iOS Release Engineer;iOS Platform
# Печаль После обновления не открывается страница перевода средств кликну Сбербанка!
# iOS Release Engineer;iOS Platform;"СБОЛ. Классические переводы;Автопереводы
# 5+ Очень удобное приложение
# None
# Расходы финансов Почему убрали кнопку «не учитывать в расходах», когда смотришь расходы финансов и можно было самостоятельно убирая «лишнее» узнавать свой реальный расход. И когда заходил в приложение всегда показывало наверху во вкладке сумму моих расходов.
# PFM Бюджет;Global Navigation
# Normal I Спасибо
# None
# !!! Разработчики вы где ?!?!?!?
# После обновления приложение не работает!!!!!
# Отреагируйте уже как нибудь !!!!!!
# iOS Release Engineer;iOS Platform
# Камиль Хорошее приложение
# None
# Итзыв Все ок
# None
# Вклады и карта Посте обновления не отображаются вклады, пишет что их нет. На деле они есть и теперь их не видно. Карты так вообще перестали быть видны. Только испортили приложение, с каждым обновлением все хуже и хуже. Почему нельзя сделать один раз нормально и забыть, зачем чат, анимация, и так далее.  Программисты что курят... в каких облаках летают!? Бардак а не приложение стало
# ВС.МП вклады;Дебетовые карты в мобильном приложении;iOS Release Engineer
# Ошибки Заказал справку для ежегодного отчета госслужащих, приложение зависло, пришлось удалять и загружать
#  по новой
# ЕФС Выписки и справки. Mobile
# Не работает после обновления «Спасибо!» Вчера обновил приложение и оно перестало работать. В самый нужный момент не смог провести операции.
# iOS Release Engineer;iOS Platform;Развитие лояльности в МП СБОЛ
# Отличный карманный помощник Нравится функционал приложения. Переводы физ лицам и особенно оплата жку без комиссий. В период всеобщей самоизоляции по достоинству оценил удобство он-лайн платежей. Сравнивать есть с чем - установлены приложения других крупных банков, таких как ал**а, х**м кредит и по**а банка. В качестве минуса можно было бы назвать излишнюю цветастость вкладок и маленький шрифт, а ещё отсутствие привязки карт платежной системы «МИР» к Apple Pay, но повторюсь - функционал с лихвой перекрывает эти минусы, а для Apple Pay можно выпустить и цифровую карту.
# iphone 11
# Разработчикам - спасибо.
# None
# Павел Супер приложение👍👍👍
# None
# Платежи-переводы надёжно, но дорого. Всё хорошо, но нужно снижать комиссию
# Платежи. Штраф;ЕФС.Платежи МП;ЕФС.Автоплатежи
# Хорошее приложение Йоу
# None
# Сбербанк За введение платы за переводы +50круб одну звезду всем вашим Приложениям
# Платежи. Штраф;ЕФС.Платежи МП;ЕФС.Автоплатежи
# баг кнопки диалоги 1.перегружен интерфейс
# 2. раздражает баг -каждый раз при старте программы на кнопке диалоги показывается что пришли новые сообщения, на самом деле их там нет никаких
# Мессенджер;Global Navigation;iOS Platform
# Возникла проблема Что случилось с приложением, не могу посмотреть комментарий к переводу, в сообщении видно, а в прошедших переводах посмотреть комментарий невозможно! Верните как было🙏🏻
# СБОЛ. Классические переводы;Автопереводы
# Обновление После обновления вылетает!!!
# iOS Release Engineer;iOS Platform
# Отличное приложение! Отличный банк,с адекватным, быстрым приложением! Легко и просто управлять финансами!
# None
# Не работает после обновления!!! Для чего нужны эти обновления, если после них все висит, не работает ни одна функция!
# iOS Release Engineer;iOS Platform
# Почему После последнего обновления перестало заходить в кабинет
# iOS Release Engineer;iOS Platform
# После ваших обновлений После ваших обновлений приложение не запускается, белый экран, а потом вылетает. (iPhone 5) Скажите, вы как-то это будете исправлять?
# iOS Release Engineer;iOS Platform
# Все данные После последнего обновления в приложении стали доступны все данные о карте: номер карты, cvc код и тд. Это крайне не безопасно!!
# iOS Release Engineer;iOS Platform;DDA Profile;Редактируемый профиль клиента
# ..... После последнего обновления приложение не открывается, оно тупо вылетает, можно как нибудь исправить ???  Может только на моем айфоне, хз, но мне нужно зайти и перевести срочно деньги, а не могу
# iOS Release Engineer;iOS Platform
#  40%|████      | 4/10 [2:41:20<3:58:13, 2382.19s/it]
# Пользование приложением Не совсем интуитивное, иногда приходится искать нужное действие...
# Способ сохранения чека так же не совсем понятен...
#  40%|████      | 4/10 [2:41:25<4:02:08, 2421.49s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-68485a16f95e> in <module>
#       5         data_marked[-1]['review']=review
#       6         print(review)
# ----> 7         label = input()
#       8         data_marked[-1]['label'] = label
#
# ~/anaconda3/envs/sbercode/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~/anaconda3/envs/sbercode/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
data_marked_df = pd.DataFrame(data_marked).dropna()

# %%
data_marked_df = data_marked_df[data_marked_df['label']!='None']

# %%
data_marked_df.to_csv(os.path.join(DATA_PATH,'marked.csv'))

# %%
data_marked_df
# Out:
#                                                 review  \
# 0    Сбербанк Отличное приложение! Пользуюсь им уже...
# 1    Отстой Верните оповещение при снятии и поступл...
# 2    Не ожидала Выкидывает из приложения даже не ус...
# 3    Жадность Спасибо за комиссии. Теперь жене толь...
# 4    Переделайте историю операций Нельзя посмотреть...
# ..                                                 ...
# 395  Не работает после обновления!!! Для чего нужны...
# 396  Почему После последнего обновления перестало з...
# 397  После ваших обновлений После ваших обновлений ...
# 398  Все данные После последнего обновления в прило...
# 399  ..... После последнего обновления приложение н...
#
#                                                  label
# 0                                         iOS Platform
# 1                        iOS Release Engineer;PUSH IOS
# 2                                         iOS Platform
# 3    Sberbank ID B2C;ЕФС.Платежи МП;Платежи. Штрафы...
# 4    История операций;iOS Platform;ЕФС Выписки и сп...
# ..                                                 ...
# 395                  iOS Release Engineer;iOS Platform
# 396                  iOS Release Engineer;iOS Platform
# 397                  iOS Release Engineer;iOS Platform
# 398  iOS Release Engineer;iOS Platform;DDA Profile;...
# 399                  iOS Release Engineer;iOS Platform
#
# [304 rows x 2 columns]

# %%
data['TIT_REW'] = [data.iloc[j][TITLE_COL]+' '+data.iloc[j][REVIEW_COL] for j in data.index]

# %%
data_marked_df['tit_rev'] = data_marked_df['review']
data_marked_df['review'] = [data[data['TIT_REW']==rev][REVIEW_COL].values[0] for rev in data_marked_df['tit_rev']]

# %%
data_marked_df.to_csv(os.path.join(DATA_PATH,'marked.csv'))

# %% [markdown]
# # Load predictions

# %%
data_marked_df = pd.read_csv(os.path.join(DATA_PATH,'marked.csv'),index_col = 0)

# %%
bert_preds = pd.read_csv(os.path.join(DATA_PATH, '3_predictions', 'teams_predictions_bert.csv'),index_col=0)

# %%
flair_preds = pd.read_csv(os.path.join(DATA_PATH, '3_predictions', 'teams_predictions_flair.csv'))

# %%
import pickle

# %%
with open(os.path.join(DATA_PATH, '3_predictions', 'team_labeled.pkl'), 'rb') as f:
    keywords_preds = pickle.load(f)

# %%
tfidf_cos_preds = pd.read_csv(os.path.join(DATA_PATH, '3_predictions', 'tfidf_cos_preds.csv'))

# %%
REVIEW_COL = 'review'
PREDS_COL = 'euclid_team'
preds = []
for review in data_marked_df[REVIEW_COL]:
    preds.append(bert_preds[bert_preds[REVIEW_COL]==review][PREDS_COL].values[0])
assert len(preds)==len(data_marked_df[REVIEW_COL])

data_marked_df['bert_'+PREDS_COL] = preds
PREDS_COL = 'cosine_team'
preds = []
for review in data_marked_df[REVIEW_COL]:
    preds.append(bert_preds[bert_preds[REVIEW_COL]==review][PREDS_COL].values[0])
assert len(preds)==len(data_marked_df[REVIEW_COL])

data_marked_df['bert_'+PREDS_COL] = preds

# %%
len(bert_preds)
# Out:
# 11584

# %%
REVIEW_COL = 'review'
PREDS_COL = 'euclid_team'
preds = []
for review in data_marked_df[REVIEW_COL]:
    preds.append(flair_preds[flair_preds[REVIEW_COL]==review][PREDS_COL].values[0])
assert len(preds)==len(data_marked_df[REVIEW_COL])

data_marked_df['flair_'+PREDS_COL] = preds
PREDS_COL = 'cosine_team'
preds = []
for review in data_marked_df[REVIEW_COL]:
    preds.append(flair_preds[flair_preds[REVIEW_COL]==review][PREDS_COL].values[0])
assert len(preds)==len(data_marked_df[REVIEW_COL])

data_marked_df['flair_'+PREDS_COL] = preds

# %%
REVIEW_COL = 'review'
PREDS_COL = 'label'
preds = []
for review in data_marked_df['tit_rev']:
    if len(tfidf_cos_preds[tfidf_cos_preds[REVIEW_COL]==review])!=0:
        preds.append(tfidf_cos_preds[tfidf_cos_preds[REVIEW_COL]==review][PREDS_COL].values[0])
    else:
        preds.append('')
assert len(preds)==len(data_marked_df[REVIEW_COL])

data_marked_df['tfidf_cos_preds'] = preds

# %%
REVIEW_COL = 'Review'
PREDS_COL = 'teams'
preds = []
for review in data_marked_df['review']:
    preds.append(keywords_preds[keywords_preds[REVIEW_COL]==review][PREDS_COL].values[0])
assert len(preds)==len(data_marked_df['review'])

data_marked_df['keywords_preds'] = preds

# %%
data_marked_df.to_csv(os.path.join(DATA_PATH,'marked.csv'))

# %% [markdown]
# # Compute quality metrics

# %%
LABEL_COL = 'label'

# %%
data_marked_df = pd.read_csv(os.path.join(DATA_PATH,'marked.csv'),index_col = 0)

# %%
y_true = [y.split(';') for y in data_marked_df[LABEL_COL]]

# %%
bert_eucl_preds = list(data_marked_df['bert_euclid_team'].values)
bert_cos_preds = list(data_marked_df['bert_cosine_team'].values)

# %%
flair_eucl_preds = list(data_marked_df['flair_euclid_team'].values)
flair_cos_preds = list(data_marked_df['flair_cosine_team'].values)

# %%
tfidf_cos_preds = list(data_marked_df['tfidf_cos_preds'].values)

# %%
keywords_preds = [y[2:-2].split('\', \'')[0] for y in data_marked_df['keywords_preds'].values]
# keywords_preds = [preds if len(preds)!=1 and preds[0]!='' else ['iOS Platform'] for preds in keywords_preds]

# %%
metrics = []

# %%
def accuracy(y_trues,  y_preds):
    import numpy as np
    accs = []
    for j in range(3):
        y_true = y_trues[j*100:(j+1)*100]
        y_pred = y_preds[j*100:(j+1)*100]


        acc = 0
        for i,pred in enumerate(y_pred):
            if pred in y_true[i]:
                acc+=1
            else:
                pass
        accs.append(acc/len(y_pred))
    return np.mean(accs), np.std(accs)

# %%
mean, std = accuracy(y_true,bert_eucl_preds)
print('Bert eucleadean metric accuracy = ',round(mean,2),'+/-',round(std,2))
metrics.append({'model':'BERT with euclidean distance','accuracy_mean':mean, 'accuracy_std':std})
mean, std = accuracy(y_true,bert_cos_preds)
print('Bert cosine metric accuracy = ',round(mean,2),'+/-',round(std,2))
metrics.append({'model':'BERT with cosine distance','accuracy_mean':mean, 'accuracy_std':std})
print()
mean, std = accuracy(y_true,flair_eucl_preds)
print('Flair eucleadean metric accuracy = ',round(mean,2),'+/-',round(std,2))
metrics.append({'model':'Flair with euclidean distance','accuracy_mean':mean, 'accuracy_std':std})
mean, std = accuracy(y_true,flair_cos_preds)
print('Flair cosine metric accuracy = ',round(mean,2),'+/-',round(std,2))
metrics.append({'model':'Flair with cosine distance','accuracy_mean':mean, 'accuracy_std':std})
print()
mean, std = accuracy(y_true,tfidf_cos_preds)
print('TFIDF cosine metric accuracy = ',round(mean,2),'+/-',round(std,2))
metrics.append({'model':'OneHot with cosine distance','accuracy_mean':mean, 'accuracy_std':std})
print()
mean, std = accuracy(y_true,keywords_preds)
print('Keywords matching accuracy = ',round(mean,2),'+/-',round(std,2))
metrics.append({'model':'Keywords matching','accuracy_mean':mean, 'accuracy_std':std})
# Out:
# Bert eucleadean metric accuracy =  0.52 +/- 0.07
# Bert cosine metric accuracy =  0.54 +/- 0.06
#
# Flair eucleadean metric accuracy =  0.25 +/- 0.02
# Flair cosine metric accuracy =  0.56 +/- 0.04
#
# TFIDF cosine metric accuracy =  0.57 +/- 0.07
#
# Keywords matching accuracy =  0.37 +/- 0.06

# %%
def accuracy_wo_platform(y_trues,  y_preds):
    import numpy as np
    accs = []
    for j in range(3):
        y_true = y_trues[j*100:(j+1)*100]
        y_pred = y_preds[j*100:(j+1)*100]


        acc = 0
        for i,pred in enumerate(y_pred):
            if pred in y_true[i] and pred!='iOS Platform':
                acc+=1
            else:
                pass
        accs.append(acc/len(y_pred))
    return np.mean(accs), np.std(accs)

# %%
mean, std = accuracy_wo_platform(y_true,bert_eucl_preds)
print('Bert eucleadean metric accuracy = ',round(mean,2),'+/-',round(std,2))
mean, std = accuracy_wo_platform(y_true,bert_cos_preds)
print('Bert cosine metric accuracy = ',round(mean,2),'+/-',round(std,2))
print()
mean, std = accuracy_wo_platform(y_true,flair_eucl_preds)
print('Flair eucleadean metric accuracy = ',round(mean,2),'+/-',round(std,2))
mean, std = accuracy_wo_platform(y_true,flair_cos_preds)
print('Flair cosine metric accuracy = ',round(mean,2),'+/-',round(std,2))
print()
mean, std = accuracy_wo_platform(y_true,tfidf_cos_preds)
print('TFIDF cosine metric accuracy = ',round(mean,2),'+/-',round(std,2))
print()
mean, std = accuracy_wo_platform(y_true,keywords_preds)
print('Keywords matching accuracy = ',round(mean,2),'+/-',round(std,2))
# Out:
# Bert eucleadean metric accuracy =  0.32 +/- 0.05
# Bert cosine metric accuracy =  0.38 +/- 0.08
#
# Flair eucleadean metric accuracy =  0.13 +/- 0.02
# Flair cosine metric accuracy =  0.22 +/- 0.04
#
# TFIDF cosine metric accuracy =  0.31 +/- 0.03
#
# Keywords matching accuracy =  0.33 +/- 0.07

# %%
def recall(y_trues,  y_preds):
    classes = list(team_names_keywords.keys())+['']
    import numpy as np
    from collections import Counter
    recalls = []
    for j in range(3):
        
        tp = np.zeros(len(classes))
        fp = np.zeros(len(classes))
        
        y_true = y_trues[j*100:(j+1)*100]
        y_pred = y_preds[j*100:(j+1)*100]
        
        for i,pred in enumerate(y_pred):
            if pred in y_true[i]:
                tp[classes.index(pred)]+=1
            else:
                for true in y_true[i]:
                    try:
                        fp[classes.index(true.rstrip('\'').rstrip('.').lstrip('"'))]+=1
                    except ValueError:
                        pass
        recalls.append(np.sum(tp)/np.sum(tp+fp))
    return np.mean(recalls), np.std(recalls)

# %%
def prescision(y_trues,  y_preds):
    import numpy as np
    from collections import Counter
    recalls = []
    classes = list(team_names_keywords.keys())+[np.nan]+['']


    for j in range(3):
        
        tp = np.zeros(len(classes))
        fp = np.zeros(len(classes))
        
        y_true = y_trues[j*100:(j+1)*100]
        y_pred = y_preds[j*100:(j+1)*100]
        
        for i,pred in enumerate(y_pred):
            if pred in y_true[i]:
                tp[classes.index(pred)]+=1
            else:
                fp[classes.index(pred)]+=1
        recalls.append(np.sum(tp)/np.sum(tp+fp))
    return np.mean(recalls), np.std(recalls)

# %%
mean, std = recall(y_true,bert_eucl_preds)
print('Bert eucleadean metric recall = ',round(mean,2),'+/-',round(std,2))
metrics[0]['recall_mean']  = mean
metrics[0]['recall_std']  = std
mean, std = recall(y_true,bert_cos_preds)
print('Bert cosine metric recall = ',round(mean,2),'+/-',round(std,2))
metrics[1]['recall_mean']  = mean
metrics[1]['recall_std']  = std
print()
mean, std = recall(y_true,flair_eucl_preds)
print('Flair eucleadean metric recall = ',round(mean,2),'+/-',round(std,2))
metrics[2]['recall_mean']  = mean
metrics[2]['recall_std']  = std
mean, std = recall(y_true,flair_cos_preds)
print('Flair cosine metric recall = ',round(mean,2),'+/-',round(std,2))
metrics[3]['recall_mean']  = mean
metrics[3]['recall_std']  = std
print()
mean, std = recall(y_true,tfidf_cos_preds)
print('TFIDF cosine metric recall = ',round(mean,2),'+/-',round(std,2))
metrics[4]['recall_mean']  = mean
metrics[4]['recall_std']  = std
print()
mean, std = recall(y_true,keywords_preds)
print('Keywords matching recall = ',round(mean,2),'+/-',round(std,2))
metrics[5]['recall_mean']  = mean
metrics[5]['recall_std']  = std
# Out:
# Bert eucleadean metric recall =  0.33 +/- 0.07
# Bert cosine metric recall =  0.34 +/- 0.06
#
# Flair eucleadean metric recall =  0.13 +/- 0.01
# Flair cosine metric recall =  0.37 +/- 0.03
#
# TFIDF cosine metric recall =  0.35 +/- 0.06
#
# Keywords matching recall =  0.21 +/- 0.05

# %%
mean, std = prescision(y_true,bert_eucl_preds)
print('Bert eucleadean metric prescision = ',round(mean,2),'+/-',round(std,2))
mean, std = prescision(y_true,bert_cos_preds)
print('Bert cosine metric prescision = ',round(mean,2),'+/-',round(std,2))
print()
mean, std = prescision(y_true,flair_eucl_preds)
print('Flair eucleadean metric prescision = ',round(mean,2),'+/-',round(std,2))
mean, std = prescision(y_true,flair_cos_preds)
print('Flair cosine metric prescision = ',round(mean,2),'+/-',round(std,2))
print()
mean, std = prescision(y_true,tfidf_cos_preds)
print('TFIDF cosine metric prescision = ',round(mean,2),'+/-',round(std,2))
print()
mean, std = prescision(y_true,keywords_preds)
print('Keywords matching prescision = ',round(mean,2),'+/-',round(std,2))
# Out:
# Bert eucleadean metric prescision =  0.52 +/- 0.07
# Bert cosine metric prescision =  0.54 +/- 0.06
#
# Flair eucleadean metric prescision =  0.25 +/- 0.02
# Flair cosine metric prescision =  0.56 +/- 0.04
#
# TFIDF cosine metric prescision =  0.57 +/- 0.07
#
# Keywords matching prescision =  0.37 +/- 0.06

# %%
def f1_score(y_trues, y_preds):
    
    import numpy as np
    from collections import Counter
    classes = list(team_names_keywords.keys())+['']+[np.nan]
    f1s = []
    for j in range(10):
        
        tp = np.zeros(len(classes))
        fp = np.zeros(len(classes))
        fn = np.zeros(len(classes))
        
        y_true = y_trues[j*10:(j+1)*10]
        y_pred = y_preds[j*10:(j+1)*10]
        
        for i,pred in enumerate(y_pred):
            if pred in y_true[i]:
                tp[classes.index(pred)]+=1
            else:
                fp[classes.index(pred)]+=1
                for true in y_true[i]:
                    try:
                        fn[classes.index(true.rstrip('\''))]+=1
                    except ValueError:
                        pass
        recall = np.sum(tp)/np.sum(tp+fn)
        precision = np.sum(tp)/np.sum(tp+fp)
        if recall==0 and precision==0:
            continue


        f1s.append(2*precision*recall/(precision+recall))
    return np.mean(f1s), np.std(f1s)

# %%
mean, std = f1_score(y_true,bert_eucl_preds)
print('Bert eucleadean metric f1 = ',round(mean,2),'+/-',round(std,2))
metrics[0]['f1_score_mean']  = mean
metrics[0]['f1_score_std']  = std

mean, std = f1_score(y_true,bert_cos_preds)
print('Bert cosine metric f1 = ',round(mean,2),'+/-',round(std,2))

metrics[1]['f1_score_mean']  = mean
metrics[1]['f1_score_std']  = std
print()
mean, std = f1_score(y_true,flair_eucl_preds)
print('Flair eucleadean metric f1 = ',round(mean,2),'+/-',round(std,2))
metrics[2]['f1_score_mean']  = mean
metrics[2]['f1_score_std']  = std
mean, std = f1_score(y_true,flair_cos_preds)
print('Flair cosine metric f1 = ',round(mean,2),'+/-',round(std,2))
metrics[3]['f1_score_mean']  = mean
metrics[3]['f1_score_std']  = std
print()
mean, std = f1_score(y_true,tfidf_cos_preds)
print('TFIDF cosine metric f1 = ',round(mean,2),'+/-',round(std,2))
metrics[4]['f1_score_mean']  = mean
metrics[4]['f1_score_std']  = std
print()
mean, std = f1_score(y_true,keywords_preds)
print('Keywords matching f1 = ',round(mean,2),'+/-',round(std,2))
metrics[5]['f1_score_mean']  = mean
metrics[5]['f1_score_std']  = std
# Out:
# Bert eucleadean metric f1 =  0.42 +/- 0.15
# Bert cosine metric f1 =  0.38 +/- 0.11
#
# Flair eucleadean metric f1 =  0.2 +/- 0.11
# Flair cosine metric f1 =  0.48 +/- 0.16
#
# TFIDF cosine metric f1 =  0.52 +/- 0.12
#
# Keywords matching f1 =  0.22 +/- 0.11

# %%
metrics = pd.DataFrame(metrics).set_index('model')

# %%
metrics.to_csv(os.path.join(DATA_PATH, '3_predictions', 'model_metrics.csv'))

# %%
metrics
# Out:
#                                accuracy_mean  accuracy_std  recall_mean  \
# model
# BERT with euclidean distance        0.523333      0.073636     0.332971
# BERT with cosine distance           0.536667      0.059067     0.338565
# Flair with euclidean distance       0.250000      0.016330     0.127611
# Flair with cosine distance          0.563333      0.041096     0.374472
# OneHot with cosine distance         0.566667      0.065490     0.348332
# Keywords matching                   0.370000      0.064807     0.207649
#
#                                recall_std  f1_score_mean  f1_score_std
# model
# BERT with euclidean distance     0.066308       0.420986      0.148256
# BERT with cosine distance        0.060877       0.381978      0.114157
# Flair with euclidean distance    0.008797       0.204672      0.112118
# Flair with cosine distance       0.032604       0.481776      0.162705
# OneHot with cosine distance      0.061853       0.520125      0.120319
# Keywords matching                0.049650       0.221724      0.106149

# %% [markdown]
# # Plot metrics

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,ax = plt.subplots(1,3,figsize=(30,24), sharey = 'row')
for i, metric in enumerate(['accuracy','recall','f1_score']):
    metric = metric+'_mean'
    sns.barplot(metrics.index,metrics[metric], ax = ax[i%3],yerr = metrics[metric[:-4]+'std'].values)
    ax[i%3].set_xticklabels(metrics.index, rotation = 90, fontsize = 30)
    ax[i%3].set_yticklabels(np.array(range(8))/10, fontsize = 35)
    ax[i%3].set_ylabel(metric[:-5],fontsize=35)

plt.show()
# fig.savefig(os.path.join(DATA_PATH,'metric.png'), dpi = 300)
# Out:
# /Users/Alisa.Alenicheva/anaconda3/envs/sbercode/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
